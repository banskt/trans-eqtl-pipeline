# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt
import numpy as np
X = np.random.rand(48).reshape(4, 12)

# %%
Z = linkage(X, 'centroid')
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(Z)
