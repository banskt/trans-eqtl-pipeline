# %%
import time
import sys, os, collections
import numpy as np
sys.path.append('../')
from operator import attrgetter

def read_ldfile(ldfile):
    ldict = collections.defaultdict(dict) #lambda: False)
    with open(ldfile) as instream:
        next(instream)
        for line in instream:
            arr = line.rstrip().split()
            chrm = int(arr[0])
            pos1 = str(arr[1])
            pos2 = str(arr[2])
            n = int(arr[3])
            r2 = float(arr[4])
            ldict[pos1][pos2] = r2
    return ldict

import mpmath

mpmath.mp.dps = 500
def pval(x): return float(1 - 0.5 * (1 + mpmath.erf(x/mpmath.sqrt(2))))

SNPRES_FIELDS = ['rsid', 'chrom', 'pos', 'q', 'mu', 'sigma', 'p']
class SNPRes(collections.namedtuple('_SNPRes', SNPRES_FIELDS)):
    __slots__ = ()
        
def tejaas(filepath, chrom):
    res = list()
    with open(filepath, 'r') as mfile:
        next(mfile)
        for line in mfile:
            arr   = line.strip().split("\t")
            rsid  = arr[0]
            pos   = int(arr[1])
            p     = float(arr[5])
            q     = float(arr[2])
            mu    = float(arr[3])
            sigma = float(arr[4])
            if sigma == 0:
                continue
            p = p if p != 0 else pval( (q - mu) / sigma)
            res.append(SNPRes(rsid=rsid, chrom=chrom, pos=pos, q=q, mu=mu, sigma=sigma, p=p))
    return res

def tejaas_write(snplist, filepath):
    with open(filepath, 'w') as mfile:
        mfile.write("ID\tPos\tQ\tMu\tSigma\tP\n")
        for snp in snplist:
            fmtstring = "{:s}\t{:d}\t{:g}\t{:g}\t{:g}\t{:g}\n"
            mfile.write(fmtstring.format(snp.rsid, snp.pos, snp.q, snp.mu, snp.sigma, snp.p))

# %%
def prune_rr(rrfile, chrm, ld_dict, isworst=False):
    start = time.time()
    snplist = tejaas(rrfile, chrm)
    pruned_snps = list()
    best = None
    i = 0
    added = collections.defaultdict(lambda: False)
    switched = collections.defaultdict(lambda: False)
    while i < (len(snplist) - 2):
        best = snplist[i]
        if switched[best.pos]:
            next
        # print("best", best)
        if ld_dict.get("{:d}".format(snplist[i].pos), None) is None:
            ## This snp is not in LD with anyone, add and next
            if not added[best.pos] and not switched[best.pos]:
                pruned_snps.append(best)
                # print("add1", best)
                added[best.pos] = True
        else:
            ## This snp is in LD with at least one other SNP
            j = 1
            ## while the SNPs are less than 100kb appart and indices are within possible
            while (np.abs(snplist[i].pos - snplist[i+j].pos) <= 100000) and (i+j < len(snplist) - 1):
                # print(len(snplist), i, j)
                ## if my current snp is in LD with the next snp, does it have lower pvalue?
                if ld_dict["{:d}".format(snplist[i].pos)].get("{:d}".format(snplist[i+j].pos), None) is not None:
                    if isworst:
                        if snplist[i+j].p > best.p:
                            best = snplist[i+j]
                            # print("switch", best)
                        else:
                            # print("no switch", snplist[i+j])
                            ## this snp is in LD and has no better pval than one before it (or equal)
                            switched[snplist[i+j].pos] = True
                    else:
                        if snplist[i+j].p < best.p:
                            best = snplist[i+j]
                            # print("switch", best)
                        else:
                            # print("no switch", snplist[i+j])
                            ## this snp is in LD and has no better pval than one before it (or equal)
                            switched[snplist[i+j].pos] = True
                else:
                    pass
                    ## this pair of SNPs is not in LD, the SNP ahead (i+j) will be checked later
                    # pruned_snps.append(best)
                j += 1
            if not added[best.pos] and not switched[best.pos]:
                pruned_snps.append(best)
                # print("add2", best)
                added[best.pos] = True
        i += 1
    took = time.time() - start
    print("LD prunning took", took)
    return sorted(pruned_snps, key=attrgetter('pos'), reverse=False)

# %%
from utils import utils
# tissue_file = "/usr/users/fsimone/trans-eqtl-pipeline/main/tissues.txt"
# tissuenames, descriptions = utils.read_tissues(tissue_file)
# tissues = ["gtex-"+t for t in tissuenames]
tissues = ["gtex-ms"]

expressions = ["norm"] #["lmcorrected_age_precorr"]
randmethods = ["tejaas_rand_"+str(i) for i in range(1,45)]
methods = ["tejaas", "tejaas_rand"] #+ randmethods
# basedir = "/cbscratch/franco/trans-eqtl/dev-pipeline/gtex_v6"
basedir = "/cbscratch/franco/trans-eqtl/dev-pipeline/precorr"
chroms = np.arange(1,23)
isworst = True

# %%
# Pruning

for chrm in chroms: #range(1,23):
    start = time.time()
    print("Loading CHR ", chrm, end="")
    ldfile = "/cbscratch/franco/datasets/gtex/genotypes/vcfs_allsamples/LD/chr{:d}_ld_window_100000.geno.ld".format(chrm)
    myldict = read_ldfile(ldfile)
    took = time.time() - start
    print(" - {:g} seconds".format(took))
    
    # Do the actual pruning on all datasets and stuff
    for tissue in tissues:
        for expr in expressions:
            pruned_snps = list()
            for method in methods:
                inputfile = os.path.join(basedir,expr,tissue,method,"permnull_sb0.05/chr"+str(chrm)+"/rr.txt")
                print(inputfile)
                
                # prune snps
                snplist = tejaas(inputfile, chrm)
                pruned_snps2 = prune_rr(inputfile, chrm, myldict, isworst)
                
                # write pruned snps
                pruned_outfile = inputfile+".ld"
                if isworst:
                    pruned_outfile += ".worst"
                tejaas_write(pruned_snps2, pruned_outfile)
# Out:
# Loading CHR  1 - 14.5737 seconds
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas/permnull_sb0.05/chr1/rr.txt
# LD prunning took 210.1786768436432
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas_rand/permnull_sb0.05/chr1/rr.txt
# LD prunning took 206.39970469474792
# Loading CHR  2 - 17.1821 seconds
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas/permnull_sb0.05/chr2/rr.txt
# LD prunning took 226.17120265960693
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas_rand/permnull_sb0.05/chr2/rr.txt
# LD prunning took 223.6771969795227
# Loading CHR  3 - 16.4313 seconds
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas/permnull_sb0.05/chr3/rr.txt
# LD prunning took 210.0557951927185
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas_rand/permnull_sb0.05/chr3/rr.txt
# LD prunning took 205.20145964622498
# Loading CHR  4 - 19.3543 seconds
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas/permnull_sb0.05/chr4/rr.txt
# LD prunning took 232.79958868026733
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas_rand/permnull_sb0.05/chr4/rr.txt
# LD prunning took 228.28868222236633
# Loading CHR  5 - 14.9151 seconds
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas/permnull_sb0.05/chr5/rr.txt
# LD prunning took 185.69868111610413
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas_rand/permnull_sb0.05/chr5/rr.txt
# LD prunning took 188.5195758342743
# Loading CHR  6 - 21.4605 seconds
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas/permnull_sb0.05/chr6/rr.txt
# LD prunning took 357.6918170452118
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas_rand/permnull_sb0.05/chr6/rr.txt
# LD prunning took 353.89887523651123
# Loading CHR  7 - 13.2954 seconds
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas/permnull_sb0.05/chr7/rr.txt
# LD prunning took 178.6773943901062
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas_rand/permnull_sb0.05/chr7/rr.txt
# LD prunning took 176.70227646827698
# Loading CHR  8 - 12.3156 seconds
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas/permnull_sb0.05/chr8/rr.txt
# LD prunning took 180.42341375350952
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas_rand/permnull_sb0.05/chr8/rr.txt
# LD prunning took 171.7739269733429
# Loading CHR  9 - 7.97818 seconds
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas/permnull_sb0.05/chr9/rr.txt
# LD prunning took 123.28701949119568
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas_rand/permnull_sb0.05/chr9/rr.txt
# LD prunning took 123.67271876335144
# Loading CHR  10 - 10.6386 seconds
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas/permnull_sb0.05/chr10/rr.txt
# LD prunning took 153.48938083648682
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas_rand/permnull_sb0.05/chr10/rr.txt
# LD prunning took 150.2933201789856
# Loading CHR  11 - 11.7683 seconds
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas/permnull_sb0.05/chr11/rr.txt
# LD prunning took 148.47399735450745
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas_rand/permnull_sb0.05/chr11/rr.txt
# LD prunning took 146.94088768959045
# Loading CHR  12 - 9.79279 seconds
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas/permnull_sb0.05/chr12/rr.txt
# LD prunning took 136.3734610080719
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas_rand/permnull_sb0.05/chr12/rr.txt
# LD prunning took 136.20793533325195
# Loading CHR  13 - 8.60269 seconds
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas/permnull_sb0.05/chr13/rr.txt
# LD prunning took 111.42132043838501
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas_rand/permnull_sb0.05/chr13/rr.txt
# LD prunning took 107.71043372154236
# Loading CHR  14 - 6.38747 seconds
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas/permnull_sb0.05/chr14/rr.txt
# LD prunning took 92.40583491325378
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas_rand/permnull_sb0.05/chr14/rr.txt
# LD prunning took 90.4279375076294
# Loading CHR  15 - 5.51499 seconds
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas/permnull_sb0.05/chr15/rr.txt
# LD prunning took 81.15164232254028
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas_rand/permnull_sb0.05/chr15/rr.txt
# LD prunning took 80.03802275657654
# Loading CHR  16 - 5.08236 seconds
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas/permnull_sb0.05/chr16/rr.txt
# LD prunning took 96.8670117855072
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas_rand/permnull_sb0.05/chr16/rr.txt
# LD prunning took 95.82235288619995
# Loading CHR  17 - 6.86535 seconds
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas/permnull_sb0.05/chr17/rr.txt
# LD prunning took 79.36088395118713
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas_rand/permnull_sb0.05/chr17/rr.txt
# LD prunning took 77.50477743148804
# Loading CHR  18 - 5.4709 seconds
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas/permnull_sb0.05/chr18/rr.txt
# LD prunning took 83.29033136367798
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas_rand/permnull_sb0.05/chr18/rr.txt
# LD prunning took 81.88347697257996
# Loading CHR  19 - 4.54904 seconds
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas/permnull_sb0.05/chr19/rr.txt
# LD prunning took 77.85820293426514
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas_rand/permnull_sb0.05/chr19/rr.txt
# LD prunning took 76.544273853302
# Loading CHR  20 - 3.958 seconds
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas/permnull_sb0.05/chr20/rr.txt
# LD prunning took 66.08765721321106
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas_rand/permnull_sb0.05/chr20/rr.txt
# LD prunning took 66.11737823486328
# Loading CHR  21 - 2.73755 seconds
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas/permnull_sb0.05/chr21/rr.txt
# LD prunning took 46.453006744384766
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas_rand/permnull_sb0.05/chr21/rr.txt
# LD prunning took 45.94448518753052
# Loading CHR  22 - 2.22052 seconds
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas/permnull_sb0.05/chr22/rr.txt
# LD prunning took 42.73519420623779
# /cbscratch/franco/trans-eqtl/dev-pipeline/precorr/norm/gtex-ms/tejaas_rand/permnull_sb0.05/chr22/rr.txt
# LD prunning took 42.726202726364136
