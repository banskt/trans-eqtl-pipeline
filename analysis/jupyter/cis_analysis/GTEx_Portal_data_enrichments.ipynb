# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
import time
from statsmodels.distributions.empirical_distribution import ECDF
sys.path.append('../../')
sys.path.append('/usr/users/fsimone/tejaas')
from utils import readgtf
from utils import utils
import mpmath
import collections
from operator import attrgetter
import gzip

gene_info = readgtf.gencode_v12("/cbscratch/franco/datasets/GENCODE/gencode.v26.annotation.gtf.gz", trim=True)
gene_info_dict = collections.defaultdict(dict)
for gene in gene_info:
    gene_info_dict[gene.chrom][gene.ensembl_id] = gene.typ

mpmath.mp.dps = 50
def pvalue(x): return float(mpmath.log10(1 - 0.5 * (1 + mpmath.erf(x/mpmath.sqrt(2)))))

SNPRES_FIELDS = ['rsid', 'chrom', 'pos', 'logp', 'target', 'maf']
class SNPRes(collections.namedtuple('_SNPRes', SNPRES_FIELDS)):
    __slots__ = ()
    
CT_FIELDS = ['tissue', 'ncis', 'ntrans', 'ncistrans', 'randtrans', 'enrichment', 'pval']
class CisTrans(collections.namedtuple('_CisTrans', CT_FIELDS)):
    __slots__ = ()
    
CT_TYPE_FIELDS = ['tissue', 'genetype', 'hits', 'enrichment', 'pval', 'frac']
class CisTrans_type(collections.namedtuple('_CisTransType', CT_TYPE_FIELDS)):
    __slots__ = ()

def load_snp_maf(filepath, tissue):
    snp_maf_dict = collections.defaultdict(lambda:False)
    for chrm in np.arange(1,23):
        with open(filepath.format(tissue, chrm)) as instream:
            for line in instream:
                arr = line.strip().split("\t")
                snp_maf_dict[arr[0]] = float(arr[1])
    return snp_maf_dict

def tejaas(filepath, mafcutoff=0.01):
    res = list()
    with open(filepath, 'r') as mfile:
        next(mfile)
        for line in mfile:
            arr   = line.strip().split("\t")
            rsid  = arr[0]
            chrom = int(arr[1])
            pos   = int(arr[2])
            maf   = float(arr[3])
            if maf < mafcutoff or maf > (1-mafcutoff):
                continue
            q     = float(arr[4])
            mu    = float(arr[5])
            sigma = float(arr[6])
            p     = float(arr[7])
            if sigma == 0:
                continue
            logp  = np.log10(p) if p != 0 else pvalue( (q - mu) / sigma)
            res.append(SNPRes(rsid=rsid, chrom=chrom, pos=pos, logp=-logp, maf=maf, target=None))
    return res

def read_cis(filepath):
    res = list()
    if not os.path.exists(filepath) or os.stat(filepath).st_size == 0:
        print("File empty or does not exist")
        return res
    with gzip.open(filepath, 'r') as mfile:
        next(mfile)
        for line in mfile:
            arr  = line.decode().strip().split("\t")
            rsid = arr[0]
            if rsid.startswith("chrX"):
                continue
            pos = int(rsid.split("_")[1])
            chrom = int(rsid.split("_")[0][3:])
            gene = arr[1].split(":")[-1].split(".")[0]
            maf  = float(arr[5])
            logp = np.log10(float(arr[6]))
            res.append(SNPRes(rsid=rsid, chrom=chrom, pos=pos, logp=-logp, target=gene, maf=maf))
    return res
# Out:
# Mode v26

# %%
# Filter by allowed snps according to MAF
basepath = "/cbscratch/franco/trans-eqtl/dev-pipeline/gtex_v8_lncRNA_freeze/"
baseoutdir = os.path.join(basepath, "GTExPortal_eqtl_analysis")
if not os.path.exists(baseoutdir): os.makedirs(baseoutdir)

MAF = 0.01
title = "maf{:g}".format(MAF*100)
maffile = "/cbscratch/franco/datasets/gtex_v8/genotypes/snpMAFs/{:s}_snp_CHR{:d}.maf"
randompath = "/usr/users/fsimone/vcfs_{:.2f}/".format(MAF)

print(title, maffile, randompath)

outdir = os.path.join(baseoutdir, title)
if not os.path.exists(outdir): os.makedirs(outdir)

# NTOT_SNPS = 0
# snp_maf_dict = collections.defaultdict(lambda:False)
# with open(maffile) as instream:
#     for line in instream:
#         snp_maf_dict[line.rstrip().split()[1]] = True
#         NTOT_SNPS += 1
# print("Total Number of SNPs at MAF {:g}%: {:d}".format(MAF*100, NTOT_SNPS))
# Out:
# maf1 /usr/users/fsimone/vcfs_0.01/

# %%
# for a set of eQTLs, get me those targeting a specific type of targets
def cis_typespecific_eqtls(cistrans_target_eqtls, genetype_dict):
    cis_typespecific_eqtls = [x for x in cistrans_target_eqtls if genetype_dict[x.target]]
    
    uniq_cis_snps = list(set([x.rsid for x in cis_typespecific_eqtls]))
    unique_targets = list(set([x.target for x in cis_typespecific_eqtls]))
    return cis_typespecific_eqtls, uniq_cis_snps, unique_targets

# for a set of cis and trans-eQTLs, return the cis-trans ids and the cis-eQTLs with its targets
def cross_ref_cis_trans(trans_ids, cis_eqtls):
    cis_ids = list(set([x.rsid for x in cis_eqtls]))
    
    #Intersection between cis-eqtls (MatrixEQTL) and trans-eqtls (TEJAAS)
    cis_trans_eqtls_ids = list(set.intersection(set(trans_ids), set(cis_ids)))
    
    #set up a dict for fast look up later
    cis_trans_dict = dict()
    for x in cis_trans_eqtls_ids:
        cis_trans_dict[x] = True
    
    # List of cis-trans-eqtls with its target gene
    cis_target_eqtls = [x for x in cis_eqtls if cis_trans_dict.get(x.rsid, False)]

    return cis_trans_eqtls_ids, cis_target_eqtls

def crossref_trans_tejaas(transeqtls, cis_eqtls):
    trans_ids = [x.rsid for x in transeqtls]
    a, b = cross_ref_cis_trans(trans_ids, cis_eqtls)
    return a, b

def get_cistype_fractions(ciseqtls, valid_types, alltypes_dict):
    cistype_frac_dict = dict()
    NCIS = len(list(set([x.rsid for x in ciseqtls])))
    for gtype in valid_types:
        cishits = list()
        for ciseqtl in ciseqtls:
            if alltypes_dict[gtype][ciseqtl.target]:
                cishits.append(ciseqtl.rsid)
        NCIS_TYPE = len(list(set(cishits)))
        cistype_frac_dict[gtype] = NCIS_TYPE / NCIS
        # print("CIS_frac:", gtype, NCIS_TYPE, NCIS)
    return cistype_frac_dict

def sample_background_50000_simple(ciseqtls, randompath):
    randtrans = list()
    chroms    = [str(x) for x in np.arange(1,23)]
    for nid in ["{:03d}".format(x) for x in np.arange(1, 11)]:
        Nrand="50000"
        randomfile = randompath+"random_"+Nrand+"_"+nid

        rand_ids = list()
        for chrm in chroms:
            with open(os.path.join(randomfile, "chr{:s}.txt".format(chrm))) as ins:
                rand_ids += [line.rstrip() for line in ins]

        a, b = cross_ref_cis_trans(rand_ids, ciseqtls)
        randtrans.append( len(a) )
    return np.mean(randtrans)

def sample_background_50000(ciseqtls, randompath, valid_types = [], alltypes_dict = dict()):
    randtrans = list()
    res_dict  = collections.defaultdict(list)
    chroms    = [str(x) for x in np.arange(1,23)]
    for nid in ["{:03d}".format(x) for x in np.arange(1, 11)]:
        Nrand="50000"
        randomfile = randompath+"random_"+Nrand+"_"+nid

        rand_ids = list()
        for chrm in chroms:
            with open(os.path.join(randomfile, "chr{:s}.txt".format(chrm))) as ins:
                rand_ids += [line.rstrip() for line in ins]

        a, b = cross_ref_cis_trans(rand_ids, ciseqtls)
        randtrans.append( len(a) )
        if len(valid_types) > 0:
            for gtype in valid_types:
                cis_types_eqtls, uniq_cis_snps, uniq_targets = cis_typespecific_eqtls(b, alltypes_dict[gtype])
                # save only the number of uniq cistrans snps found for that gene type
                res_dict[gtype].append(len(uniq_cis_snps)) 
    return np.mean(randtrans), res_dict


def sample_binomial(n, p, NTIMES):
    array_n = list()
    for i in range(NTIMES):
        n_success = np.random.binomial(n, p)
        array_n.append(n_success)
    return array_n

# %%
# GENEINFO_FIELDS = ['name', 'ensembl_id', 'chrom', 'start', 'end', 'typ']
# class GeneInfo(collections.namedtuple('_GeneInfo', GENEINFO_FIELDS)):
#     __slots__ = ()
    
# def read_TFannot(infile):
#     TF_list = list()
#     with open(infile) as instream:
#         next(instream)
#         for line in instream:
#             arr = line.rstrip().split()
#             TF_list.append(GeneInfo(ensembl_id=arr[0], chrom=int(arr[1]), start=int(arr[2]), end=int(arr[3]), name=arr[4], typ="TF"))
#     return TF_list

# base_dir = "/cbscratch/franco/datasets"
# TF_annot = read_TFannot("../TF_annotation.txt")

# TF_dict = collections.defaultdict(dict)
# for g in TF_annot:
#     TF_dict[g.chrom][g.ensembl_id] = "TF"

# # Reformat genetype dict, we can add as many gene annotations as we want here
# alltypes_dict = collections.defaultdict(dict)
# genetypes = []
# for chrm in range(1,23):
#     gene_info_dict[chrm]
#     for k in gene_info_dict[chrm].keys():
#         genetype = gene_info_dict[chrm][k]
#         if genetype not in alltypes_dict:
#             alltypes_dict[genetype] = collections.defaultdict(lambda:False)
#             genetypes.append(genetype)
#         alltypes_dict[genetype][k] = True
#     # Add TF dictionary
#     for k in TF_dict[chrm].keys():
#         genetype = "TF"
#         if genetype not in alltypes_dict:
#             alltypes_dict[genetype] = collections.defaultdict(lambda:False)
#             genetypes.append(genetype)
#         alltypes_dict[genetype][k] = True

# %%
import json
json_file = "../gtex_v8_metadata.json"
with open(json_file) as instream:
    gtex_meta = json.load(instream)
    
tissue_file = "/usr/users/fsimone/trans-eqtl-pipeline/main/tissues.txt"
tissues, descriptions = utils.read_tissues(tissue_file)
tissue_names   = dict()
tissue_colors  = dict()
tissue_samples = dict()
for tshort, tfull in zip(tissues, descriptions):
    tissue_names[tshort] = tfull
    tissue_colors[tshort] = "#" + gtex_meta[tfull.replace(" ", "_")]["colorHex"]
    tissue_samples[tshort] = gtex_meta[tfull.replace(" ", "_")]["rnaSeqAndGenotypeSampleCount"]

# %%
# ###### Old enrichment calculation, everything in one go

# gtexportal_dir = "/cbscratch/franco/datasets/gtex_v8/expression/gtex_portal/eQTLs/GTEx_Analysis_v8_eQTL/"
# dataset = "gtex_v8"
# # meqtl_expr  = "tmm_cclm"
# tejaas_expr = "raw"
# K = 30
# pcutoff = 5e-8
# MIN_TRANS = 1
# MIN_CIS   = 1

# res_dict = dict()
# res_dict_cistype = collections.defaultdict(dict)
# res_dict_randomtype = collections.defaultdict(dict)
# for tissue in tissues:
#     gtex_t = "-".join([dataset, tissue])
    
#     snp_maf_dict = load_snp_maf(maffile, tissue)
    
#     tejaas_file = os.path.join(basepath, tejaas_expr, gtex_t, "tejaas", "permnull_sb0.1_knn{:d}".format(K), "trans_eqtls_{:g}.txt".format(pcutoff))
#     if not os.path.exists(tejaas_file):
#         print("{:s} has no trans-eqtl results".format(tissue))
#         continue
#     transeqtls = tejaas(tejaas_file)
#     transeqtls = [x for x in transeqtls if snp_maf_dict[x.rsid]]
    
#     if len(transeqtls) < MIN_TRANS:
#         print("{:s} has less than {:d} trans-eqtls".format(tissue, MIN_TRANS))
#         continue
    
#     signif_cisfile = os.path.join(gtexportal_dir, "{:s}.v8.signif_variant_gene_pairs.txt.gz".format(tissue_names[tissue].replace(" ", "_")))
#     if not os.path.exists(signif_cisfile) or os.stat(signif_cisfile).st_size == 0:
#         print("{:s} has no cis-file in GTEx!".format(tissue_names[tissue]))
#         continue
#     ciseqtls = read_cis(signif_cisfile)
#     cis_ids = list(set([x.rsid for x in ciseqtls]))
    
#     if len(ciseqtls) < MIN_CIS:
#         print("{:s} has less than {:d} cis-eqtls".format(tissue, MIN_CIS))
#         continue
    
#     cis_trans_eqtls_ids, cistrans_target_eqtls = crossref_trans_tejaas(transeqtls, ciseqtls)

    
#     valid_types = []
#     genetarget_counts = dict()
#     for genetype in genetypes:
#         cis_types_eqtls, uniq_cis_snps, unique_targets = cis_typespecific_eqtls(cistrans_target_eqtls, alltypes_dict[genetype])
#         if len(uniq_cis_snps) > 0:
#             # print(genetype, len(uniq_cis_snps), len(unique_targets))
#             valid_types.append(genetype)
#             genetarget_counts[genetype] = [cis_types_eqtls, uniq_cis_snps, unique_targets]
    
#     # randtrans: contains avg number of random snps that are cis-trans-eQTLs
#     # rand_res_dict: contains, for each genetype, a list with the number of those random cis-trans-eQTLs targeting that genetype
#     randtrans, rand_res_dict = sample_background_50000(ciseqtls, randompath, valid_types, alltypes_dict)
#     FRAC_CISTRANS = len(cis_trans_eqtls_ids) / len(transeqtls)
#     FRAC_RANDOM_GWCISTRANS = randtrans / 50000 
    
#     enrichment = FRAC_CISTRANS / FRAC_RANDOM_GWCISTRANS
   
#     ncis = len(cis_ids)
#     ntrans = len(transeqtls)
#     ncistrans = len(cis_trans_eqtls_ids)
    
#     randtrans1k_bin = sample_binomial(ntrans, FRAC_RANDOM_GWCISTRANS, 10000000)
#     num_null = np.array(randtrans1k_bin) /  ntrans

#     null_enrichments = num_null / FRAC_RANDOM_GWCISTRANS
#     ecdf = ECDF(null_enrichments)
#     pval = 1 - ecdf(enrichment)
    
    
#     res_dict[tissue] = CisTrans(tissue=tissue, ncis=ncis, ntrans=ntrans, 
#                                 ncistrans=ncistrans, randtrans=FRAC_RANDOM_GWCISTRANS,
#                                 enrichment=enrichment, pval=pval)
    
#     print(f"########## Tissue: {tissue} - {ntrans} trans-eqtls - {ncistrans} cis-trans-eqtls #########")
#     print(f"{tissue:>20}        Enrichment: {enrichment:>g} - pval: {pval:>g}")
    
#     cistype_fracs_dict = get_cistype_fractions(ciseqtls, valid_types, alltypes_dict)
    
#     for vt in valid_types:
#         # from the 50000 random SNPs, randtrans is the nº that are cistrans
#         FRAC_RANDOM_TYPE_NULL = np.mean(np.array(rand_res_dict[vt])) / 50000 #randtrans
#         FRAC_CIS_TYPE_NULL    = cistype_fracs_dict[vt]
#         uniq_snps_targettype  = len(genetarget_counts[vt][1]) # contains --> genetarget_counts[genetype] = [cis_types_eqtls, uniq_cis_snps, unique_targets]
#         FRAC_CISTYPE =  uniq_snps_targettype / ntrans
        
#         if FRAC_CIS_TYPE_NULL != 1.0:        
#             cis_type_enrichment    = FRAC_CISTYPE / FRAC_CIS_TYPE_NULL
#             # Calculate pvalue
#             randtrans1k_bin = sample_binomial(ntrans, FRAC_CIS_TYPE_NULL, 10000000)
#             num_null = np.array(randtrans1k_bin) /  ntrans
#             null_enrichments = num_null / FRAC_CIS_TYPE_NULL
#             ecdf = ECDF(null_enrichments)
#             cis_pval = 1 - ecdf(cis_type_enrichment)
#         else:
#             cis_pval = 1.0
#             cis_type_enrichment = 1.0
          
#         random_type_enrichment = FRAC_CISTYPE / FRAC_RANDOM_TYPE_NULL
#         # Calculate pvalue
#         randtrans1k_bin = sample_binomial(ntrans, FRAC_RANDOM_TYPE_NULL, 10000000)
#         num_null = np.array(randtrans1k_bin) /  ntrans
#         null_enrichments = num_null / FRAC_RANDOM_TYPE_NULL
#         ecdf = ECDF(null_enrichments)
#         random_pval = 1 - ecdf(random_type_enrichment)
                  
#         print(f"{vt:>20}    CIS Enrichment: {cis_type_enrichment:>g} - pval: {cis_pval:>g}")
#         print(f"{vt:>20} RANDOM Enrichment: {random_type_enrichment:>g} - pval: {random_pval:>g}")
    
#         res_dict_cistype[tissue][vt]    = CisTrans_type(tissue=tissue, genetype=vt,
#                                                         hits=uniq_snps_targettype,
#                                                         frac=FRAC_CIS_TYPE_NULL,
#                                                         enrichment=cis_type_enrichment, pval=cis_pval)
#         res_dict_randomtype[tissue][vt] = CisTrans_type(tissue=tissue, genetype=vt, 
#                                                         hits=uniq_snps_targettype,
#                                                         frac=FRAC_RANDOM_TYPE_NULL,
#                                                         enrichment=random_type_enrichment, pval=random_pval)

# %%
gtexportal_dir = "/cbscratch/franco/datasets/gtex_v8/expression/gtex_portal/eQTLs/GTEx_Analysis_v8_eQTL/"
dataset = "gtex_v8"
# meqtl_expr  = "tmm_cclm"
tejaas_expr = "raw"
K = 30
pcutoff = 5e-8
MIN_TRANS = 1
MIN_CIS   = 1

res_dict = dict()
res_target_dict = dict()
for tissue in tissues:
    gtex_t = "-".join([dataset, tissue])
    
    snp_maf_dict = load_snp_maf(maffile, tissue)
    
    tejaas_file = os.path.join(basepath, tejaas_expr, gtex_t, "tejaas", "permnull_sb0.1_knn{:d}".format(K), "trans_eqtls_{:g}.txt".format(pcutoff))
    if not os.path.exists(tejaas_file):
        print("{:s} has no trans-eqtl results".format(tissue))
        continue
    transeqtls = tejaas(tejaas_file)
    # transeqtls = [x for x in transeqtls if snp_maf_dict[x.rsid]]
    
    if len(transeqtls) < MIN_TRANS:
        print("{:s} has less than {:d} trans-eqtls".format(tissue, MIN_TRANS))
        continue
    
    signif_cisfile = os.path.join(gtexportal_dir, "{:s}.v8.signif_variant_gene_pairs.txt.gz".format(tissue_names[tissue].replace(" ", "_")))
    if not os.path.exists(signif_cisfile) or os.stat(signif_cisfile).st_size == 0:
        print("{:s} has no cis-file in GTEx!".format(tissue_names[tissue]))
        continue
    ciseqtls = read_cis(signif_cisfile)
    cis_ids = list(set([x.rsid for x in ciseqtls]))
    
    if len(ciseqtls) < MIN_CIS:
        print("{:s} has less than {:d} cis-eqtls".format(tissue, MIN_CIS))
        continue
    
    cis_trans_eqtls_ids, cistrans_target_eqtls = crossref_trans_tejaas(transeqtls, ciseqtls)
    
    randtrans = sample_background_50000_simple(ciseqtls, randompath)
    FRAC_CISTRANS = len(cis_trans_eqtls_ids) / len(transeqtls)
    FRAC_RANDOM_GWCISTRANS = randtrans / 50000 
    
    enrichment = FRAC_CISTRANS / FRAC_RANDOM_GWCISTRANS
   
    ncis = len(cis_ids)
    ntrans = len(transeqtls)
    ncistrans = len(cis_trans_eqtls_ids)
    
    randtrans1k_bin = sample_binomial(ntrans, FRAC_RANDOM_GWCISTRANS, 10000000)
    num_null = np.array(randtrans1k_bin) /  ntrans

    null_enrichments = num_null / FRAC_RANDOM_GWCISTRANS
    ecdf = ECDF(null_enrichments)
    pval = 1 - ecdf(enrichment)
    
    res_dict[tissue] = CisTrans(tissue=tissue, ncis=ncis, ntrans=ntrans, 
                                ncistrans=ncistrans, randtrans=FRAC_RANDOM_GWCISTRANS,
                                enrichment=enrichment, pval=pval)
    
    res_target_dict[tissue] = cistrans_target_eqtls
    
    print(f"########## Tissue: {tissue} - {ntrans} trans-eqtls - {ncistrans} cis-trans-eqtls #########")
    print(f"{tissue:>20}        Enrichment: {enrichment:>g} - pval: {pval:>g}")
# Out:
# ########## Tissue: as - 1280 trans-eqtls - 168 cis-trans-eqtls #########
#                   as        Enrichment: 1.12366 - pval: 0.0510985
# ########## Tissue: av - 671 trans-eqtls - 123 cis-trans-eqtls #########
#                   av        Enrichment: 2.16738 - pval: 0
# ########## Tissue: ag - 349 trans-eqtls - 119 cis-trans-eqtls #########
#                   ag        Enrichment: 7.95851 - pval: 0
# ########## Tissue: aa - 2615 trans-eqtls - 465 cis-trans-eqtls #########
#                   aa        Enrichment: 2.09058 - pval: 0
# ########## Tissue: ac - 3479 trans-eqtls - 136 cis-trans-eqtls #########
#                   ac        Enrichment: 1.20179 - pval: 0.0147335
# ########## Tissue: at - 920 trans-eqtls - 120 cis-trans-eqtls #########
#                   at        Enrichment: 1.09808 - pval: 0.127324
# ########## Tissue: bam - 2598 trans-eqtls - 29 cis-trans-eqtls #########
#                  bam        Enrichment: 0.692029 - pval: 0.97799
# ########## Tissue: ban - 2064 trans-eqtls - 62 cis-trans-eqtls #########
#                  ban        Enrichment: 1.20647 - pval: 0.0617691
# ########## Tissue: bca - 18 trans-eqtls - 0 cis-trans-eqtls #########
#                  bca        Enrichment: 0 - pval: 0.538717
# ########## Tissue: bceh - 157 trans-eqtls - 0 cis-trans-eqtls #########
#                 bceh        Enrichment: 0 - pval: 0.999669
# ########## Tissue: bce - 49 trans-eqtls - 2 cis-trans-eqtls #########
#                  bce        Enrichment: 0.6592 - pval: 0.59189
# ########## Tissue: bco - 76 trans-eqtls - 0 cis-trans-eqtls #########
#                  bco        Enrichment: 0 - pval: 0.977044
# ########## Tissue: bfr - 33 trans-eqtls - 0 cis-trans-eqtls #########
#                  bfr        Enrichment: 0 - pval: 0.694753
# ########## Tissue: bhi - 108 trans-eqtls - 0 cis-trans-eqtls #########
#                  bhi        Enrichment: 0 - pval: 0.94045
# ########## Tissue: bhy - 207 trans-eqtls - 0 cis-trans-eqtls #########
#                  bhy        Enrichment: 0 - pval: 0.995894
# ########## Tissue: bnu - 663 trans-eqtls - 10 cis-trans-eqtls #########
#                  bnu        Enrichment: 0.367232 - pval: 0.999889
# ########## Tissue: bpu - 7 trans-eqtls - 0 cis-trans-eqtls #########
#                  bpu        Enrichment: 0 - pval: 0.20715
# ########## Tissue: bsp - 86 trans-eqtls - 0 cis-trans-eqtls #########
#                  bsp        Enrichment: 0 - pval: 0.82172
# ########## Tissue: bsu - 40 trans-eqtls - 0 cis-trans-eqtls #########
#                  bsu        Enrichment: 0 - pval: 0.404157
# ########## Tissue: br - 841 trans-eqtls - 84 cis-trans-eqtls #########
#                   br        Enrichment: 1.48222 - pval: 0.0001542
# ########## Tissue: ebv - 514 trans-eqtls - 20 cis-trans-eqtls #########
#                  ebv        Enrichment: 1.84971 - pval: 0.0035087
# ########## Tissue: fib - 390 trans-eqtls - 54 cis-trans-eqtls #########
#                  fib        Enrichment: 1.13278 - pval: 0.145966
# ########## Tissue: cols - 138 trans-eqtls - 37 cis-trans-eqtls #########
#                 cols        Enrichment: 4.24422 - pval: 0
# ########## Tissue: colt - 2198 trans-eqtls - 439 cis-trans-eqtls #########
#                 colt        Enrichment: 2.83429 - pval: 0
# ########## Tissue: esog - 30 trans-eqtls - 2 cis-trans-eqtls #########
#                 esog        Enrichment: 1.0039 - pval: 0.321018
# ########## Tissue: esom - 90 trans-eqtls - 85 cis-trans-eqtls #########
#                 esom        Enrichment: 8.8924 - pval: 0
# ########## Tissue: esomu - 35 trans-eqtls - 2 cis-trans-eqtls #########
#                esomu        Enrichment: 0.553324 - pval: 0.715315
# haa has less than 1 trans-eqtls
# ########## Tissue: hlv - 437 trans-eqtls - 51 cis-trans-eqtls #########
#                  hlv        Enrichment: 1.84706 - pval: 9.4e-06
# ########## Tissue: kc - 17 trans-eqtls - 0 cis-trans-eqtls #########
#                   kc        Enrichment: 0 - pval: 0.0763555
# ########## Tissue: liv - 83 trans-eqtls - 0 cis-trans-eqtls #########
#                  liv        Enrichment: 0 - pval: 0.905589
# ########## Tissue: lu - 907 trans-eqtls - 220 cis-trans-eqtls #########
#                   lu        Enrichment: 2.53711 - pval: 0
# ########## Tissue: msg - 4 trans-eqtls - 0 cis-trans-eqtls #########
#                  msg        Enrichment: 0 - pval: 0.0771449
# ########## Tissue: ms - 4827 trans-eqtls - 849 cis-trans-eqtls #########
#                   ms        Enrichment: 1.59438 - pval: 0
# ########## Tissue: nt - 1573 trans-eqtls - 175 cis-trans-eqtls #########
#                   nt        Enrichment: 0.825168 - pval: 0.997103
# pan has less than 1 trans-eqtls
# ########## Tissue: pit - 11 trans-eqtls - 0 cis-trans-eqtls #########
#                  pit        Enrichment: 0 - pval: 0.43693
# ########## Tissue: snse - 1411 trans-eqtls - 306 cis-trans-eqtls #########
#                 snse        Enrichment: 1.97515 - pval: 0
# ########## Tissue: sse - 642 trans-eqtls - 237 cis-trans-eqtls #########
#                  sse        Enrichment: 2.85815 - pval: 0
# ########## Tissue: si - 133 trans-eqtls - 8 cis-trans-eqtls #########
#                   si        Enrichment: 2.08667 - pval: 0.0153378
# ########## Tissue: spl - 5 trans-eqtls - 0 cis-trans-eqtls #########
#                  spl        Enrichment: 0 - pval: 0.250239
# ########## Tissue: sto - 453 trans-eqtls - 55 cis-trans-eqtls #########
#                  sto        Enrichment: 2.34796 - pval: 0
# ########## Tissue: thy - 2658 trans-eqtls - 323 cis-trans-eqtls #########
#                  thy        Enrichment: 0.878034 - pval: 0.994243
# wb has less than 1 trans-eqtls
# ########## Tissue: ov - 178 trans-eqtls - 8 cis-trans-eqtls #########
#                   ov        Enrichment: 1.77531 - pval: 0.038577
# ########## Tissue: pro - 2101 trans-eqtls - 100 cis-trans-eqtls #########
#                  pro        Enrichment: 1.31722 - pval: 0.0029007
# ########## Tissue: tes - 2344 trans-eqtls - 356 cis-trans-eqtls #########
#                  tes        Enrichment: 1.32065 - pval: 0
# ########## Tissue: ut - 3506 trans-eqtls - 66 cis-trans-eqtls #########
#                   ut        Enrichment: 1.29327 - pval: 0.0176398
# va has less than 1 trans-eqtls
# Bladder has no cis-file in GTEx!

# %%
res_target_dict
# Out:
# {'as': [SNPRes(rsid='chr1_115556462_T_C_b38', chrom=1, pos=115556462, logp=9.320521226679793, target='ENSG00000173218', maf=0.302926),
#   SNPRes(rsid='chr1_115577519_C_A_b38', chrom=1, pos=115577519, logp=9.320521226679793, target='ENSG00000173218', maf=0.302926),
#   SNPRes(rsid='chr1_115582269_C_T_b38', chrom=1, pos=115582269, logp=9.320521226679793, target='ENSG00000173218', maf=0.302926),
#   SNPRes(rsid='chr1_115594189_C_T_b38', chrom=1, pos=115594189, logp=11.244205153312071, target='ENSG00000173218', maf=0.312392),
#   SNPRes(rsid='chr2_46536234_A_G_b38', chrom=2, pos=46536234, logp=4.139108246749908, target='ENSG00000279254', maf=0.0378658),
#   SNPRes(rsid='chr2_46659694_T_G_b38', chrom=2, pos=46659694, logp=5.518530139364184, target='ENSG00000279254', maf=0.0481928),
#   SNPRes(rsid='chr2_84206517_G_T_b38', chrom=2, pos=84206517, logp=4.9214018236123485, target='ENSG00000115423', maf=0.276248),
#   SNPRes(rsid='chr2_84206772_G_A_b38', chrom=2, pos=84206772, logp=5.098254060581719, target='ENSG00000115423', maf=0.285714),
#   SNPRes(rsid='chr2_84211610_C_T_b38', chrom=2, pos=84211610, logp=4.9214018236123485, target='ENSG00000115423', maf=0.276248),
#   SNPRes(rsid='chr2_84213179_T_G_b38', chrom=2, pos=84213179, logp=4.69702222500169, target='ENSG00000115423', maf=0.277108),
#   SNPRes(rsid='chr2_84213880_T_C_b38', chrom=2, pos=84213880, logp=4.69702222500169, target='ENSG00000115423', maf=0.277108),
#   SNPRes(rsid='chr2_84214222_G_A_b38', chrom=2, pos=84214222, logp=4.9333535978428005, target='ENSG00000115423', maf=0.277969),
#   SNPRes(rsid='chr2_84217319_A_G_b38', chrom=2, pos=84217319, logp=4.69702222500169, target='ENSG00000115423', maf=0.277108),
#   SNPRes(rsid='chr2_84217551_A_C_b38', chrom=2, pos=84217551, logp=4.69702222500169, target='ENSG00000115423', maf=0.277108),
#   SNPRes(rsid='chr2_84221215_T_C_b38', chrom=2, pos=84221215, logp=5.165679774307058, target='ENSG00000115423', maf=0.284854),
#   SNPRes(rsid='chr2_84225011_G_A_b38', chrom=2, pos=84225011, logp=5.123191181964685, target='ENSG00000115423', maf=0.283133),
#   SNPRes(rsid='chr2_84225086_C_A_b38', chrom=2, pos=84225086, logp=5.165679774307058, target='ENSG00000115423', maf=0.284854),
#   SNPRes(rsid='chr2_84232904_A_C_b38', chrom=2, pos=84232904, logp=5.262859857603598, target='ENSG00000115423', maf=0.283993),
#   SNPRes(rsid='chr2_84237103_A_G_b38', chrom=2, pos=84237103, logp=5.725052822127251, target='ENSG00000115423', maf=0.27883),
#   SNPRes(rsid='chr2_84243387_T_C_b38', chrom=2, pos=84243387, logp=5.540060464918941, target='ENSG00000115423', maf=0.27969),
#   SNPRes(rsid='chr2_84247081_T_C_b38', chrom=2, pos=84247081, logp=5.675197114926462, target='ENSG00000115423', maf=0.277969),
#   SNPRes(rsid='chr2_84247615_C_A_b38', chrom=2, pos=84247615, logp=5.595907267550753, target='ENSG00000115423', maf=0.277108),
#   SNPRes(rsid='chr2_84248096_T_G_b38', chrom=2, pos=84248096, logp=5.595907267550753, target='ENSG00000115423', maf=0.277108),
#   SNPRes(rsid='chr2_84248654_C_T_b38', chrom=2, pos=84248654, logp=5.595907267550753, target='ENSG00000115423', maf=0.277108),
#   SNPRes(rsid='chr2_84249811_A_G_b38', chrom=2, pos=84249811, logp=5.863710771423283, target='ENSG00000115423', maf=0.277969),
#   SNPRes(rsid='chr2_84250832_T_C_b38', chrom=2, pos=84250832, logp=5.947367609927441, target='ENSG00000115423', maf=0.27883),
#   SNPRes(rsid='chr2_84255772_T_C_b38', chrom=2, pos=84255772, logp=5.863710771423283, target='ENSG00000115423', maf=0.277969),
#   SNPRes(rsid='chr2_84262138_T_C_b38', chrom=2, pos=84262138, logp=5.675197114926462, target='ENSG00000115423', maf=0.277969),
#   SNPRes(rsid='chr2_84263152_C_T_b38', chrom=2, pos=84263152, logp=5.947367609927441, target='ENSG00000115423', maf=0.27883),
#   SNPRes(rsid='chr2_84278845_G_A_b38', chrom=2, pos=84278845, logp=5.947367609927441, target='ENSG00000115423', maf=0.27883),
#   SNPRes(rsid='chr2_84292539_G_T_b38', chrom=2, pos=84292539, logp=5.064791099209451, target='ENSG00000115423', maf=0.300344),
#   SNPRes(rsid='chr2_84295323_G_A_b38', chrom=2, pos=84295323, logp=6.484824501578756, target='ENSG00000115423', maf=0.301205),
#   SNPRes(rsid='chr2_84301632_T_C_b38', chrom=2, pos=84301632, logp=5.806293947809959, target='ENSG00000115423', maf=0.310671),
#   SNPRes(rsid='chr2_84305680_G_A_b38', chrom=2, pos=84305680, logp=5.8462034221239, target='ENSG00000115423', maf=0.301205),
#   SNPRes(rsid='chr2_84306251_T_C_b38', chrom=2, pos=84306251, logp=5.8462034221239, target='ENSG00000115423', maf=0.301205),
#   SNPRes(rsid='chr2_84307204_C_A_b38', chrom=2, pos=84307204, logp=5.739213331345024, target='ENSG00000115423', maf=0.299484),
#   SNPRes(rsid='chr2_84307854_C_T_b38', chrom=2, pos=84307854, logp=5.444014891429652, target='ENSG00000115423', maf=0.311532),
#   SNPRes(rsid='chr2_84308549_A_G_b38', chrom=2, pos=84308549, logp=5.642255674819625, target='ENSG00000115423', maf=0.311532),
#   SNPRes(rsid='chr2_84308773_G_A_b38', chrom=2, pos=84308773, logp=5.594513622493918, target='ENSG00000115423', maf=0.310671),
#   SNPRes(rsid='chr2_84310850_G_A_b38', chrom=2, pos=84310850, logp=5.966230555042972, target='ENSG00000115423', maf=0.315835),
#   SNPRes(rsid='chr2_84314440_C_T_b38', chrom=2, pos=84314440, logp=5.9037123424029305, target='ENSG00000115423', maf=0.314974),
#   SNPRes(rsid='chr2_84315354_T_C_b38', chrom=2, pos=84315354, logp=6.04370619950276, target='ENSG00000115423', maf=0.316695),
#   SNPRes(rsid='chr2_84317508_T_C_b38', chrom=2, pos=84317508, logp=5.7729132362908775, target='ENSG00000115423', maf=0.302065),
#   SNPRes(rsid='chr2_84317765_T_C_b38', chrom=2, pos=84317765, logp=5.7729132362908775, target='ENSG00000115423', maf=0.302065),
#   SNPRes(rsid='chr2_84317769_A_G_b38', chrom=2, pos=84317769, logp=5.749916828493535, target='ENSG00000115423', maf=0.314974),
#   SNPRes(rsid='chr2_84317935_C_T_b38', chrom=2, pos=84317935, logp=5.7729132362908775, target='ENSG00000115423', maf=0.302065),
#   SNPRes(rsid='chr2_84310850_G_A_b38', chrom=2, pos=84310850, logp=3.8968259493459043, target='ENSG00000186854', maf=0.315835),
#   SNPRes(rsid='chr2_84314440_C_T_b38', chrom=2, pos=84314440, logp=3.6983363968134637, target='ENSG00000186854', maf=0.314974),
#   SNPRes(rsid='chr2_84315354_T_C_b38', chrom=2, pos=84315354, logp=3.755690710427956, target='ENSG00000186854', maf=0.316695),
#   SNPRes(rsid='chr2_84317508_T_C_b38', chrom=2, pos=84317508, logp=3.98235740561338, target='ENSG00000186854', maf=0.302065),
#   SNPRes(rsid='chr2_84317765_T_C_b38', chrom=2, pos=84317765, logp=3.98235740561338, target='ENSG00000186854', maf=0.302065),
#   SNPRes(rsid='chr2_84317935_C_T_b38', chrom=2, pos=84317935, logp=3.98235740561338, target='ENSG00000186854', maf=0.302065),
#   SNPRes(rsid='chr2_131474964_C_T_b38', chrom=2, pos=131474964, logp=7.245827558584839, target='ENSG00000173272', maf=0.166954),
#   SNPRes(rsid='chr2_131475952_G_A_b38', chrom=2, pos=131475952, logp=7.486104843189927, target='ENSG00000173272', maf=0.167814),
#   SNPRes(rsid='chr2_131474964_C_T_b38', chrom=2, pos=131474964, logp=66.61348854977716, target='ENSG00000152117', maf=0.166954),
#   SNPRes(rsid='chr2_131475952_G_A_b38', chrom=2, pos=131475952, logp=70.00806810490091, target='ENSG00000152117', maf=0.167814),
#   SNPRes(rsid='chr2_131474964_C_T_b38', chrom=2, pos=131474964, logp=6.31890536175205, target='ENSG00000163040', maf=0.166954),
#   SNPRes(rsid='chr2_131475952_G_A_b38', chrom=2, pos=131475952, logp=6.098048813451035, target='ENSG00000163040', maf=0.167814),
#   SNPRes(rsid='chr3_48781943_G_T_b38', chrom=3, pos=48781943, logp=4.633976964568982, target='ENSG00000068745', maf=0.0791738),
#   SNPRes(rsid='chr3_48781943_G_T_b38', chrom=3, pos=48781943, logp=6.490523272999005, target='ENSG00000178252', maf=0.0791738),
#   SNPRes(rsid='chr3_50143000_T_C_b38', chrom=3, pos=50143000, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50149252_C_T_b38', chrom=3, pos=50149252, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50150204_T_C_b38', chrom=3, pos=50150204, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50155950_C_T_b38', chrom=3, pos=50155950, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50159659_C_T_b38', chrom=3, pos=50159659, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50162916_G_A_b38', chrom=3, pos=50162916, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50164880_G_A_b38', chrom=3, pos=50164880, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50165290_A_G_b38', chrom=3, pos=50165290, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50169777_A_C_b38', chrom=3, pos=50169777, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50172179_T_C_b38', chrom=3, pos=50172179, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50186941_T_C_b38', chrom=3, pos=50186941, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50200943_G_A_b38', chrom=3, pos=50200943, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50202031_C_T_b38', chrom=3, pos=50202031, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50204188_G_A_b38', chrom=3, pos=50204188, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50212067_G_A_b38', chrom=3, pos=50212067, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50216962_A_C_b38', chrom=3, pos=50216962, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50229696_C_A_b38', chrom=3, pos=50229696, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50235381_G_A_b38', chrom=3, pos=50235381, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50241181_G_A_b38', chrom=3, pos=50241181, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50244324_C_T_b38', chrom=3, pos=50244324, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50249828_T_G_b38', chrom=3, pos=50249828, logp=4.329049454414102, target='ENSG00000186792', maf=0.106713),
#   SNPRes(rsid='chr3_50250119_C_T_b38', chrom=3, pos=50250119, logp=4.007759835051512, target='ENSG00000186792', maf=0.100688),
#   SNPRes(rsid='chr3_50253398_A_G_b38', chrom=3, pos=50253398, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50254761_G_T_b38', chrom=3, pos=50254761, logp=4.6315457533309505, target='ENSG00000186792', maf=0.0929432),
#   SNPRes(rsid='chr3_50257119_A_G_b38', chrom=3, pos=50257119, logp=4.329049454414102, target='ENSG00000186792', maf=0.106713),
#   SNPRes(rsid='chr3_50261708_C_A_b38', chrom=3, pos=50261708, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50269619_C_T_b38', chrom=3, pos=50269619, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50271693_A_G_b38', chrom=3, pos=50271693, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50285741_C_T_b38', chrom=3, pos=50285741, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50303895_C_T_b38', chrom=3, pos=50303895, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50305190_C_T_b38', chrom=3, pos=50305190, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50314167_C_T_b38', chrom=3, pos=50314167, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50323371_G_A_b38', chrom=3, pos=50323371, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50336404_C_A_b38', chrom=3, pos=50336404, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50350079_A_C_b38', chrom=3, pos=50350079, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50361458_A_G_b38', chrom=3, pos=50361458, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50364410_G_A_b38', chrom=3, pos=50364410, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50372610_G_A_b38', chrom=3, pos=50372610, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#   SNPRes(rsid='chr3_50376973_C_T_b38', chrom=3, pos=50376973, logp=3.332948838563166, target='ENSG00000186792', maf=0.0172117),
#   SNPRes(rsid='chr3_50380247_C_T_b38', chrom=3, pos=50380247, logp=3.086029406189079, target='ENSG00000186792', maf=0.0189329),
#   SNPRes(rsid='chr3_138933102_G_A_b38', chrom=3, pos=138933102, logp=3.6597403507538284, target='ENSG00000280399', maf=0.0180723),
#   SNPRes(rsid='chr3_138934554_C_T_b38', chrom=3, pos=138934554, logp=3.6597403507538284, target='ENSG00000280399', maf=0.0180723),
#   SNPRes(rsid='chr4_139367077_A_G_b38', chrom=4, pos=139367077, logp=10.875851311786716, target='ENSG00000109390', maf=0.301205),
#   SNPRes(rsid='chr5_33964105_T_G_b38', chrom=5, pos=33964105, logp=4.038626372405199, target='ENSG00000242110', maf=0.139415),
#   SNPRes(rsid='chr5_39699948_G_T_b38', chrom=5, pos=39699948, logp=3.941107283891963, target='ENSG00000250048', maf=0.0817556),
#   SNPRes(rsid='chr5_39700154_C_T_b38', chrom=5, pos=39700154, logp=3.941107283891963, target='ENSG00000250048', maf=0.0817556),
#   SNPRes(rsid='chr5_39700938_G_T_b38', chrom=5, pos=39700938, logp=3.941107283891963, target='ENSG00000250048', maf=0.0817556),
#   SNPRes(rsid='chr5_39701279_G_T_b38', chrom=5, pos=39701279, logp=3.941107283891963, target='ENSG00000250048', maf=0.0817556),
#   SNPRes(rsid='chr5_39702176_G_A_b38', chrom=5, pos=39702176, logp=3.941107283891963, target='ENSG00000250048', maf=0.0817556),
#   SNPRes(rsid='chr5_39704976_C_T_b38', chrom=5, pos=39704976, logp=3.941107283891963, target='ENSG00000250048', maf=0.0817556),
#   SNPRes(rsid='chr5_39706810_T_C_b38', chrom=5, pos=39706810, logp=3.941107283891963, target='ENSG00000250048', maf=0.0817556),
#   SNPRes(rsid='chr5_39706831_A_G_b38', chrom=5, pos=39706831, logp=3.941107283891963, target='ENSG00000250048', maf=0.0817556),
#   SNPRes(rsid='chr5_39707481_T_C_b38', chrom=5, pos=39707481, logp=3.941107283891963, target='ENSG00000250048', maf=0.0817556),
#   SNPRes(rsid='chr5_132743502_A_G_b38', chrom=5, pos=132743502, logp=21.03965672302108, target='ENSG00000131437', maf=0.185886),
#   SNPRes(rsid='chr5_132746205_A_G_b38', chrom=5, pos=132746205, logp=21.03965672302108, target='ENSG00000131437', maf=0.185886),
#   SNPRes(rsid='chr5_132749264_G_A_b38', chrom=5, pos=132749264, logp=19.62475350899281, target='ENSG00000131437', maf=0.185886),
#   SNPRes(rsid='chr5_132755136_T_C_b38', chrom=5, pos=132755136, logp=18.122134162596875, target='ENSG00000131437', maf=0.212565),
#   SNPRes(rsid='chr5_132789134_T_C_b38', chrom=5, pos=132789134, logp=16.658915822269975, target='ENSG00000131437', maf=0.207401),
#   SNPRes(rsid='chr6_143079531_A_G_b38', chrom=6, pos=143079531, logp=5.841939206063395, target='ENSG00000227192', maf=0.133391),
#   SNPRes(rsid='chr6_143079531_A_G_b38', chrom=6, pos=143079531, logp=4.52203414050442, target='ENSG00000146416', maf=0.133391),
#   SNPRes(rsid='chr6_169617611_G_A_b38', chrom=6, pos=169617611, logp=4.091889922977998, target='ENSG00000130023', maf=0.179002),
#   SNPRes(rsid='chr6_169621385_C_T_b38', chrom=6, pos=169621385, logp=4.091889922977998, target='ENSG00000130023', maf=0.179002),
#   SNPRes(rsid='chr10_18465566_T_C_b38', chrom=10, pos=18465566, logp=3.9028364330450604, target='ENSG00000241058', maf=0.244406),
#   SNPRes(rsid='chr10_89494542_T_C_b38', chrom=10, pos=89494542, logp=3.6830970284107063, target='ENSG00000138134', maf=0.0860585),
#   SNPRes(rsid='chr10_89494542_T_C_b38', chrom=10, pos=89494542, logp=4.423158980304397, target='ENSG00000152779', maf=0.0860585),
#   SNPRes(rsid='chr10_89499900_C_T_b38', chrom=10, pos=89499900, logp=4.00347037854562, target='ENSG00000152779', maf=0.0860585),
#   SNPRes(rsid='chr11_2301799_T_C_b38', chrom=11, pos=2301799, logp=8.974497517596776, target='ENSG00000110665', maf=0.0817556),
#   SNPRes(rsid='chr11_2302811_A_G_b38', chrom=11, pos=2302811, logp=8.70774614443735, target='ENSG00000110665', maf=0.0791738),
#   SNPRes(rsid='chr11_2307463_C_T_b38', chrom=11, pos=2307463, logp=8.773869437900192, target='ENSG00000110665', maf=0.0774527),
#   SNPRes(rsid='chr11_2307477_A_G_b38', chrom=11, pos=2307477, logp=8.745046094350839, target='ENSG00000110665', maf=0.0791738),
#   SNPRes(rsid='chr11_2307848_T_G_b38', chrom=11, pos=2307848, logp=8.357013453108634, target='ENSG00000110665', maf=0.0774527),
#   SNPRes(rsid='chr11_2307889_C_T_b38', chrom=11, pos=2307889, logp=8.357013453108634, target='ENSG00000110665', maf=0.0774527),
#   SNPRes(rsid='chr11_2309170_G_A_b38', chrom=11, pos=2309170, logp=7.457335129902486, target='ENSG00000110665', maf=0.0774527),
#   SNPRes(rsid='chr11_2309249_G_A_b38', chrom=11, pos=2309249, logp=7.457335129902486, target='ENSG00000110665', maf=0.0774527),
#   SNPRes(rsid='chr11_2309700_C_T_b38', chrom=11, pos=2309700, logp=7.457335129902486, target='ENSG00000110665', maf=0.0774527),
#   SNPRes(rsid='chr11_2309747_T_C_b38', chrom=11, pos=2309747, logp=7.457335129902486, target='ENSG00000110665', maf=0.0774527),
#   SNPRes(rsid='chr11_2309820_C_A_b38', chrom=11, pos=2309820, logp=7.457335129902486, target='ENSG00000110665', maf=0.0774527),
#   SNPRes(rsid='chr11_2309823_A_G_b38', chrom=11, pos=2309823, logp=7.457335129902486, target='ENSG00000110665', maf=0.0774527),
#   SNPRes(rsid='chr11_2309866_G_A_b38', chrom=11, pos=2309866, logp=7.457335129902486, target='ENSG00000110665', maf=0.0774527),
#   SNPRes(rsid='chr11_2309984_A_C_b38', chrom=11, pos=2309984, logp=7.457335129902486, target='ENSG00000110665', maf=0.0774527),
#   SNPRes(rsid='chr11_2917931_G_A_b38', chrom=11, pos=2917931, logp=11.013271697353563, target='ENSG00000110628', maf=0.0963855),
#   SNPRes(rsid='chr11_2918475_G_A_b38', chrom=11, pos=2918475, logp=11.013271697353563, target='ENSG00000110628', maf=0.0963855),
#   SNPRes(rsid='chr11_120213513_C_T_b38', chrom=11, pos=120213513, logp=5.160032625788768, target='ENSG00000137699', maf=0.0370052),
#   SNPRes(rsid='chr11_120213801_T_C_b38', chrom=11, pos=120213801, logp=5.160032625788768, target='ENSG00000137699', maf=0.0370052),
#   SNPRes(rsid='chr11_120226466_G_A_b38', chrom=11, pos=120226466, logp=4.262823265809409, target='ENSG00000137699', maf=0.0421687),
#   SNPRes(rsid='chr12_37415519_A_G_b38', chrom=12, pos=37415519, logp=6.3909106048999105, target='ENSG00000175548', maf=0.0490534),
#   SNPRes(rsid='chr13_49651403_C_T_b38', chrom=13, pos=49651403, logp=4.514782704373369, target='ENSG00000274270', maf=0.0309811),
#   SNPRes(rsid='chr13_49653360_T_G_b38', chrom=13, pos=49653360, logp=4.514782704373369, target='ENSG00000274270', maf=0.0309811),
#   SNPRes(rsid='chr13_49746825_T_C_b38', chrom=13, pos=49746825, logp=5.289610122308776, target='ENSG00000274270', maf=0.035284),
#   SNPRes(rsid='chr14_94121934_G_A_b38', chrom=14, pos=94121934, logp=4.0581364049365805, target='ENSG00000133937', maf=0.0567986),
#   SNPRes(rsid='chr15_40284286_C_T_b38', chrom=15, pos=40284286, logp=3.912009291333857, target='ENSG00000137843', maf=0.0172117),
#   SNPRes(rsid='chr15_78756895_C_T_b38', chrom=15, pos=78756895, logp=5.249133055268177, target='ENSG00000261143', maf=0.260757),
#   SNPRes(rsid='chr15_78758922_C_T_b38', chrom=15, pos=78758922, logp=5.249133055268177, target='ENSG00000261143', maf=0.260757),
#   SNPRes(rsid='chr15_78759111_G_A_b38', chrom=15, pos=78759111, logp=5.249133055268177, target='ENSG00000261143', maf=0.260757),
#   SNPRes(rsid='chr16_10860932_C_T_b38', chrom=16, pos=10860932, logp=5.02601825788597, target='ENSG00000179583', maf=0.345955),
#   SNPRes(rsid='chr16_21979439_T_C_b38', chrom=16, pos=21979439, logp=8.457643964203715, target='ENSG00000260306', maf=0.315835),
#   SNPRes(rsid='chr16_21979439_T_C_b38', chrom=16, pos=21979439, logp=3.6426369693848573, target='ENSG00000248124', maf=0.315835),
#   SNPRes(rsid='chr16_29605798_A_C_b38', chrom=16, pos=29605798, logp=6.754687252358704, target='ENSG00000169203', maf=0.373494),
#   SNPRes(rsid='chr16_29605798_A_C_b38', chrom=16, pos=29605798, logp=5.416242558935648, target='ENSG00000205534', maf=0.373494),
#   SNPRes(rsid='chr16_29605798_A_C_b38', chrom=16, pos=29605798, logp=5.623328165437885, target='ENSG00000279583', maf=0.373494),
#   SNPRes(rsid='chr16_71531679_A_G_b38', chrom=16, pos=71531679, logp=5.8204884231486425, target='ENSG00000140832', maf=0.276248),
#   SNPRes(rsid='chr16_71531679_A_G_b38', chrom=16, pos=71531679, logp=4.263182953721987, target='ENSG00000166747', maf=0.276248),
#   SNPRes(rsid='chr17_19020505_G_A_b38', chrom=17, pos=19020505, logp=5.232675645498686, target='ENSG00000279825', maf=0.309811),
#   SNPRes(rsid='chr17_19238913_C_T_b38', chrom=17, pos=19238913, logp=11.38712187983071, target='ENSG00000279825', maf=0.247849),
#   SNPRes(rsid='chr17_19268883_T_G_b38', chrom=17, pos=19268883, logp=6.948639066216026, target='ENSG00000279825', maf=0.296041),
#   SNPRes(rsid='chr17_19269192_A_G_b38', chrom=17, pos=19269192, logp=6.948639066216026, target='ENSG00000279825', maf=0.296041),
#   SNPRes(rsid='chr17_19271561_T_C_b38', chrom=17, pos=19271561, logp=7.0582476355542, target='ENSG00000279825', maf=0.297762),
#   SNPRes(rsid='chr17_19272004_A_G_b38', chrom=17, pos=19272004, logp=6.948639066216026, target='ENSG00000279825', maf=0.296041),
#   SNPRes(rsid='chr17_19301550_T_C_b38', chrom=17, pos=19301550, logp=6.948639066216026, target='ENSG00000279825', maf=0.296041),
#   SNPRes(rsid='chr17_19313948_C_T_b38', chrom=17, pos=19313948, logp=6.948639066216026, target='ENSG00000279825', maf=0.296041),
#   SNPRes(rsid='chr17_19317353_G_A_b38', chrom=17, pos=19317353, logp=7.289413883772641, target='ENSG00000279825', maf=0.296902),
#   SNPRes(rsid='chr17_19336119_C_T_b38', chrom=17, pos=19336119, logp=6.828241377576568, target='ENSG00000279825', maf=0.297762),
#   SNPRes(rsid='chr17_19338192_G_A_b38', chrom=17, pos=19338192, logp=6.948639066216026, target='ENSG00000279825', maf=0.296041),
#   SNPRes(rsid='chr17_19343762_G_A_b38', chrom=17, pos=19343762, logp=6.392645787697912, target='ENSG00000279825', maf=0.295181),
#   SNPRes(rsid='chr17_19353811_A_G_b38', chrom=17, pos=19353811, logp=6.687317107588747, target='ENSG00000279825', maf=0.295181),
#   SNPRes(rsid='chr17_19378515_T_G_b38', chrom=17, pos=19378515, logp=6.077242892068766, target='ENSG00000279825', maf=0.324441),
#   SNPRes(rsid='chr17_19388755_A_G_b38', chrom=17, pos=19388755, logp=5.938396750391624, target='ENSG00000279825', maf=0.32358),
#   SNPRes(rsid='chr17_19390414_G_A_b38', chrom=17, pos=19390414, logp=5.938396750391624, target='ENSG00000279825', maf=0.32358),
#   SNPRes(rsid='chr17_19391511_G_T_b38', chrom=17, pos=19391511, logp=10.78691010759294, target='ENSG00000279825', maf=0.2642),
#   SNPRes(rsid='chr17_19392137_G_T_b38', chrom=17, pos=19392137, logp=5.7464972266883345, target='ENSG00000279825', maf=0.327022),
#   SNPRes(rsid='chr17_19020505_G_A_b38', chrom=17, pos=19020505, logp=5.355530882968063, target='ENSG00000265185', maf=0.309811),
#   SNPRes(rsid='chr17_19238913_C_T_b38', chrom=17, pos=19238913, logp=8.26811482324403, target='ENSG00000265185', maf=0.247849),
#   SNPRes(rsid='chr17_19268883_T_G_b38', chrom=17, pos=19268883, logp=7.304486803279982, target='ENSG00000265185', maf=0.296041),
#   SNPRes(rsid='chr17_19269192_A_G_b38', chrom=17, pos=19269192, logp=7.304486803279982, target='ENSG00000265185', maf=0.296041),
#   SNPRes(rsid='chr17_19271561_T_C_b38', chrom=17, pos=19271561, logp=7.429687110319394, target='ENSG00000265185', maf=0.297762),
#   SNPRes(rsid='chr17_19272004_A_G_b38', chrom=17, pos=19272004, logp=7.304486803279982, target='ENSG00000265185', maf=0.296041),
#   SNPRes(rsid='chr17_19301550_T_C_b38', chrom=17, pos=19301550, logp=7.304486803279982, target='ENSG00000265185', maf=0.296041),
#   SNPRes(rsid='chr17_19313948_C_T_b38', chrom=17, pos=19313948, logp=7.304486803279982, target='ENSG00000265185', maf=0.296041),
#   SNPRes(rsid='chr17_19317353_G_A_b38', chrom=17, pos=19317353, logp=7.711350656471256, target='ENSG00000265185', maf=0.296902),
#   SNPRes(rsid='chr17_19336119_C_T_b38', chrom=17, pos=19336119, logp=7.449373013047116, target='ENSG00000265185', maf=0.297762),
#   SNPRes(rsid='chr17_19338192_G_A_b38', chrom=17, pos=19338192, logp=7.304486803279982, target='ENSG00000265185', maf=0.296041),
#   SNPRes(rsid='chr17_19343762_G_A_b38', chrom=17, pos=19343762, logp=7.571819834290984, target='ENSG00000265185', maf=0.295181),
#   SNPRes(rsid='chr17_19353811_A_G_b38', chrom=17, pos=19353811, logp=7.376046070031765, target='ENSG00000265185', maf=0.295181),
#   SNPRes(rsid='chr17_19378515_T_G_b38', chrom=17, pos=19378515, logp=6.025910372037221, target='ENSG00000265185', maf=0.324441),
#   SNPRes(rsid='chr17_19388755_A_G_b38', chrom=17, pos=19388755, logp=6.1479062854115805, target='ENSG00000265185', maf=0.32358),
#   SNPRes(rsid='chr17_19390414_G_A_b38', chrom=17, pos=19390414, logp=6.1479062854115805, target='ENSG00000265185', maf=0.32358),
#   SNPRes(rsid='chr17_19391511_G_T_b38', chrom=17, pos=19391511, logp=6.401653860444893, target='ENSG00000265185', maf=0.2642),
#   SNPRes(rsid='chr17_19392137_G_T_b38', chrom=17, pos=19392137, logp=5.743222139899377, target='ENSG00000265185', maf=0.327022),
#   SNPRes(rsid='chr17_19020505_G_A_b38', chrom=17, pos=19020505, logp=11.091491926594124, target='ENSG00000262074', maf=0.309811),
#   SNPRes(rsid='chr17_19238913_C_T_b38', chrom=17, pos=19238913, logp=7.3230577708171465, target='ENSG00000262074', maf=0.247849),
#   SNPRes(rsid='chr17_19268883_T_G_b38', chrom=17, pos=19268883, logp=12.86780116720427, target='ENSG00000262074', maf=0.296041),
#   SNPRes(rsid='chr17_19269192_A_G_b38', chrom=17, pos=19269192, logp=12.86780116720427, target='ENSG00000262074', maf=0.296041),
#   SNPRes(rsid='chr17_19271561_T_C_b38', chrom=17, pos=19271561, logp=12.726371480826549, target='ENSG00000262074', maf=0.297762),
#   SNPRes(rsid='chr17_19272004_A_G_b38', chrom=17, pos=19272004, logp=12.86780116720427, target='ENSG00000262074', maf=0.296041),
#   SNPRes(rsid='chr17_19301550_T_C_b38', chrom=17, pos=19301550, logp=12.86780116720427, target='ENSG00000262074', maf=0.296041),
#   SNPRes(rsid='chr17_19313948_C_T_b38', chrom=17, pos=19313948, logp=12.86780116720427, target='ENSG00000262074', maf=0.296041),
#   SNPRes(rsid='chr17_19317353_G_A_b38', chrom=17, pos=19317353, logp=12.277079110223925, target='ENSG00000262074', maf=0.296902),
#   SNPRes(rsid='chr17_19336119_C_T_b38', chrom=17, pos=19336119, logp=12.782416047966478, target='ENSG00000262074', maf=0.297762),
#   SNPRes(rsid='chr17_19338192_G_A_b38', chrom=17, pos=19338192, logp=12.86780116720427, target='ENSG00000262074', maf=0.296041),
#   SNPRes(rsid='chr17_19343762_G_A_b38', chrom=17, pos=19343762, logp=12.686394278321632, target='ENSG00000262074', maf=0.295181),
#   SNPRes(rsid='chr17_19353811_A_G_b38', chrom=17, pos=19353811, logp=12.693871036988952, target='ENSG00000262074', maf=0.295181),
#   SNPRes(rsid='chr17_19378515_T_G_b38', chrom=17, pos=19378515, logp=8.207452832892074, target='ENSG00000262074', maf=0.324441),
#   SNPRes(rsid='chr17_19388755_A_G_b38', chrom=17, pos=19388755, logp=7.9160353818647975, target='ENSG00000262074', maf=0.32358),
#   SNPRes(rsid='chr17_19390414_G_A_b38', chrom=17, pos=19390414, logp=7.9160353818647975, target='ENSG00000262074', maf=0.32358),
#   SNPRes(rsid='chr17_19391511_G_T_b38', chrom=17, pos=19391511, logp=5.152937813383845, target='ENSG00000262074', maf=0.2642),
#   SNPRes(rsid='chr17_19392137_G_T_b38', chrom=17, pos=19392137, logp=8.022888037554859, target='ENSG00000262074', maf=0.327022),
#   SNPRes(rsid='chr17_19020505_G_A_b38', chrom=17, pos=19020505, logp=8.893340032427442, target='ENSG00000228157', maf=0.309811),
#   SNPRes(rsid='chr17_19238913_C_T_b38', chrom=17, pos=19238913, logp=29.912548686263996, target='ENSG00000228157', maf=0.247849),
#   SNPRes(rsid='chr17_19268883_T_G_b38', chrom=17, pos=19268883, logp=17.365652735347247, target='ENSG00000228157', maf=0.296041),
#   SNPRes(rsid='chr17_19269192_A_G_b38', chrom=17, pos=19269192, logp=17.365652735347247, target='ENSG00000228157', maf=0.296041),
#   SNPRes(rsid='chr17_19271561_T_C_b38', chrom=17, pos=19271561, logp=17.412765112002006, target='ENSG00000228157', maf=0.297762),
#   SNPRes(rsid='chr17_19272004_A_G_b38', chrom=17, pos=19272004, logp=17.365652735347247, target='ENSG00000228157', maf=0.296041),
#   SNPRes(rsid='chr17_19301550_T_C_b38', chrom=17, pos=19301550, logp=17.365652735347247, target='ENSG00000228157', maf=0.296041),
#   SNPRes(rsid='chr17_19313948_C_T_b38', chrom=17, pos=19313948, logp=17.365652735347247, target='ENSG00000228157', maf=0.296041),
#   SNPRes(rsid='chr17_19317353_G_A_b38', chrom=17, pos=19317353, logp=17.375357001742742, target='ENSG00000228157', maf=0.296902),
#   SNPRes(rsid='chr17_19336119_C_T_b38', chrom=17, pos=19336119, logp=17.326160146189537, target='ENSG00000228157', maf=0.297762),
#   SNPRes(rsid='chr17_19338192_G_A_b38', chrom=17, pos=19338192, logp=17.365652735347247, target='ENSG00000228157', maf=0.296041),
#   SNPRes(rsid='chr17_19343762_G_A_b38', chrom=17, pos=19343762, logp=17.466085656611046, target='ENSG00000228157', maf=0.295181),
#   SNPRes(rsid='chr17_19353811_A_G_b38', chrom=17, pos=19353811, logp=16.99657824591471, target='ENSG00000228157', maf=0.295181),
#   SNPRes(rsid='chr17_19378515_T_G_b38', chrom=17, pos=19378515, logp=13.191900485528702, target='ENSG00000228157', maf=0.324441),
#   SNPRes(rsid='chr17_19388755_A_G_b38', chrom=17, pos=19388755, logp=13.008069432216928, target='ENSG00000228157', maf=0.32358),
#   SNPRes(rsid='chr17_19390414_G_A_b38', chrom=17, pos=19390414, logp=13.008069432216928, target='ENSG00000228157', maf=0.32358),
#   SNPRes(rsid='chr17_19391511_G_T_b38', chrom=17, pos=19391511, logp=25.262109547224703, target='ENSG00000228157', maf=0.2642),
#   SNPRes(rsid='chr17_19392137_G_T_b38', chrom=17, pos=19392137, logp=12.605912718992803, target='ENSG00000228157', maf=0.327022),
#   SNPRes(rsid='chr17_19020505_G_A_b38', chrom=17, pos=19020505, logp=3.7088088114375397, target='ENSG00000262202', maf=0.309811),
#   SNPRes(rsid='chr17_19020505_G_A_b38', chrom=17, pos=19020505, logp=19.298518364379074, target='ENSG00000262319', maf=0.309811),
#   SNPRes(rsid='chr17_19238913_C_T_b38', chrom=17, pos=19238913, logp=21.19480237027155, target='ENSG00000262319', maf=0.247849),
#   SNPRes(rsid='chr17_19268883_T_G_b38', chrom=17, pos=19268883, logp=26.450062905396518, target='ENSG00000262319', maf=0.296041),
#   SNPRes(rsid='chr17_19269192_A_G_b38', chrom=17, pos=19269192, logp=26.450062905396518, target='ENSG00000262319', maf=0.296041),
#   SNPRes(rsid='chr17_19271561_T_C_b38', chrom=17, pos=19271561, logp=25.48089161529806, target='ENSG00000262319', maf=0.297762),
#   SNPRes(rsid='chr17_19272004_A_G_b38', chrom=17, pos=19272004, logp=26.450062905396518, target='ENSG00000262319', maf=0.296041),
#   SNPRes(rsid='chr17_19301550_T_C_b38', chrom=17, pos=19301550, logp=26.450062905396518, target='ENSG00000262319', maf=0.296041),
#   SNPRes(rsid='chr17_19313948_C_T_b38', chrom=17, pos=19313948, logp=26.450062905396518, target='ENSG00000262319', maf=0.296041),
#   SNPRes(rsid='chr17_19317353_G_A_b38', chrom=17, pos=19317353, logp=26.206011365335698, target='ENSG00000262319', maf=0.296902),
#   SNPRes(rsid='chr17_19336119_C_T_b38', chrom=17, pos=19336119, logp=26.079717496372833, target='ENSG00000262319', maf=0.297762),
#   SNPRes(rsid='chr17_19338192_G_A_b38', chrom=17, pos=19338192, logp=26.450062905396518, target='ENSG00000262319', maf=0.296041),
#   SNPRes(rsid='chr17_19343762_G_A_b38', chrom=17, pos=19343762, logp=25.78818823622509, target='ENSG00000262319', maf=0.295181),
#   SNPRes(rsid='chr17_19353811_A_G_b38', chrom=17, pos=19353811, logp=26.440936460852345, target='ENSG00000262319', maf=0.295181),
#   SNPRes(rsid='chr17_19378515_T_G_b38', chrom=17, pos=19378515, logp=26.249753186270887, target='ENSG00000262319', maf=0.324441),
#   SNPRes(rsid='chr17_19388755_A_G_b38', chrom=17, pos=19388755, logp=26.5885132960442, target='ENSG00000262319', maf=0.32358),
#   SNPRes(rsid='chr17_19390414_G_A_b38', chrom=17, pos=19390414, logp=26.5885132960442, target='ENSG00000262319', maf=0.32358),
#   SNPRes(rsid='chr17_19391511_G_T_b38', chrom=17, pos=19391511, logp=20.539297558574546, target='ENSG00000262319', maf=0.2642),
#   SNPRes(rsid='chr17_19392137_G_T_b38', chrom=17, pos=19392137, logp=27.110604724119003, target='ENSG00000262319', maf=0.327022),
#   SNPRes(rsid='chr17_19020505_G_A_b38', chrom=17, pos=19020505, logp=3.982987540745547, target='ENSG00000263934', maf=0.309811),
#   SNPRes(rsid='chr17_19020505_G_A_b38', chrom=17, pos=19020505, logp=15.99714307393888, target='ENSG00000072134', maf=0.309811),
#   SNPRes(rsid='chr17_19238913_C_T_b38', chrom=17, pos=19238913, logp=23.852506086833177, target='ENSG00000072134', maf=0.247849),
#   SNPRes(rsid='chr17_19268883_T_G_b38', chrom=17, pos=19268883, logp=31.886601527828294, target='ENSG00000072134', maf=0.296041),
#   SNPRes(rsid='chr17_19269192_A_G_b38', chrom=17, pos=19269192, logp=31.886601527828294, target='ENSG00000072134', maf=0.296041),
#   SNPRes(rsid='chr17_19271561_T_C_b38', chrom=17, pos=19271561, logp=31.446674149519435, target='ENSG00000072134', maf=0.297762),
#   SNPRes(rsid='chr17_19272004_A_G_b38', chrom=17, pos=19272004, logp=31.886601527828294, target='ENSG00000072134', maf=0.296041),
#   SNPRes(rsid='chr17_19301550_T_C_b38', chrom=17, pos=19301550, logp=31.886601527828294, target='ENSG00000072134', maf=0.296041),
#   SNPRes(rsid='chr17_19313948_C_T_b38', chrom=17, pos=19313948, logp=31.886601527828294, target='ENSG00000072134', maf=0.296041),
#   SNPRes(rsid='chr17_19317353_G_A_b38', chrom=17, pos=19317353, logp=31.401764475655856, target='ENSG00000072134', maf=0.296902),
#   SNPRes(rsid='chr17_19336119_C_T_b38', chrom=17, pos=19336119, logp=31.544162730868536, target='ENSG00000072134', maf=0.297762),
#   SNPRes(rsid='chr17_19338192_G_A_b38', chrom=17, pos=19338192, logp=31.886601527828294, target='ENSG00000072134', maf=0.296041),
#   SNPRes(rsid='chr17_19343762_G_A_b38', chrom=17, pos=19343762, logp=31.859542239986297, target='ENSG00000072134', maf=0.295181),
#   SNPRes(rsid='chr17_19353811_A_G_b38', chrom=17, pos=19353811, logp=31.756418802575723, target='ENSG00000072134', maf=0.295181),
#   SNPRes(rsid='chr17_19378515_T_G_b38', chrom=17, pos=19378515, logp=26.675491194252942, target='ENSG00000072134', maf=0.324441),
#   SNPRes(rsid='chr17_19388755_A_G_b38', chrom=17, pos=19388755, logp=26.442847837561427, target='ENSG00000072134', maf=0.32358),
#   SNPRes(rsid='chr17_19390414_G_A_b38', chrom=17, pos=19390414, logp=26.442847837561427, target='ENSG00000072134', maf=0.32358),
#   SNPRes(rsid='chr17_19391511_G_T_b38', chrom=17, pos=19391511, logp=21.457503218112002, target='ENSG00000072134', maf=0.2642),
#   SNPRes(rsid='chr17_19392137_G_T_b38', chrom=17, pos=19392137, logp=27.151178075145985, target='ENSG00000072134', maf=0.327022),
#   SNPRes(rsid='chr17_19238913_C_T_b38', chrom=17, pos=19238913, logp=3.9923844929151957, target='ENSG00000108641', maf=0.247849),
#   SNPRes(rsid='chr17_19268883_T_G_b38', chrom=17, pos=19268883, logp=5.694208109647283, target='ENSG00000108641', maf=0.296041),
#   SNPRes(rsid='chr17_19269192_A_G_b38', chrom=17, pos=19269192, logp=5.694208109647283, target='ENSG00000108641', maf=0.296041),
#   SNPRes(rsid='chr17_19271561_T_C_b38', chrom=17, pos=19271561, logp=5.491192959781508, target='ENSG00000108641', maf=0.297762),
#   SNPRes(rsid='chr17_19272004_A_G_b38', chrom=17, pos=19272004, logp=5.694208109647283, target='ENSG00000108641', maf=0.296041),
#   SNPRes(rsid='chr17_19301550_T_C_b38', chrom=17, pos=19301550, logp=5.694208109647283, target='ENSG00000108641', maf=0.296041),
#   SNPRes(rsid='chr17_19313948_C_T_b38', chrom=17, pos=19313948, logp=5.694208109647283, target='ENSG00000108641', maf=0.296041),
#   SNPRes(rsid='chr17_19317353_G_A_b38', chrom=17, pos=19317353, logp=5.378988947792443, target='ENSG00000108641', maf=0.296902),
#   SNPRes(rsid='chr17_19336119_C_T_b38', chrom=17, pos=19336119, logp=5.6194450778457865, target='ENSG00000108641', maf=0.297762),
#   SNPRes(rsid='chr17_19338192_G_A_b38', chrom=17, pos=19338192, logp=5.694208109647283, target='ENSG00000108641', maf=0.296041),
#   SNPRes(rsid='chr17_19343762_G_A_b38', chrom=17, pos=19343762, logp=5.422133811314928, target='ENSG00000108641', maf=0.295181),
#   SNPRes(rsid='chr17_19353811_A_G_b38', chrom=17, pos=19353811, logp=5.767148678567981, target='ENSG00000108641', maf=0.295181),
#   SNPRes(rsid='chr17_19378515_T_G_b38', chrom=17, pos=19378515, logp=4.973626101352703, target='ENSG00000108641', maf=0.324441),
#   SNPRes(rsid='chr17_19388755_A_G_b38', chrom=17, pos=19388755, logp=5.205124537536084, target='ENSG00000108641', maf=0.32358),
#   SNPRes(rsid='chr17_19390414_G_A_b38', chrom=17, pos=19390414, logp=5.205124537536084, target='ENSG00000108641', maf=0.32358),
#   SNPRes(rsid='chr17_19391511_G_T_b38', chrom=17, pos=19391511, logp=3.6571570465740115, target='ENSG00000108641', maf=0.2642),
#   SNPRes(rsid='chr17_19392137_G_T_b38', chrom=17, pos=19392137, logp=5.074938138322538, target='ENSG00000108641', maf=0.327022),
#   SNPRes(rsid='chr17_60439553_G_A_b38', chrom=17, pos=60439553, logp=3.722166248187536, target='ENSG00000266992', maf=0.0895009),
#   SNPRes(rsid='chr19_7882640_C_T_b38', chrom=19, pos=7882640, logp=8.28396408550045, target='ENSG00000142459', maf=0.194492),
#   SNPRes(rsid='chr19_18216532_C_T_b38', chrom=19, pos=18216532, logp=4.595688092075895, target='ENSG00000268650', maf=0.0714286),
#   SNPRes(rsid='chr19_39387366_G_A_b38', chrom=19, pos=39387366, logp=5.224313111243299, target='ENSG00000128011', maf=0.182444),
#   SNPRes(rsid='chr22_41435263_A_C_b38', chrom=22, pos=41435263, logp=3.7957850258154786, target='ENSG00000100413', maf=0.0309811)],
#  'av': [SNPRes(rsid='chr1_1387698_A_G_b38', chrom=1, pos=1387698, logp=4.122903487051224, target='ENSG00000184163', maf=0.26226),
#   SNPRes(rsid='chr1_1411323_A_C_b38', chrom=1, pos=1411323, logp=4.306847508360431, target='ENSG00000184163', maf=0.26226),
#   SNPRes(rsid='chr1_1387698_A_G_b38', chrom=1, pos=1387698, logp=5.091566456110376, target='ENSG00000127054', maf=0.26226),
#   SNPRes(rsid='chr1_1411323_A_C_b38', chrom=1, pos=1411323, logp=4.551554953572729, target='ENSG00000127054', maf=0.26226),
#   SNPRes(rsid='chr1_1387698_A_G_b38', chrom=1, pos=1387698, logp=18.824241827746707, target='ENSG00000242485', maf=0.26226),
#   SNPRes(rsid='chr1_1411323_A_C_b38', chrom=1, pos=1411323, logp=18.655022511029312, target='ENSG00000242485', maf=0.26226),
#   SNPRes(rsid='chr1_1387698_A_G_b38', chrom=1, pos=1387698, logp=18.618287611008864, target='ENSG00000235098', maf=0.26226),
#   SNPRes(rsid='chr1_1411323_A_C_b38', chrom=1, pos=1411323, logp=19.831378786693808, target='ENSG00000235098', maf=0.26226),
#   SNPRes(rsid='chr1_1519934_T_G_b38', chrom=1, pos=1519934, logp=4.135389849397229, target='ENSG00000235098', maf=0.317697),
#   SNPRes(rsid='chr1_1519938_T_C_b38', chrom=1, pos=1519938, logp=4.135389849397229, target='ENSG00000235098', maf=0.317697),
#   SNPRes(rsid='chr1_1519934_T_G_b38', chrom=1, pos=1519934, logp=5.221731505933428, target='ENSG00000197785', maf=0.317697),
#   SNPRes(rsid='chr1_1519938_T_C_b38', chrom=1, pos=1519938, logp=5.221731505933428, target='ENSG00000197785', maf=0.317697),
#   SNPRes(rsid='chr1_35029209_T_G_b38', chrom=1, pos=35029209, logp=5.154911266395781, target='ENSG00000197056', maf=0.158849),
#   SNPRes(rsid='chr1_35438311_A_G_b38', chrom=1, pos=35438311, logp=4.405284887536836, target='ENSG00000142686', maf=0.178038),
#   SNPRes(rsid='chr1_35460549_T_C_b38', chrom=1, pos=35460549, logp=6.090947552148362, target='ENSG00000142686', maf=0.214286),
#   SNPRes(rsid='chr1_35485437_A_G_b38', chrom=1, pos=35485437, logp=4.222342678446882, target='ENSG00000142686', maf=0.176972),
#   SNPRes(rsid='chr1_35571621_A_G_b38', chrom=1, pos=35571621, logp=5.8203161023012715, target='ENSG00000142686', maf=0.214286),
#   SNPRes(rsid='chr1_35666945_C_T_b38', chrom=1, pos=35666945, logp=7.006989895717758, target='ENSG00000142686', maf=0.190832),
#   SNPRes(rsid='chr2_10374170_C_T_b38', chrom=2, pos=10374170, logp=4.192352015938839, target='ENSG00000260077', maf=0.0938166),
#   SNPRes(rsid='chr2_152319675_G_A_b38', chrom=2, pos=152319675, logp=3.9199257498788556, target='ENSG00000115145', maf=0.498934),
#   SNPRes(rsid='chr2_152340776_C_T_b38', chrom=2, pos=152340776, logp=3.9199257498788556, target='ENSG00000115145', maf=0.498934),
#   SNPRes(rsid='chr2_152350372_T_C_b38', chrom=2, pos=152350372, logp=4.498883200999932, target='ENSG00000115145', maf=0.484009),
#   SNPRes(rsid='chr2_189962297_A_G_b38', chrom=2, pos=189962297, logp=7.308997236415555, target='ENSG00000128699', maf=0.369936),
#   SNPRes(rsid='chr4_38797027_C_A_b38', chrom=4, pos=38797027, logp=4.780611972310432, target='ENSG00000197712', maf=0.373134),
#   SNPRes(rsid='chr5_1006946_G_A_b38', chrom=5, pos=1006946, logp=5.58546617993845, target='ENSG00000215246', maf=0.197228),
#   SNPRes(rsid='chr5_1012168_C_T_b38', chrom=5, pos=1012168, logp=5.807028545287861, target='ENSG00000215246', maf=0.195096),
#   SNPRes(rsid='chr5_1013579_T_C_b38', chrom=5, pos=1013579, logp=5.58546617993845, target='ENSG00000215246', maf=0.197228),
#   SNPRes(rsid='chr5_132697920_C_T_b38', chrom=5, pos=132697920, logp=10.871642740964724, target='ENSG00000131437', maf=0.236674),
#   SNPRes(rsid='chr5_132743502_A_G_b38', chrom=5, pos=132743502, logp=9.271176459970182, target='ENSG00000131437', maf=0.181237),
#   SNPRes(rsid='chr5_132746205_A_G_b38', chrom=5, pos=132746205, logp=9.271176459970182, target='ENSG00000131437', maf=0.181237),
#   SNPRes(rsid='chr5_132749264_G_A_b38', chrom=5, pos=132749264, logp=9.516086213513898, target='ENSG00000131437', maf=0.182303),
#   SNPRes(rsid='chr5_132755136_T_C_b38', chrom=5, pos=132755136, logp=12.04067569256622, target='ENSG00000131437', maf=0.208955),
#   SNPRes(rsid='chr5_132757957_T_C_b38', chrom=5, pos=132757957, logp=12.04067569256622, target='ENSG00000131437', maf=0.208955),
#   SNPRes(rsid='chr5_132759282_G_A_b38', chrom=5, pos=132759282, logp=12.04067569256622, target='ENSG00000131437', maf=0.208955),
#   SNPRes(rsid='chr5_132762728_A_C_b38', chrom=5, pos=132762728, logp=11.919842689029815, target='ENSG00000131437', maf=0.197228),
#   SNPRes(rsid='chr5_132763546_A_G_b38', chrom=5, pos=132763546, logp=11.07800364765545, target='ENSG00000131437', maf=0.202559),
#   SNPRes(rsid='chr5_132764307_A_G_b38', chrom=5, pos=132764307, logp=12.04067569256622, target='ENSG00000131437', maf=0.208955),
#   SNPRes(rsid='chr5_132764780_T_C_b38', chrom=5, pos=132764780, logp=11.145207092495678, target='ENSG00000131437', maf=0.206823),
#   SNPRes(rsid='chr5_132766211_G_A_b38', chrom=5, pos=132766211, logp=10.140044340830624, target='ENSG00000131437', maf=0.186567),
#   SNPRes(rsid='chr5_132767579_G_A_b38', chrom=5, pos=132767579, logp=11.07800364765545, target='ENSG00000131437', maf=0.202559),
#   SNPRes(rsid='chr5_132771359_G_T_b38', chrom=5, pos=132771359, logp=11.07800364765545, target='ENSG00000131437', maf=0.202559),
#   SNPRes(rsid='chr5_132771703_A_G_b38', chrom=5, pos=132771703, logp=11.07800364765545, target='ENSG00000131437', maf=0.202559),
#   SNPRes(rsid='chr5_132772334_G_A_b38', chrom=5, pos=132772334, logp=11.07800364765545, target='ENSG00000131437', maf=0.202559),
#   SNPRes(rsid='chr5_132773793_A_G_b38', chrom=5, pos=132773793, logp=11.07800364765545, target='ENSG00000131437', maf=0.202559),
#   SNPRes(rsid='chr5_132773927_T_C_b38', chrom=5, pos=132773927, logp=11.07800364765545, target='ENSG00000131437', maf=0.202559),
#   SNPRes(rsid='chr5_132774050_G_A_b38', chrom=5, pos=132774050, logp=11.07800364765545, target='ENSG00000131437', maf=0.202559),
#   SNPRes(rsid='chr5_132774274_T_C_b38', chrom=5, pos=132774274, logp=11.07800364765545, target='ENSG00000131437', maf=0.202559),
#   SNPRes(rsid='chr5_132775238_A_C_b38', chrom=5, pos=132775238, logp=11.145207092495678, target='ENSG00000131437', maf=0.206823),
#   SNPRes(rsid='chr5_132775351_G_A_b38', chrom=5, pos=132775351, logp=11.145207092495678, target='ENSG00000131437', maf=0.206823),
#   SNPRes(rsid='chr5_132776043_G_A_b38', chrom=5, pos=132776043, logp=11.07800364765545, target='ENSG00000131437', maf=0.202559),
#   SNPRes(rsid='chr5_132776297_T_C_b38', chrom=5, pos=132776297, logp=11.145207092495678, target='ENSG00000131437', maf=0.206823),
#   SNPRes(rsid='chr5_132776348_G_A_b38', chrom=5, pos=132776348, logp=11.145207092495678, target='ENSG00000131437', maf=0.206823),
#   SNPRes(rsid='chr5_132776741_A_G_b38', chrom=5, pos=132776741, logp=11.145207092495678, target='ENSG00000131437', maf=0.206823),
#   SNPRes(rsid='chr5_132778248_T_C_b38', chrom=5, pos=132778248, logp=10.776807885877565, target='ENSG00000131437', maf=0.205757),
#   SNPRes(rsid='chr5_132779532_C_T_b38', chrom=5, pos=132779532, logp=10.525572469533461, target='ENSG00000131437', maf=0.202559),
#   SNPRes(rsid='chr5_132783561_A_G_b38', chrom=5, pos=132783561, logp=10.878361379378054, target='ENSG00000131437', maf=0.203625),
#   SNPRes(rsid='chr5_132789134_T_C_b38', chrom=5, pos=132789134, logp=10.732541966385671, target='ENSG00000131437', maf=0.201493),
#   SNPRes(rsid='chr6_105108639_G_A_b38', chrom=6, pos=105108639, logp=5.5493675880929905, target='ENSG00000112276', maf=0.228145),
#   SNPRes(rsid='chr6_105110901_G_A_b38', chrom=6, pos=105110901, logp=5.5493675880929905, target='ENSG00000112276', maf=0.228145),
#   SNPRes(rsid='chr6_105112443_G_A_b38', chrom=6, pos=105112443, logp=5.5493675880929905, target='ENSG00000112276', maf=0.228145),
#   SNPRes(rsid='chr6_105117376_G_A_b38', chrom=6, pos=105117376, logp=5.5493675880929905, target='ENSG00000112276', maf=0.228145),
#   SNPRes(rsid='chr6_105174646_T_C_b38', chrom=6, pos=105174646, logp=5.5493675880929905, target='ENSG00000112276', maf=0.228145),
#   SNPRes(rsid='chr7_30672979_A_G_b38', chrom=7, pos=30672979, logp=5.5349548991921935, target='ENSG00000226874', maf=0.414712),
#   SNPRes(rsid='chr7_30687711_G_A_b38', chrom=7, pos=30687711, logp=4.610157298118331, target='ENSG00000226874', maf=0.454158),
#   SNPRes(rsid='chr7_30688387_G_A_b38', chrom=7, pos=30688387, logp=4.325694707764495, target='ENSG00000226874', maf=0.460554),
#   SNPRes(rsid='chr7_30672979_A_G_b38', chrom=7, pos=30672979, logp=20.794222009872467, target='ENSG00000196295', maf=0.414712),
#   SNPRes(rsid='chr7_30687711_G_A_b38', chrom=7, pos=30687711, logp=15.885622570213844, target='ENSG00000196295', maf=0.454158),
#   SNPRes(rsid='chr7_30688387_G_A_b38', chrom=7, pos=30688387, logp=15.245988985161164, target='ENSG00000196295', maf=0.460554),
#   SNPRes(rsid='chr8_27532675_G_A_b38', chrom=8, pos=27532675, logp=13.355756443677612, target='ENSG00000120915', maf=0.230277),
#   SNPRes(rsid='chr8_30259153_T_C_b38', chrom=8, pos=30259153, logp=4.711256827416159, target='ENSG00000248159', maf=0.234542),
#   SNPRes(rsid='chr9_127952651_T_C_b38', chrom=9, pos=127952651, logp=15.931027923582443, target='ENSG00000167103', maf=0.308102),
#   SNPRes(rsid='chr10_31276692_A_G_b38', chrom=10, pos=31276692, logp=8.498134548190887, target='ENSG00000237036', maf=0.142857),
#   SNPRes(rsid='chr10_31412414_T_C_b38', chrom=10, pos=31412414, logp=8.30305679282553, target='ENSG00000237036', maf=0.141791),
#   SNPRes(rsid='chr10_31528977_C_T_b38', chrom=10, pos=31528977, logp=9.027061614039951, target='ENSG00000237036', maf=0.139659),
#   SNPRes(rsid='chr10_75655858_G_A_b38', chrom=10, pos=75655858, logp=4.6915508444934435, target='ENSG00000148655', maf=0.335821),
#   SNPRes(rsid='chr10_75657535_C_T_b38', chrom=10, pos=75657535, logp=4.816670355948471, target='ENSG00000148655', maf=0.336887),
#   SNPRes(rsid='chr12_46439822_C_T_b38', chrom=12, pos=46439822, logp=13.721914354495643, target='ENSG00000257261', maf=0.481876),
#   SNPRes(rsid='chr12_46439822_C_T_b38', chrom=12, pos=46439822, logp=7.1759835673773855, target='ENSG00000272369', maf=0.481876),
#   SNPRes(rsid='chr15_52560413_T_C_b38', chrom=15, pos=52560413, logp=6.759345934664697, target='ENSG00000128989', maf=0.333689),
# ...
#   SNPRes(rsid='chr17_52391996_G_A_b38', chrom=17, pos=52391996, logp=4.3804632055876995, target='ENSG00000226364', maf=0.206522),
#   SNPRes(rsid='chr17_60161930_T_C_b38', chrom=17, pos=60161930, logp=11.106993779557659, target='ENSG00000068097', maf=0.127329),
#   SNPRes(rsid='chr17_60161930_T_C_b38', chrom=17, pos=60161930, logp=5.081503099802862, target='ENSG00000267248', maf=0.127329),
#   SNPRes(rsid='chr17_60410823_A_G_b38', chrom=17, pos=60410823, logp=12.37318555565384, target='ENSG00000267248', maf=0.22205),
#   SNPRes(rsid='chr17_60558968_A_G_b38', chrom=17, pos=60558968, logp=6.404415605504972, target='ENSG00000267248', maf=0.186335),
#   SNPRes(rsid='chr17_64854905_G_T_b38', chrom=17, pos=64854905, logp=5.614803192770504, target='ENSG00000136478', maf=0.0667702),
#   SNPRes(rsid='chr17_75440323_G_A_b38', chrom=17, pos=75440323, logp=5.279939975250757, target='ENSG00000177728', maf=0.251553),
#   SNPRes(rsid='chr17_75450949_C_T_b38', chrom=17, pos=75450949, logp=5.563123660496605, target='ENSG00000177728', maf=0.253106),
#   SNPRes(rsid='chr17_75440323_G_A_b38', chrom=17, pos=75440323, logp=6.078624663608464, target='ENSG00000073350', maf=0.251553),
#   SNPRes(rsid='chr17_75450949_C_T_b38', chrom=17, pos=75450949, logp=6.412775223069008, target='ENSG00000073350', maf=0.253106),
#   SNPRes(rsid='chr18_8790588_A_G_b38', chrom=18, pos=8790588, logp=7.109573950790205, target='ENSG00000272788', maf=0.423913),
#   SNPRes(rsid='chr18_73171355_T_C_b38', chrom=18, pos=73171355, logp=5.528063195405271, target='ENSG00000263711', maf=0.161491),
#   SNPRes(rsid='chr19_2889168_C_T_b38', chrom=19, pos=2889168, logp=4.594950899377506, target='ENSG00000253392', maf=0.175466),
#   SNPRes(rsid='chr19_4539074_A_G_b38', chrom=19, pos=4539074, logp=4.7403392382254, target='ENSG00000105251', maf=0.192547),
#   SNPRes(rsid='chr19_4541391_T_C_b38', chrom=19, pos=4541391, logp=4.660361762801013, target='ENSG00000105251', maf=0.184783),
#   SNPRes(rsid='chr19_5799795_A_G_b38', chrom=19, pos=5799795, logp=35.68355785169179, target='ENSG00000141994', maf=0.223602),
#   SNPRes(rsid='chr20_2846822_G_A_b38', chrom=20, pos=2846822, logp=20.720755238395636, target='ENSG00000215305', maf=0.39441),
#   SNPRes(rsid='chr20_2853133_G_A_b38', chrom=20, pos=2853133, logp=20.720755238395636, target='ENSG00000215305', maf=0.39441),
#   SNPRes(rsid='chr20_2855611_T_C_b38', chrom=20, pos=2855611, logp=20.819983142416746, target='ENSG00000215305', maf=0.392857),
#   SNPRes(rsid='chr20_2855618_C_T_b38', chrom=20, pos=2855618, logp=20.819983142416746, target='ENSG00000215305', maf=0.392857),
#   SNPRes(rsid='chr20_2856034_T_G_b38', chrom=20, pos=2856034, logp=20.819983142416746, target='ENSG00000215305', maf=0.392857),
#   SNPRes(rsid='chr20_22352470_T_C_b38', chrom=20, pos=22352470, logp=4.562117900743439, target='ENSG00000204684', maf=0.295031),
#   SNPRes(rsid='chr20_22422649_T_C_b38', chrom=20, pos=22422649, logp=7.688604314736716, target='ENSG00000204684', maf=0.170807),
#   SNPRes(rsid='chr20_32566653_T_C_b38', chrom=20, pos=32566653, logp=3.797876927201956, target='ENSG00000204393', maf=0.161491),
#   SNPRes(rsid='chr20_63530987_T_C_b38', chrom=20, pos=63530987, logp=13.906266715286414, target='ENSG00000125534', maf=0.32764),
#   SNPRes(rsid='chr20_63506110_G_A_b38', chrom=20, pos=63506110, logp=4.686223442796127, target='ENSG00000101213', maf=0.245342),
#   SNPRes(rsid='chr20_63506618_A_G_b38', chrom=20, pos=63506618, logp=4.38561960664357, target='ENSG00000101213', maf=0.209627),
#   SNPRes(rsid='chr20_63522320_T_G_b38', chrom=20, pos=63522320, logp=4.470048907243874, target='ENSG00000101213', maf=0.206522),
#   SNPRes(rsid='chr20_63522433_G_A_b38', chrom=20, pos=63522433, logp=4.145023900393014, target='ENSG00000101213', maf=0.270186),
#   SNPRes(rsid='chr22_23393578_C_T_b38', chrom=22, pos=23393578, logp=4.720670769067779, target='ENSG00000133519', maf=0.32764),
#   SNPRes(rsid='chr22_23570536_A_G_b38', chrom=22, pos=23570536, logp=4.423605662188167, target='ENSG00000133519', maf=0.368012),
#   SNPRes(rsid='chr22_23570536_A_G_b38', chrom=22, pos=23570536, logp=10.32404669305591, target='ENSG00000280623', maf=0.368012),
#   SNPRes(rsid='chr22_23570536_A_G_b38', chrom=22, pos=23570536, logp=15.757239988763601, target='ENSG00000224277', maf=0.368012),
#   SNPRes(rsid='chr22_36358218_C_T_b38', chrom=22, pos=36358218, logp=9.573911853163946, target='ENSG00000100345', maf=0.450311),
#   SNPRes(rsid='chr22_41527647_T_C_b38', chrom=22, pos=41527647, logp=5.693866744756855, target='ENSG00000100413', maf=0.0854037),
#   SNPRes(rsid='chr22_45338979_T_C_b38', chrom=22, pos=45338979, logp=8.407264905691724, target='ENSG00000100376', maf=0.333851),
#   SNPRes(rsid='chr22_45341600_T_C_b38', chrom=22, pos=45341600, logp=9.23882870292822, target='ENSG00000100376', maf=0.372671),
#   SNPRes(rsid='chr22_45342606_A_G_b38', chrom=22, pos=45342606, logp=9.705110708189588, target='ENSG00000100376', maf=0.371118),
#   SNPRes(rsid='chr22_45343973_A_G_b38', chrom=22, pos=45343973, logp=9.705110708189588, target='ENSG00000100376', maf=0.371118),
#   SNPRes(rsid='chr22_45341600_T_C_b38', chrom=22, pos=45341600, logp=4.905085369816545, target='ENSG00000077935', maf=0.372671),
#   SNPRes(rsid='chr22_45342606_A_G_b38', chrom=22, pos=45342606, logp=4.841233560680399, target='ENSG00000077935', maf=0.371118),
#   SNPRes(rsid='chr22_45343973_A_G_b38', chrom=22, pos=45343973, logp=4.841233560680399, target='ENSG00000077935', maf=0.371118)],
#  'ut': [SNPRes(rsid='chr1_1309988_G_A_b38', chrom=1, pos=1309988, logp=6.304229473662854, target='ENSG00000127054', maf=0.302326),
#   SNPRes(rsid='chr1_1330125_G_A_b38', chrom=1, pos=1330125, logp=5.232738728220506, target='ENSG00000127054', maf=0.306202),
#   SNPRes(rsid='chr1_1387698_A_G_b38', chrom=1, pos=1387698, logp=5.659232763381842, target='ENSG00000127054', maf=0.294574),
#   SNPRes(rsid='chr1_1400410_A_G_b38', chrom=1, pos=1400410, logp=6.2216866432677485, target='ENSG00000127054', maf=0.275194),
#   SNPRes(rsid='chr1_1411323_A_C_b38', chrom=1, pos=1411323, logp=4.915620360785649, target='ENSG00000127054', maf=0.290698),
#   SNPRes(rsid='chr1_1306420_A_G_b38', chrom=1, pos=1306420, logp=6.282027592576997, target='ENSG00000235098', maf=0.20155),
#   SNPRes(rsid='chr1_1309988_G_A_b38', chrom=1, pos=1309988, logp=7.41983028156749, target='ENSG00000235098', maf=0.302326),
#   SNPRes(rsid='chr1_1330125_G_A_b38', chrom=1, pos=1330125, logp=5.965844993859616, target='ENSG00000235098', maf=0.306202),
#   SNPRes(rsid='chr1_1387698_A_G_b38', chrom=1, pos=1387698, logp=7.445281941730927, target='ENSG00000235098', maf=0.294574),
#   SNPRes(rsid='chr1_1400410_A_G_b38', chrom=1, pos=1400410, logp=5.568604067070812, target='ENSG00000235098', maf=0.275194),
#   SNPRes(rsid='chr1_1411323_A_C_b38', chrom=1, pos=1411323, logp=7.606314263111428, target='ENSG00000235098', maf=0.290698),
#   SNPRes(rsid='chr1_1421170_A_G_b38', chrom=1, pos=1421170, logp=9.52019587102115, target='ENSG00000235098', maf=0.186047),
#   SNPRes(rsid='chr1_1422081_C_T_b38', chrom=1, pos=1422081, logp=9.444822087800933, target='ENSG00000235098', maf=0.197674),
#   SNPRes(rsid='chr1_1421170_A_G_b38', chrom=1, pos=1421170, logp=5.781128532299452, target='ENSG00000225905', maf=0.186047),
#   SNPRes(rsid='chr1_1422081_C_T_b38', chrom=1, pos=1422081, logp=5.566623848848044, target='ENSG00000225905', maf=0.197674),
#   SNPRes(rsid='chr3_129352535_T_C_b38', chrom=3, pos=129352535, logp=11.550771604216852, target='ENSG00000270773', maf=0.170543),
#   SNPRes(rsid='chr3_129353642_T_C_b38', chrom=3, pos=129353642, logp=9.390716217054253, target='ENSG00000270773', maf=0.186047),
#   SNPRes(rsid='chr3_129356400_C_T_b38', chrom=3, pos=129356400, logp=11.550771604216852, target='ENSG00000270773', maf=0.170543),
#   SNPRes(rsid='chr3_129365923_A_G_b38', chrom=3, pos=129365923, logp=8.752780655482434, target='ENSG00000270773', maf=0.182171),
#   SNPRes(rsid='chr3_129366295_A_C_b38', chrom=3, pos=129366295, logp=8.752780655482434, target='ENSG00000270773', maf=0.182171),
#   SNPRes(rsid='chr3_129426770_G_A_b38', chrom=3, pos=129426770, logp=9.619323950102347, target='ENSG00000251474', maf=0.27907),
#   SNPRes(rsid='chr3_129442145_G_A_b38', chrom=3, pos=129442145, logp=9.619323950102347, target='ENSG00000251474', maf=0.27907),
#   SNPRes(rsid='chr3_129461746_G_A_b38', chrom=3, pos=129461746, logp=9.619323950102347, target='ENSG00000251474', maf=0.27907),
#   SNPRes(rsid='chr3_129497279_T_G_b38', chrom=3, pos=129497279, logp=9.619323950102347, target='ENSG00000251474', maf=0.27907),
#   SNPRes(rsid='chr3_129497829_A_G_b38', chrom=3, pos=129497829, logp=9.619323950102347, target='ENSG00000251474', maf=0.27907),
#   SNPRes(rsid='chr3_129524695_G_A_b38', chrom=3, pos=129524695, logp=9.619323950102347, target='ENSG00000251474', maf=0.27907),
#   SNPRes(rsid='chr3_129527571_T_C_b38', chrom=3, pos=129527571, logp=8.965523954143713, target='ENSG00000251474', maf=0.275194),
#   SNPRes(rsid='chr3_129527956_C_A_b38', chrom=3, pos=129527956, logp=8.965523954143713, target='ENSG00000251474', maf=0.275194),
#   SNPRes(rsid='chr3_129528708_A_G_b38', chrom=3, pos=129528708, logp=9.139232104968992, target='ENSG00000251474', maf=0.271318),
#   SNPRes(rsid='chr7_99529017_T_C_b38', chrom=7, pos=99529017, logp=4.713563740911165, target='ENSG00000244219', maf=0.20155),
#   SNPRes(rsid='chr10_109948435_A_G_b38', chrom=10, pos=109948435, logp=4.72160769944101, target='ENSG00000148700', maf=0.236434),
#   SNPRes(rsid='chr10_109969745_C_T_b38', chrom=10, pos=109969745, logp=4.72160769944101, target='ENSG00000148700', maf=0.236434),
#   SNPRes(rsid='chr10_110086929_A_G_b38', chrom=10, pos=110086929, logp=4.693109829518084, target='ENSG00000148700', maf=0.255814),
#   SNPRes(rsid='chr10_110141809_G_A_b38', chrom=10, pos=110141809, logp=4.73617936589667, target='ENSG00000148700', maf=0.248062),
#   SNPRes(rsid='chr12_53013054_A_G_b38', chrom=12, pos=53013054, logp=6.167818847809004, target='ENSG00000063046', maf=0.248062),
#   SNPRes(rsid='chr12_53014796_A_G_b38', chrom=12, pos=53014796, logp=6.167818847809004, target='ENSG00000063046', maf=0.248062),
#   SNPRes(rsid='chr12_53040321_C_A_b38', chrom=12, pos=53040321, logp=6.167818847809004, target='ENSG00000063046', maf=0.248062),
#   SNPRes(rsid='chr12_53043071_T_C_b38', chrom=12, pos=53043071, logp=6.167818847809004, target='ENSG00000063046', maf=0.248062),
#   SNPRes(rsid='chr14_76955317_T_C_b38', chrom=14, pos=76955317, logp=5.602046094126895, target='ENSG00000258602', maf=0.321705),
#   SNPRes(rsid='chr14_76955317_T_C_b38', chrom=14, pos=76955317, logp=5.7270890705844595, target='ENSG00000243225', maf=0.321705),
#   SNPRes(rsid='chr14_104818822_A_G_b38', chrom=14, pos=104818822, logp=9.355332998227635, target='ENSG00000258701', maf=0.313953),
#   SNPRes(rsid='chr14_104823579_G_A_b38', chrom=14, pos=104823579, logp=9.355332998227635, target='ENSG00000258701', maf=0.313953),
#   SNPRes(rsid='chr14_104848305_T_C_b38', chrom=14, pos=104848305, logp=9.471984946374171, target='ENSG00000258701', maf=0.317829),
#   SNPRes(rsid='chr14_104818822_A_G_b38', chrom=14, pos=104818822, logp=6.293744061013886, target='ENSG00000258811', maf=0.313953),
#   SNPRes(rsid='chr14_104823579_G_A_b38', chrom=14, pos=104823579, logp=6.293744061013886, target='ENSG00000258811', maf=0.313953),
#   SNPRes(rsid='chr14_104848305_T_C_b38', chrom=14, pos=104848305, logp=6.491517416320959, target='ENSG00000258811', maf=0.317829),
#   SNPRes(rsid='chr15_41857274_T_C_b38', chrom=15, pos=41857274, logp=5.824725983018778, target='ENSG00000137877', maf=0.430233),
#   SNPRes(rsid='chr15_45095352_A_G_b38', chrom=15, pos=45095352, logp=5.912978552449125, target='ENSG00000259479', maf=0.170543),
#   SNPRes(rsid='chr15_45096184_C_T_b38', chrom=15, pos=45096184, logp=5.912978552449125, target='ENSG00000259479', maf=0.170543),
#   SNPRes(rsid='chr15_45099877_G_A_b38', chrom=15, pos=45099877, logp=5.865064655398692, target='ENSG00000259479', maf=0.170543),
#   SNPRes(rsid='chr15_45110742_A_G_b38', chrom=15, pos=45110742, logp=5.238605965422612, target='ENSG00000259479', maf=0.174419),
#   SNPRes(rsid='chr15_45116501_C_T_b38', chrom=15, pos=45116501, logp=5.242215405967699, target='ENSG00000259479', maf=0.182171),
#   SNPRes(rsid='chr15_45117073_C_T_b38', chrom=15, pos=45117073, logp=5.242215405967699, target='ENSG00000259479', maf=0.182171),
#   SNPRes(rsid='chr16_963537_A_G_b38', chrom=16, pos=963537, logp=5.931695373097727, target='ENSG00000103227', maf=0.410853),
#   SNPRes(rsid='chr16_22316773_G_T_b38', chrom=16, pos=22316773, logp=5.037634453175138, target='ENSG00000237296', maf=0.399225),
#   SNPRes(rsid='chr16_48969867_C_T_b38', chrom=16, pos=48969867, logp=6.273755427408948, target='ENSG00000102924', maf=0.244186),
#   SNPRes(rsid='chr16_48970373_G_A_b38', chrom=16, pos=48970373, logp=6.273755427408948, target='ENSG00000102924', maf=0.244186),
#   SNPRes(rsid='chr16_48969867_C_T_b38', chrom=16, pos=48969867, logp=6.497898039718479, target='ENSG00000260614', maf=0.244186),
#   SNPRes(rsid='chr16_48970373_G_A_b38', chrom=16, pos=48970373, logp=6.497898039718479, target='ENSG00000260614', maf=0.244186),
#   SNPRes(rsid='chr17_19238913_C_T_b38', chrom=17, pos=19238913, logp=6.255861199221098, target='ENSG00000279825', maf=0.251938),
#   SNPRes(rsid='chr17_19391511_G_T_b38', chrom=17, pos=19391511, logp=5.626968398493666, target='ENSG00000279825', maf=0.271318),
#   SNPRes(rsid='chr17_19238913_C_T_b38', chrom=17, pos=19238913, logp=5.278984533286663, target='ENSG00000228157', maf=0.251938),
#   SNPRes(rsid='chr17_19011465_C_T_b38', chrom=17, pos=19011465, logp=5.000869023548035, target='ENSG00000262319', maf=0.44186),
#   SNPRes(rsid='chr17_19020505_G_A_b38', chrom=17, pos=19020505, logp=5.70198576877207, target='ENSG00000262319', maf=0.329457),
#   SNPRes(rsid='chr17_19238913_C_T_b38', chrom=17, pos=19238913, logp=8.064942375999784, target='ENSG00000262319', maf=0.251938),
#   SNPRes(rsid='chr17_19268883_T_G_b38', chrom=17, pos=19268883, logp=7.38398896211747, target='ENSG00000262319', maf=0.325581),
#   SNPRes(rsid='chr17_19269192_A_G_b38', chrom=17, pos=19269192, logp=7.38398896211747, target='ENSG00000262319', maf=0.325581),
#   SNPRes(rsid='chr17_19271561_T_C_b38', chrom=17, pos=19271561, logp=8.232337381594954, target='ENSG00000262319', maf=0.329457),
#   SNPRes(rsid='chr17_19272004_A_G_b38', chrom=17, pos=19272004, logp=7.38398896211747, target='ENSG00000262319', maf=0.325581),
#   SNPRes(rsid='chr17_19301550_T_C_b38', chrom=17, pos=19301550, logp=7.38398896211747, target='ENSG00000262319', maf=0.325581),
#   SNPRes(rsid='chr17_19313948_C_T_b38', chrom=17, pos=19313948, logp=7.38398896211747, target='ENSG00000262319', maf=0.325581),
#   SNPRes(rsid='chr17_19317353_G_A_b38', chrom=17, pos=19317353, logp=7.38398896211747, target='ENSG00000262319', maf=0.325581),
#   SNPRes(rsid='chr17_19336119_C_T_b38', chrom=17, pos=19336119, logp=7.38398896211747, target='ENSG00000262319', maf=0.325581),
#   SNPRes(rsid='chr17_19338192_G_A_b38', chrom=17, pos=19338192, logp=7.38398896211747, target='ENSG00000262319', maf=0.325581),
#   SNPRes(rsid='chr17_19343762_G_A_b38', chrom=17, pos=19343762, logp=7.38398896211747, target='ENSG00000262319', maf=0.325581),
#   SNPRes(rsid='chr17_19353811_A_G_b38', chrom=17, pos=19353811, logp=7.38398896211747, target='ENSG00000262319', maf=0.325581),
#   SNPRes(rsid='chr17_19378515_T_G_b38', chrom=17, pos=19378515, logp=6.854235062168666, target='ENSG00000262319', maf=0.364341),
#   SNPRes(rsid='chr17_19388755_A_G_b38', chrom=17, pos=19388755, logp=6.854235062168666, target='ENSG00000262319', maf=0.364341),
#   SNPRes(rsid='chr17_19390414_G_A_b38', chrom=17, pos=19390414, logp=6.854235062168666, target='ENSG00000262319', maf=0.364341),
#   SNPRes(rsid='chr17_19391511_G_T_b38', chrom=17, pos=19391511, logp=6.763992073967879, target='ENSG00000262319', maf=0.271318),
#   SNPRes(rsid='chr17_19392137_G_T_b38', chrom=17, pos=19392137, logp=6.492721773278338, target='ENSG00000262319', maf=0.372093),
#   SNPRes(rsid='chr19_40088753_C_T_b38', chrom=19, pos=40088753, logp=5.065600033671099, target='ENSG00000197782', maf=0.244186)]}

# %%
outcisfilename = os.path.join(outdir,"CisEQTL_enrichment_results_"+title+".txt")
with open(outcisfilename, 'w') as outstream:
    for tissue in tissues:
        if tissue in res_dict:
            line = f"{tissue}\t{res_dict[tissue].ncis}\t{res_dict[tissue].ntrans}\t{res_dict[tissue].ncistrans}\t{res_dict[tissue].randtrans}\t{res_dict[tissue].enrichment}\t{res_dict[tissue].pval}\n"
            outstream.write(line)

targets_outfile = os.path.join(outdir,"CistransEQTL_targets.txt")
with open(targets_outfile, 'w') as outstream:
    for tissue in tissues:
        if tissue in res_target_dict:
            for snp in res_target_dict[tissue]:
                line = f"{tissue}\t{snp.rsid}\t{snp.logp}\t{snp.target}\t{snp.maf}\n"
                outstream.write(line)
            
# outcistypefilename = os.path.join(outdir,"CisEQTL_target_enrichment_results_"+title+".txt")
# if os.path.exists(outcistypefilename):
#     print("Warning! File exists")
#     raise
# with open(outcistypefilename, 'w') as outstream:
#     for tissue in tissues:
#         if tissue in res_dict_cistype:
#             for genetype in res_dict_cistype[tissue].keys():
#                 cis_hits = res_dict_cistype[tissue][genetype].hits
#                 cis_frac = res_dict_cistype[tissue][genetype].frac
#                 cis_e    = res_dict_cistype[tissue][genetype].enrichment
#                 cis_pval = res_dict_cistype[tissue][genetype].pval
#                 random_hits = res_dict_randomtype[tissue][genetype].hits
#                 random_frac = res_dict_randomtype[tissue][genetype].frac
#                 random_e    = res_dict_randomtype[tissue][genetype].enrichment
#                 random_pval = res_dict_randomtype[tissue][genetype].pval
#                 cisline    = f"{tissue}\t{genetype}\tCIS\t{cis_hits}\t{cis_frac}\t{cis_e}\t{cis_pval}\n"
#                 randomline = f"{tissue}\t{genetype}\tRANDOM\t{random_hits}\t{random_frac}\t{random_e}\t{random_pval}\n"
#                 outstream.write(cisline)
#                 outstream.write(randomline)

# %%
### Fisher exact test

import scipy.stats as stats
oddsratio, pvalue = stats.fisher_exact([[168, 1462637-168], [1280-168, 4362583-168-1462637]])
pvalue
# Out:
# 1.1247162498187758e-62

# %%
targets_outfile = os.path.join(outdir,"CistransEQTL_targets.txt")
res_target_dict = collections.defaultdict(list)
with open(targets_outfile) as instream:
    for line in instream:
        arr = line.strip().split("\t")
        t    = arr[0]
        rsid = arr[1]
        logp = -float(arr[2])
        targ = arr[3]
        maf  = float(arr[4])
        chrom = int(rsid.split("_")[0][3:])
        pos   = int(rsid.split("_")[1])
        res_target_dict[t].append( SNPRes(rsid=rsid, chrom=chrom, pos=pos, logp=-logp, maf=maf, target=targ) )

# %%
res_target_dict
# Out:
# defaultdict(list,
#             {'as': [SNPRes(rsid='chr1_115556462_T_C_b38', chrom=1, pos=115556462, logp=9.320521226679793, target='ENSG00000173218', maf=0.302926),
#               SNPRes(rsid='chr1_115577519_C_A_b38', chrom=1, pos=115577519, logp=9.320521226679793, target='ENSG00000173218', maf=0.302926),
#               SNPRes(rsid='chr1_115582269_C_T_b38', chrom=1, pos=115582269, logp=9.320521226679793, target='ENSG00000173218', maf=0.302926),
#               SNPRes(rsid='chr1_115594189_C_T_b38', chrom=1, pos=115594189, logp=11.244205153312071, target='ENSG00000173218', maf=0.312392),
#               SNPRes(rsid='chr2_46536234_A_G_b38', chrom=2, pos=46536234, logp=4.139108246749908, target='ENSG00000279254', maf=0.0378658),
#               SNPRes(rsid='chr2_46659694_T_G_b38', chrom=2, pos=46659694, logp=5.518530139364184, target='ENSG00000279254', maf=0.0481928),
#               SNPRes(rsid='chr2_84206517_G_T_b38', chrom=2, pos=84206517, logp=4.9214018236123485, target='ENSG00000115423', maf=0.276248),
#               SNPRes(rsid='chr2_84206772_G_A_b38', chrom=2, pos=84206772, logp=5.098254060581719, target='ENSG00000115423', maf=0.285714),
#               SNPRes(rsid='chr2_84211610_C_T_b38', chrom=2, pos=84211610, logp=4.9214018236123485, target='ENSG00000115423', maf=0.276248),
#               SNPRes(rsid='chr2_84213179_T_G_b38', chrom=2, pos=84213179, logp=4.69702222500169, target='ENSG00000115423', maf=0.277108),
#               SNPRes(rsid='chr2_84213880_T_C_b38', chrom=2, pos=84213880, logp=4.69702222500169, target='ENSG00000115423', maf=0.277108),
#               SNPRes(rsid='chr2_84214222_G_A_b38', chrom=2, pos=84214222, logp=4.9333535978428005, target='ENSG00000115423', maf=0.277969),
#               SNPRes(rsid='chr2_84217319_A_G_b38', chrom=2, pos=84217319, logp=4.69702222500169, target='ENSG00000115423', maf=0.277108),
#               SNPRes(rsid='chr2_84217551_A_C_b38', chrom=2, pos=84217551, logp=4.69702222500169, target='ENSG00000115423', maf=0.277108),
#               SNPRes(rsid='chr2_84221215_T_C_b38', chrom=2, pos=84221215, logp=5.165679774307058, target='ENSG00000115423', maf=0.284854),
#               SNPRes(rsid='chr2_84225011_G_A_b38', chrom=2, pos=84225011, logp=5.123191181964685, target='ENSG00000115423', maf=0.283133),
#               SNPRes(rsid='chr2_84225086_C_A_b38', chrom=2, pos=84225086, logp=5.165679774307058, target='ENSG00000115423', maf=0.284854),
#               SNPRes(rsid='chr2_84232904_A_C_b38', chrom=2, pos=84232904, logp=5.262859857603598, target='ENSG00000115423', maf=0.283993),
#               SNPRes(rsid='chr2_84237103_A_G_b38', chrom=2, pos=84237103, logp=5.725052822127251, target='ENSG00000115423', maf=0.27883),
#               SNPRes(rsid='chr2_84243387_T_C_b38', chrom=2, pos=84243387, logp=5.540060464918941, target='ENSG00000115423', maf=0.27969),
#               SNPRes(rsid='chr2_84247081_T_C_b38', chrom=2, pos=84247081, logp=5.675197114926462, target='ENSG00000115423', maf=0.277969),
#               SNPRes(rsid='chr2_84247615_C_A_b38', chrom=2, pos=84247615, logp=5.595907267550753, target='ENSG00000115423', maf=0.277108),
#               SNPRes(rsid='chr2_84248096_T_G_b38', chrom=2, pos=84248096, logp=5.595907267550753, target='ENSG00000115423', maf=0.277108),
#               SNPRes(rsid='chr2_84248654_C_T_b38', chrom=2, pos=84248654, logp=5.595907267550753, target='ENSG00000115423', maf=0.277108),
#               SNPRes(rsid='chr2_84249811_A_G_b38', chrom=2, pos=84249811, logp=5.863710771423283, target='ENSG00000115423', maf=0.277969),
#               SNPRes(rsid='chr2_84250832_T_C_b38', chrom=2, pos=84250832, logp=5.947367609927441, target='ENSG00000115423', maf=0.27883),
#               SNPRes(rsid='chr2_84255772_T_C_b38', chrom=2, pos=84255772, logp=5.863710771423283, target='ENSG00000115423', maf=0.277969),
#               SNPRes(rsid='chr2_84262138_T_C_b38', chrom=2, pos=84262138, logp=5.675197114926462, target='ENSG00000115423', maf=0.277969),
#               SNPRes(rsid='chr2_84263152_C_T_b38', chrom=2, pos=84263152, logp=5.947367609927441, target='ENSG00000115423', maf=0.27883),
#               SNPRes(rsid='chr2_84278845_G_A_b38', chrom=2, pos=84278845, logp=5.947367609927441, target='ENSG00000115423', maf=0.27883),
#               SNPRes(rsid='chr2_84292539_G_T_b38', chrom=2, pos=84292539, logp=5.064791099209451, target='ENSG00000115423', maf=0.300344),
#               SNPRes(rsid='chr2_84295323_G_A_b38', chrom=2, pos=84295323, logp=6.484824501578756, target='ENSG00000115423', maf=0.301205),
#               SNPRes(rsid='chr2_84301632_T_C_b38', chrom=2, pos=84301632, logp=5.806293947809959, target='ENSG00000115423', maf=0.310671),
#               SNPRes(rsid='chr2_84305680_G_A_b38', chrom=2, pos=84305680, logp=5.8462034221239, target='ENSG00000115423', maf=0.301205),
#               SNPRes(rsid='chr2_84306251_T_C_b38', chrom=2, pos=84306251, logp=5.8462034221239, target='ENSG00000115423', maf=0.301205),
#               SNPRes(rsid='chr2_84307204_C_A_b38', chrom=2, pos=84307204, logp=5.739213331345024, target='ENSG00000115423', maf=0.299484),
#               SNPRes(rsid='chr2_84307854_C_T_b38', chrom=2, pos=84307854, logp=5.444014891429652, target='ENSG00000115423', maf=0.311532),
#               SNPRes(rsid='chr2_84308549_A_G_b38', chrom=2, pos=84308549, logp=5.642255674819625, target='ENSG00000115423', maf=0.311532),
#               SNPRes(rsid='chr2_84308773_G_A_b38', chrom=2, pos=84308773, logp=5.594513622493918, target='ENSG00000115423', maf=0.310671),
#               SNPRes(rsid='chr2_84310850_G_A_b38', chrom=2, pos=84310850, logp=5.966230555042972, target='ENSG00000115423', maf=0.315835),
#               SNPRes(rsid='chr2_84314440_C_T_b38', chrom=2, pos=84314440, logp=5.9037123424029305, target='ENSG00000115423', maf=0.314974),
#               SNPRes(rsid='chr2_84315354_T_C_b38', chrom=2, pos=84315354, logp=6.04370619950276, target='ENSG00000115423', maf=0.316695),
#               SNPRes(rsid='chr2_84317508_T_C_b38', chrom=2, pos=84317508, logp=5.7729132362908775, target='ENSG00000115423', maf=0.302065),
#               SNPRes(rsid='chr2_84317765_T_C_b38', chrom=2, pos=84317765, logp=5.7729132362908775, target='ENSG00000115423', maf=0.302065),
#               SNPRes(rsid='chr2_84317769_A_G_b38', chrom=2, pos=84317769, logp=5.749916828493535, target='ENSG00000115423', maf=0.314974),
#               SNPRes(rsid='chr2_84317935_C_T_b38', chrom=2, pos=84317935, logp=5.7729132362908775, target='ENSG00000115423', maf=0.302065),
#               SNPRes(rsid='chr2_84310850_G_A_b38', chrom=2, pos=84310850, logp=3.8968259493459043, target='ENSG00000186854', maf=0.315835),
#               SNPRes(rsid='chr2_84314440_C_T_b38', chrom=2, pos=84314440, logp=3.6983363968134637, target='ENSG00000186854', maf=0.314974),
#               SNPRes(rsid='chr2_84315354_T_C_b38', chrom=2, pos=84315354, logp=3.755690710427956, target='ENSG00000186854', maf=0.316695),
#               SNPRes(rsid='chr2_84317508_T_C_b38', chrom=2, pos=84317508, logp=3.98235740561338, target='ENSG00000186854', maf=0.302065),
#               SNPRes(rsid='chr2_84317765_T_C_b38', chrom=2, pos=84317765, logp=3.98235740561338, target='ENSG00000186854', maf=0.302065),
#               SNPRes(rsid='chr2_84317935_C_T_b38', chrom=2, pos=84317935, logp=3.98235740561338, target='ENSG00000186854', maf=0.302065),
#               SNPRes(rsid='chr2_131474964_C_T_b38', chrom=2, pos=131474964, logp=7.245827558584839, target='ENSG00000173272', maf=0.166954),
#               SNPRes(rsid='chr2_131475952_G_A_b38', chrom=2, pos=131475952, logp=7.486104843189927, target='ENSG00000173272', maf=0.167814),
#               SNPRes(rsid='chr2_131474964_C_T_b38', chrom=2, pos=131474964, logp=66.61348854977716, target='ENSG00000152117', maf=0.166954),
#               SNPRes(rsid='chr2_131475952_G_A_b38', chrom=2, pos=131475952, logp=70.00806810490091, target='ENSG00000152117', maf=0.167814),
#               SNPRes(rsid='chr2_131474964_C_T_b38', chrom=2, pos=131474964, logp=6.31890536175205, target='ENSG00000163040', maf=0.166954),
#               SNPRes(rsid='chr2_131475952_G_A_b38', chrom=2, pos=131475952, logp=6.098048813451035, target='ENSG00000163040', maf=0.167814),
#               SNPRes(rsid='chr3_48781943_G_T_b38', chrom=3, pos=48781943, logp=4.633976964568982, target='ENSG00000068745', maf=0.0791738),
#               SNPRes(rsid='chr3_48781943_G_T_b38', chrom=3, pos=48781943, logp=6.490523272999005, target='ENSG00000178252', maf=0.0791738),
#               SNPRes(rsid='chr3_50143000_T_C_b38', chrom=3, pos=50143000, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50149252_C_T_b38', chrom=3, pos=50149252, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50150204_T_C_b38', chrom=3, pos=50150204, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50155950_C_T_b38', chrom=3, pos=50155950, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50159659_C_T_b38', chrom=3, pos=50159659, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50162916_G_A_b38', chrom=3, pos=50162916, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50164880_G_A_b38', chrom=3, pos=50164880, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50165290_A_G_b38', chrom=3, pos=50165290, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50169777_A_C_b38', chrom=3, pos=50169777, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50172179_T_C_b38', chrom=3, pos=50172179, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50186941_T_C_b38', chrom=3, pos=50186941, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50200943_G_A_b38', chrom=3, pos=50200943, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50202031_C_T_b38', chrom=3, pos=50202031, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50204188_G_A_b38', chrom=3, pos=50204188, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50212067_G_A_b38', chrom=3, pos=50212067, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50216962_A_C_b38', chrom=3, pos=50216962, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50229696_C_A_b38', chrom=3, pos=50229696, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50235381_G_A_b38', chrom=3, pos=50235381, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50241181_G_A_b38', chrom=3, pos=50241181, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50244324_C_T_b38', chrom=3, pos=50244324, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50249828_T_G_b38', chrom=3, pos=50249828, logp=4.329049454414102, target='ENSG00000186792', maf=0.106713),
#               SNPRes(rsid='chr3_50250119_C_T_b38', chrom=3, pos=50250119, logp=4.007759835051512, target='ENSG00000186792', maf=0.100688),
#               SNPRes(rsid='chr3_50253398_A_G_b38', chrom=3, pos=50253398, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50254761_G_T_b38', chrom=3, pos=50254761, logp=4.6315457533309505, target='ENSG00000186792', maf=0.0929432),
#               SNPRes(rsid='chr3_50257119_A_G_b38', chrom=3, pos=50257119, logp=4.329049454414102, target='ENSG00000186792', maf=0.106713),
#               SNPRes(rsid='chr3_50261708_C_A_b38', chrom=3, pos=50261708, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50269619_C_T_b38', chrom=3, pos=50269619, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50271693_A_G_b38', chrom=3, pos=50271693, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50285741_C_T_b38', chrom=3, pos=50285741, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50303895_C_T_b38', chrom=3, pos=50303895, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50305190_C_T_b38', chrom=3, pos=50305190, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50314167_C_T_b38', chrom=3, pos=50314167, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50323371_G_A_b38', chrom=3, pos=50323371, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50336404_C_A_b38', chrom=3, pos=50336404, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50350079_A_C_b38', chrom=3, pos=50350079, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50361458_A_G_b38', chrom=3, pos=50361458, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50364410_G_A_b38', chrom=3, pos=50364410, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50372610_G_A_b38', chrom=3, pos=50372610, logp=3.242596378712471, target='ENSG00000186792', maf=0.0180723),
#               SNPRes(rsid='chr3_50376973_C_T_b38', chrom=3, pos=50376973, logp=3.332948838563166, target='ENSG00000186792', maf=0.0172117),
#               SNPRes(rsid='chr3_50380247_C_T_b38', chrom=3, pos=50380247, logp=3.086029406189079, target='ENSG00000186792', maf=0.0189329),
#               SNPRes(rsid='chr3_138933102_G_A_b38', chrom=3, pos=138933102, logp=3.6597403507538284, target='ENSG00000280399', maf=0.0180723),
#               SNPRes(rsid='chr3_138934554_C_T_b38', chrom=3, pos=138934554, logp=3.6597403507538284, target='ENSG00000280399', maf=0.0180723),
#               SNPRes(rsid='chr4_139367077_A_G_b38', chrom=4, pos=139367077, logp=10.875851311786716, target='ENSG00000109390', maf=0.301205),
#               SNPRes(rsid='chr5_33964105_T_G_b38', chrom=5, pos=33964105, logp=4.038626372405199, target='ENSG00000242110', maf=0.139415),
#               SNPRes(rsid='chr5_39699948_G_T_b38', chrom=5, pos=39699948, logp=3.941107283891963, target='ENSG00000250048', maf=0.0817556),
#               SNPRes(rsid='chr5_39700154_C_T_b38', chrom=5, pos=39700154, logp=3.941107283891963, target='ENSG00000250048', maf=0.0817556),
#               SNPRes(rsid='chr5_39700938_G_T_b38', chrom=5, pos=39700938, logp=3.941107283891963, target='ENSG00000250048', maf=0.0817556),
#               SNPRes(rsid='chr5_39701279_G_T_b38', chrom=5, pos=39701279, logp=3.941107283891963, target='ENSG00000250048', maf=0.0817556),
#               SNPRes(rsid='chr5_39702176_G_A_b38', chrom=5, pos=39702176, logp=3.941107283891963, target='ENSG00000250048', maf=0.0817556),
#               SNPRes(rsid='chr5_39704976_C_T_b38', chrom=5, pos=39704976, logp=3.941107283891963, target='ENSG00000250048', maf=0.0817556),
#               SNPRes(rsid='chr5_39706810_T_C_b38', chrom=5, pos=39706810, logp=3.941107283891963, target='ENSG00000250048', maf=0.0817556),
#               SNPRes(rsid='chr5_39706831_A_G_b38', chrom=5, pos=39706831, logp=3.941107283891963, target='ENSG00000250048', maf=0.0817556),
#               SNPRes(rsid='chr5_39707481_T_C_b38', chrom=5, pos=39707481, logp=3.941107283891963, target='ENSG00000250048', maf=0.0817556),
#               SNPRes(rsid='chr5_132743502_A_G_b38', chrom=5, pos=132743502, logp=21.03965672302108, target='ENSG00000131437', maf=0.185886),
#               SNPRes(rsid='chr5_132746205_A_G_b38', chrom=5, pos=132746205, logp=21.03965672302108, target='ENSG00000131437', maf=0.185886),
#               SNPRes(rsid='chr5_132749264_G_A_b38', chrom=5, pos=132749264, logp=19.62475350899281, target='ENSG00000131437', maf=0.185886),
#               SNPRes(rsid='chr5_132755136_T_C_b38', chrom=5, pos=132755136, logp=18.122134162596875, target='ENSG00000131437', maf=0.212565),
#               SNPRes(rsid='chr5_132789134_T_C_b38', chrom=5, pos=132789134, logp=16.658915822269975, target='ENSG00000131437', maf=0.207401),
#               SNPRes(rsid='chr6_143079531_A_G_b38', chrom=6, pos=143079531, logp=5.841939206063395, target='ENSG00000227192', maf=0.133391),
#               SNPRes(rsid='chr6_143079531_A_G_b38', chrom=6, pos=143079531, logp=4.52203414050442, target='ENSG00000146416', maf=0.133391),
#               SNPRes(rsid='chr6_169617611_G_A_b38', chrom=6, pos=169617611, logp=4.091889922977998, target='ENSG00000130023', maf=0.179002),
#               SNPRes(rsid='chr6_169621385_C_T_b38', chrom=6, pos=169621385, logp=4.091889922977998, target='ENSG00000130023', maf=0.179002),
#               SNPRes(rsid='chr10_18465566_T_C_b38', chrom=10, pos=18465566, logp=3.9028364330450604, target='ENSG00000241058', maf=0.244406),
#               SNPRes(rsid='chr10_89494542_T_C_b38', chrom=10, pos=89494542, logp=3.6830970284107063, target='ENSG00000138134', maf=0.0860585),
#               SNPRes(rsid='chr10_89494542_T_C_b38', chrom=10, pos=89494542, logp=4.423158980304397, target='ENSG00000152779', maf=0.0860585),
#               SNPRes(rsid='chr10_89499900_C_T_b38', chrom=10, pos=89499900, logp=4.00347037854562, target='ENSG00000152779', maf=0.0860585),
#               SNPRes(rsid='chr11_2301799_T_C_b38', chrom=11, pos=2301799, logp=8.974497517596776, target='ENSG00000110665', maf=0.0817556),
#               SNPRes(rsid='chr11_2302811_A_G_b38', chrom=11, pos=2302811, logp=8.70774614443735, target='ENSG00000110665', maf=0.0791738),
#               SNPRes(rsid='chr11_2307463_C_T_b38', chrom=11, pos=2307463, logp=8.773869437900192, target='ENSG00000110665', maf=0.0774527),
#               SNPRes(rsid='chr11_2307477_A_G_b38', chrom=11, pos=2307477, logp=8.745046094350839, target='ENSG00000110665', maf=0.0791738),
#               SNPRes(rsid='chr11_2307848_T_G_b38', chrom=11, pos=2307848, logp=8.357013453108634, target='ENSG00000110665', maf=0.0774527),
#               SNPRes(rsid='chr11_2307889_C_T_b38', chrom=11, pos=2307889, logp=8.357013453108634, target='ENSG00000110665', maf=0.0774527),
#               SNPRes(rsid='chr11_2309170_G_A_b38', chrom=11, pos=2309170, logp=7.457335129902486, target='ENSG00000110665', maf=0.0774527),
#               SNPRes(rsid='chr11_2309249_G_A_b38', chrom=11, pos=2309249, logp=7.457335129902486, target='ENSG00000110665', maf=0.0774527),
#               SNPRes(rsid='chr11_2309700_C_T_b38', chrom=11, pos=2309700, logp=7.457335129902486, target='ENSG00000110665', maf=0.0774527),
#               SNPRes(rsid='chr11_2309747_T_C_b38', chrom=11, pos=2309747, logp=7.457335129902486, target='ENSG00000110665', maf=0.0774527),
#               SNPRes(rsid='chr11_2309820_C_A_b38', chrom=11, pos=2309820, logp=7.457335129902486, target='ENSG00000110665', maf=0.0774527),
#               SNPRes(rsid='chr11_2309823_A_G_b38', chrom=11, pos=2309823, logp=7.457335129902486, target='ENSG00000110665', maf=0.0774527),
#               SNPRes(rsid='chr11_2309866_G_A_b38', chrom=11, pos=2309866, logp=7.457335129902486, target='ENSG00000110665', maf=0.0774527),
#               SNPRes(rsid='chr11_2309984_A_C_b38', chrom=11, pos=2309984, logp=7.457335129902486, target='ENSG00000110665', maf=0.0774527),
#               SNPRes(rsid='chr11_2917931_G_A_b38', chrom=11, pos=2917931, logp=11.013271697353563, target='ENSG00000110628', maf=0.0963855),
#               SNPRes(rsid='chr11_2918475_G_A_b38', chrom=11, pos=2918475, logp=11.013271697353563, target='ENSG00000110628', maf=0.0963855),
#               SNPRes(rsid='chr11_120213513_C_T_b38', chrom=11, pos=120213513, logp=5.160032625788768, target='ENSG00000137699', maf=0.0370052),
#               SNPRes(rsid='chr11_120213801_T_C_b38', chrom=11, pos=120213801, logp=5.160032625788768, target='ENSG00000137699', maf=0.0370052),
#               SNPRes(rsid='chr11_120226466_G_A_b38', chrom=11, pos=120226466, logp=4.262823265809409, target='ENSG00000137699', maf=0.0421687),
#               SNPRes(rsid='chr12_37415519_A_G_b38', chrom=12, pos=37415519, logp=6.3909106048999105, target='ENSG00000175548', maf=0.0490534),
#               SNPRes(rsid='chr13_49651403_C_T_b38', chrom=13, pos=49651403, logp=4.514782704373369, target='ENSG00000274270', maf=0.0309811),
#               SNPRes(rsid='chr13_49653360_T_G_b38', chrom=13, pos=49653360, logp=4.514782704373369, target='ENSG00000274270', maf=0.0309811),
#               SNPRes(rsid='chr13_49746825_T_C_b38', chrom=13, pos=49746825, logp=5.289610122308776, target='ENSG00000274270', maf=0.035284),
#               SNPRes(rsid='chr14_94121934_G_A_b38', chrom=14, pos=94121934, logp=4.0581364049365805, target='ENSG00000133937', maf=0.0567986),
#               SNPRes(rsid='chr15_40284286_C_T_b38', chrom=15, pos=40284286, logp=3.912009291333857, target='ENSG00000137843', maf=0.0172117),
#               SNPRes(rsid='chr15_78756895_C_T_b38', chrom=15, pos=78756895, logp=5.249133055268177, target='ENSG00000261143', maf=0.260757),
#               SNPRes(rsid='chr15_78758922_C_T_b38', chrom=15, pos=78758922, logp=5.249133055268177, target='ENSG00000261143', maf=0.260757),
#               SNPRes(rsid='chr15_78759111_G_A_b38', chrom=15, pos=78759111, logp=5.249133055268177, target='ENSG00000261143', maf=0.260757),
#               SNPRes(rsid='chr16_10860932_C_T_b38', chrom=16, pos=10860932, logp=5.02601825788597, target='ENSG00000179583', maf=0.345955),
#               SNPRes(rsid='chr16_21979439_T_C_b38', chrom=16, pos=21979439, logp=8.457643964203715, target='ENSG00000260306', maf=0.315835),
#               SNPRes(rsid='chr16_21979439_T_C_b38', chrom=16, pos=21979439, logp=3.6426369693848573, target='ENSG00000248124', maf=0.315835),
#               SNPRes(rsid='chr16_29605798_A_C_b38', chrom=16, pos=29605798, logp=6.754687252358704, target='ENSG00000169203', maf=0.373494),
#               SNPRes(rsid='chr16_29605798_A_C_b38', chrom=16, pos=29605798, logp=5.416242558935648, target='ENSG00000205534', maf=0.373494),
#               SNPRes(rsid='chr16_29605798_A_C_b38', chrom=16, pos=29605798, logp=5.623328165437885, target='ENSG00000279583', maf=0.373494),
#               SNPRes(rsid='chr16_71531679_A_G_b38', chrom=16, pos=71531679, logp=5.8204884231486425, target='ENSG00000140832', maf=0.276248),
#               SNPRes(rsid='chr16_71531679_A_G_b38', chrom=16, pos=71531679, logp=4.263182953721987, target='ENSG00000166747', maf=0.276248),
#               SNPRes(rsid='chr17_19020505_G_A_b38', chrom=17, pos=19020505, logp=5.232675645498686, target='ENSG00000279825', maf=0.309811),
#               SNPRes(rsid='chr17_19238913_C_T_b38', chrom=17, pos=19238913, logp=11.38712187983071, target='ENSG00000279825', maf=0.247849),
#               SNPRes(rsid='chr17_19268883_T_G_b38', chrom=17, pos=19268883, logp=6.948639066216026, target='ENSG00000279825', maf=0.296041),
#               SNPRes(rsid='chr17_19269192_A_G_b38', chrom=17, pos=19269192, logp=6.948639066216026, target='ENSG00000279825', maf=0.296041),
#               SNPRes(rsid='chr17_19271561_T_C_b38', chrom=17, pos=19271561, logp=7.0582476355542, target='ENSG00000279825', maf=0.297762),
#               SNPRes(rsid='chr17_19272004_A_G_b38', chrom=17, pos=19272004, logp=6.948639066216026, target='ENSG00000279825', maf=0.296041),
#               SNPRes(rsid='chr17_19301550_T_C_b38', chrom=17, pos=19301550, logp=6.948639066216026, target='ENSG00000279825', maf=0.296041),
#               SNPRes(rsid='chr17_19313948_C_T_b38', chrom=17, pos=19313948, logp=6.948639066216026, target='ENSG00000279825', maf=0.296041),
#               SNPRes(rsid='chr17_19317353_G_A_b38', chrom=17, pos=19317353, logp=7.289413883772641, target='ENSG00000279825', maf=0.296902),
#               SNPRes(rsid='chr17_19336119_C_T_b38', chrom=17, pos=19336119, logp=6.828241377576568, target='ENSG00000279825', maf=0.297762),
#               SNPRes(rsid='chr17_19338192_G_A_b38', chrom=17, pos=19338192, logp=6.948639066216026, target='ENSG00000279825', maf=0.296041),
#               SNPRes(rsid='chr17_19343762_G_A_b38', chrom=17, pos=19343762, logp=6.392645787697912, target='ENSG00000279825', maf=0.295181),
#               SNPRes(rsid='chr17_19353811_A_G_b38', chrom=17, pos=19353811, logp=6.687317107588747, target='ENSG00000279825', maf=0.295181),
#               SNPRes(rsid='chr17_19378515_T_G_b38', chrom=17, pos=19378515, logp=6.077242892068766, target='ENSG00000279825', maf=0.324441),
#               SNPRes(rsid='chr17_19388755_A_G_b38', chrom=17, pos=19388755, logp=5.938396750391624, target='ENSG00000279825', maf=0.32358),
#               SNPRes(rsid='chr17_19390414_G_A_b38', chrom=17, pos=19390414, logp=5.938396750391624, target='ENSG00000279825', maf=0.32358),
#               SNPRes(rsid='chr17_19391511_G_T_b38', chrom=17, pos=19391511, logp=10.78691010759294, target='ENSG00000279825', maf=0.2642),
#               SNPRes(rsid='chr17_19392137_G_T_b38', chrom=17, pos=19392137, logp=5.7464972266883345, target='ENSG00000279825', maf=0.327022),
#               SNPRes(rsid='chr17_19020505_G_A_b38', chrom=17, pos=19020505, logp=5.355530882968063, target='ENSG00000265185', maf=0.309811),
#               SNPRes(rsid='chr17_19238913_C_T_b38', chrom=17, pos=19238913, logp=8.26811482324403, target='ENSG00000265185', maf=0.247849),
#               SNPRes(rsid='chr17_19268883_T_G_b38', chrom=17, pos=19268883, logp=7.304486803279982, target='ENSG00000265185', maf=0.296041),
#               SNPRes(rsid='chr17_19269192_A_G_b38', chrom=17, pos=19269192, logp=7.304486803279982, target='ENSG00000265185', maf=0.296041),
#               SNPRes(rsid='chr17_19271561_T_C_b38', chrom=17, pos=19271561, logp=7.429687110319394, target='ENSG00000265185', maf=0.297762),
#               SNPRes(rsid='chr17_19272004_A_G_b38', chrom=17, pos=19272004, logp=7.304486803279982, target='ENSG00000265185', maf=0.296041),
#               SNPRes(rsid='chr17_19301550_T_C_b38', chrom=17, pos=19301550, logp=7.304486803279982, target='ENSG00000265185', maf=0.296041),
#               SNPRes(rsid='chr17_19313948_C_T_b38', chrom=17, pos=19313948, logp=7.304486803279982, target='ENSG00000265185', maf=0.296041),
#               SNPRes(rsid='chr17_19317353_G_A_b38', chrom=17, pos=19317353, logp=7.711350656471256, target='ENSG00000265185', maf=0.296902),
#               SNPRes(rsid='chr17_19336119_C_T_b38', chrom=17, pos=19336119, logp=7.449373013047116, target='ENSG00000265185', maf=0.297762),
#               SNPRes(rsid='chr17_19338192_G_A_b38', chrom=17, pos=19338192, logp=7.304486803279982, target='ENSG00000265185', maf=0.296041),
#               SNPRes(rsid='chr17_19343762_G_A_b38', chrom=17, pos=19343762, logp=7.571819834290984, target='ENSG00000265185', maf=0.295181),
#               SNPRes(rsid='chr17_19353811_A_G_b38', chrom=17, pos=19353811, logp=7.376046070031765, target='ENSG00000265185', maf=0.295181),
#               SNPRes(rsid='chr17_19378515_T_G_b38', chrom=17, pos=19378515, logp=6.025910372037221, target='ENSG00000265185', maf=0.324441),
#               SNPRes(rsid='chr17_19388755_A_G_b38', chrom=17, pos=19388755, logp=6.1479062854115805, target='ENSG00000265185', maf=0.32358),
#               SNPRes(rsid='chr17_19390414_G_A_b38', chrom=17, pos=19390414, logp=6.1479062854115805, target='ENSG00000265185', maf=0.32358),
#               SNPRes(rsid='chr17_19391511_G_T_b38', chrom=17, pos=19391511, logp=6.401653860444893, target='ENSG00000265185', maf=0.2642),
#               SNPRes(rsid='chr17_19392137_G_T_b38', chrom=17, pos=19392137, logp=5.743222139899377, target='ENSG00000265185', maf=0.327022),
#               SNPRes(rsid='chr17_19020505_G_A_b38', chrom=17, pos=19020505, logp=11.091491926594124, target='ENSG00000262074', maf=0.309811),
#               SNPRes(rsid='chr17_19238913_C_T_b38', chrom=17, pos=19238913, logp=7.3230577708171465, target='ENSG00000262074', maf=0.247849),
#               SNPRes(rsid='chr17_19268883_T_G_b38', chrom=17, pos=19268883, logp=12.86780116720427, target='ENSG00000262074', maf=0.296041),
#               SNPRes(rsid='chr17_19269192_A_G_b38', chrom=17, pos=19269192, logp=12.86780116720427, target='ENSG00000262074', maf=0.296041),
#               SNPRes(rsid='chr17_19271561_T_C_b38', chrom=17, pos=19271561, logp=12.726371480826549, target='ENSG00000262074', maf=0.297762),
#               SNPRes(rsid='chr17_19272004_A_G_b38', chrom=17, pos=19272004, logp=12.86780116720427, target='ENSG00000262074', maf=0.296041),
#               SNPRes(rsid='chr17_19301550_T_C_b38', chrom=17, pos=19301550, logp=12.86780116720427, target='ENSG00000262074', maf=0.296041),
#               SNPRes(rsid='chr17_19313948_C_T_b38', chrom=17, pos=19313948, logp=12.86780116720427, target='ENSG00000262074', maf=0.296041),
#               SNPRes(rsid='chr17_19317353_G_A_b38', chrom=17, pos=19317353, logp=12.277079110223925, target='ENSG00000262074', maf=0.296902),
#               SNPRes(rsid='chr17_19336119_C_T_b38', chrom=17, pos=19336119, logp=12.782416047966478, target='ENSG00000262074', maf=0.297762),
#               SNPRes(rsid='chr17_19338192_G_A_b38', chrom=17, pos=19338192, logp=12.86780116720427, target='ENSG00000262074', maf=0.296041),
#               SNPRes(rsid='chr17_19343762_G_A_b38', chrom=17, pos=19343762, logp=12.686394278321632, target='ENSG00000262074', maf=0.295181),
#               SNPRes(rsid='chr17_19353811_A_G_b38', chrom=17, pos=19353811, logp=12.693871036988952, target='ENSG00000262074', maf=0.295181),
#               SNPRes(rsid='chr17_19378515_T_G_b38', chrom=17, pos=19378515, logp=8.207452832892074, target='ENSG00000262074', maf=0.324441),
#               SNPRes(rsid='chr17_19388755_A_G_b38', chrom=17, pos=19388755, logp=7.9160353818647975, target='ENSG00000262074', maf=0.32358),
#               SNPRes(rsid='chr17_19390414_G_A_b38', chrom=17, pos=19390414, logp=7.9160353818647975, target='ENSG00000262074', maf=0.32358),
#               SNPRes(rsid='chr17_19391511_G_T_b38', chrom=17, pos=19391511, logp=5.152937813383845, target='ENSG00000262074', maf=0.2642),
#               SNPRes(rsid='chr17_19392137_G_T_b38', chrom=17, pos=19392137, logp=8.022888037554859, target='ENSG00000262074', maf=0.327022),
#               SNPRes(rsid='chr17_19020505_G_A_b38', chrom=17, pos=19020505, logp=8.893340032427442, target='ENSG00000228157', maf=0.309811),
#               SNPRes(rsid='chr17_19238913_C_T_b38', chrom=17, pos=19238913, logp=29.912548686263996, target='ENSG00000228157', maf=0.247849),
#               SNPRes(rsid='chr17_19268883_T_G_b38', chrom=17, pos=19268883, logp=17.365652735347247, target='ENSG00000228157', maf=0.296041),
#               SNPRes(rsid='chr17_19269192_A_G_b38', chrom=17, pos=19269192, logp=17.365652735347247, target='ENSG00000228157', maf=0.296041),
#               SNPRes(rsid='chr17_19271561_T_C_b38', chrom=17, pos=19271561, logp=17.412765112002006, target='ENSG00000228157', maf=0.297762),
#               SNPRes(rsid='chr17_19272004_A_G_b38', chrom=17, pos=19272004, logp=17.365652735347247, target='ENSG00000228157', maf=0.296041),
#               SNPRes(rsid='chr17_19301550_T_C_b38', chrom=17, pos=19301550, logp=17.365652735347247, target='ENSG00000228157', maf=0.296041),
#               SNPRes(rsid='chr17_19313948_C_T_b38', chrom=17, pos=19313948, logp=17.365652735347247, target='ENSG00000228157', maf=0.296041),
#               SNPRes(rsid='chr17_19317353_G_A_b38', chrom=17, pos=19317353, logp=17.375357001742742, target='ENSG00000228157', maf=0.296902),
#               SNPRes(rsid='chr17_19336119_C_T_b38', chrom=17, pos=19336119, logp=17.326160146189537, target='ENSG00000228157', maf=0.297762),
#               SNPRes(rsid='chr17_19338192_G_A_b38', chrom=17, pos=19338192, logp=17.365652735347247, target='ENSG00000228157', maf=0.296041),
#               SNPRes(rsid='chr17_19343762_G_A_b38', chrom=17, pos=19343762, logp=17.466085656611046, target='ENSG00000228157', maf=0.295181),
#               SNPRes(rsid='chr17_19353811_A_G_b38', chrom=17, pos=19353811, logp=16.99657824591471, target='ENSG00000228157', maf=0.295181),
#               SNPRes(rsid='chr17_19378515_T_G_b38', chrom=17, pos=19378515, logp=13.191900485528702, target='ENSG00000228157', maf=0.324441),
#               SNPRes(rsid='chr17_19388755_A_G_b38', chrom=17, pos=19388755, logp=13.008069432216928, target='ENSG00000228157', maf=0.32358),
#               SNPRes(rsid='chr17_19390414_G_A_b38', chrom=17, pos=19390414, logp=13.008069432216928, target='ENSG00000228157', maf=0.32358),
#               SNPRes(rsid='chr17_19391511_G_T_b38', chrom=17, pos=19391511, logp=25.262109547224703, target='ENSG00000228157', maf=0.2642),
#               SNPRes(rsid='chr17_19392137_G_T_b38', chrom=17, pos=19392137, logp=12.605912718992803, target='ENSG00000228157', maf=0.327022),
#               SNPRes(rsid='chr17_19020505_G_A_b38', chrom=17, pos=19020505, logp=3.7088088114375397, target='ENSG00000262202', maf=0.309811),
#               SNPRes(rsid='chr17_19020505_G_A_b38', chrom=17, pos=19020505, logp=19.298518364379074, target='ENSG00000262319', maf=0.309811),
#               SNPRes(rsid='chr17_19238913_C_T_b38', chrom=17, pos=19238913, logp=21.19480237027155, target='ENSG00000262319', maf=0.247849),
#               SNPRes(rsid='chr17_19268883_T_G_b38', chrom=17, pos=19268883, logp=26.450062905396518, target='ENSG00000262319', maf=0.296041),
#               SNPRes(rsid='chr17_19269192_A_G_b38', chrom=17, pos=19269192, logp=26.450062905396518, target='ENSG00000262319', maf=0.296041),
#               SNPRes(rsid='chr17_19271561_T_C_b38', chrom=17, pos=19271561, logp=25.48089161529806, target='ENSG00000262319', maf=0.297762),
#               SNPRes(rsid='chr17_19272004_A_G_b38', chrom=17, pos=19272004, logp=26.450062905396518, target='ENSG00000262319', maf=0.296041),
#               SNPRes(rsid='chr17_19301550_T_C_b38', chrom=17, pos=19301550, logp=26.450062905396518, target='ENSG00000262319', maf=0.296041),
#               SNPRes(rsid='chr17_19313948_C_T_b38', chrom=17, pos=19313948, logp=26.450062905396518, target='ENSG00000262319', maf=0.296041),
#               SNPRes(rsid='chr17_19317353_G_A_b38', chrom=17, pos=19317353, logp=26.206011365335698, target='ENSG00000262319', maf=0.296902),
#               SNPRes(rsid='chr17_19336119_C_T_b38', chrom=17, pos=19336119, logp=26.079717496372833, target='ENSG00000262319', maf=0.297762),
#               SNPRes(rsid='chr17_19338192_G_A_b38', chrom=17, pos=19338192, logp=26.450062905396518, target='ENSG00000262319', maf=0.296041),
#               SNPRes(rsid='chr17_19343762_G_A_b38', chrom=17, pos=19343762, logp=25.78818823622509, target='ENSG00000262319', maf=0.295181),
#               SNPRes(rsid='chr17_19353811_A_G_b38', chrom=17, pos=19353811, logp=26.440936460852345, target='ENSG00000262319', maf=0.295181),
#               SNPRes(rsid='chr17_19378515_T_G_b38', chrom=17, pos=19378515, logp=26.249753186270887, target='ENSG00000262319', maf=0.324441),
#               SNPRes(rsid='chr17_19388755_A_G_b38', chrom=17, pos=19388755, logp=26.5885132960442, target='ENSG00000262319', maf=0.32358),
#               SNPRes(rsid='chr17_19390414_G_A_b38', chrom=17, pos=19390414, logp=26.5885132960442, target='ENSG00000262319', maf=0.32358),
#               SNPRes(rsid='chr17_19391511_G_T_b38', chrom=17, pos=19391511, logp=20.539297558574546, target='ENSG00000262319', maf=0.2642),
#               SNPRes(rsid='chr17_19392137_G_T_b38', chrom=17, pos=19392137, logp=27.110604724119003, target='ENSG00000262319', maf=0.327022),
#               SNPRes(rsid='chr17_19020505_G_A_b38', chrom=17, pos=19020505, logp=3.982987540745547, target='ENSG00000263934', maf=0.309811),
#               SNPRes(rsid='chr17_19020505_G_A_b38', chrom=17, pos=19020505, logp=15.99714307393888, target='ENSG00000072134', maf=0.309811),
#               SNPRes(rsid='chr17_19238913_C_T_b38', chrom=17, pos=19238913, logp=23.852506086833177, target='ENSG00000072134', maf=0.247849),
#               SNPRes(rsid='chr17_19268883_T_G_b38', chrom=17, pos=19268883, logp=31.886601527828294, target='ENSG00000072134', maf=0.296041),
#               SNPRes(rsid='chr17_19269192_A_G_b38', chrom=17, pos=19269192, logp=31.886601527828294, target='ENSG00000072134', maf=0.296041),
#               SNPRes(rsid='chr17_19271561_T_C_b38', chrom=17, pos=19271561, logp=31.446674149519435, target='ENSG00000072134', maf=0.297762),
#               SNPRes(rsid='chr17_19272004_A_G_b38', chrom=17, pos=19272004, logp=31.886601527828294, target='ENSG00000072134', maf=0.296041),
#               SNPRes(rsid='chr17_19301550_T_C_b38', chrom=17, pos=19301550, logp=31.886601527828294, target='ENSG00000072134', maf=0.296041),
#               SNPRes(rsid='chr17_19313948_C_T_b38', chrom=17, pos=19313948, logp=31.886601527828294, target='ENSG00000072134', maf=0.296041),
#               SNPRes(rsid='chr17_19317353_G_A_b38', chrom=17, pos=19317353, logp=31.401764475655856, target='ENSG00000072134', maf=0.296902),
#               SNPRes(rsid='chr17_19336119_C_T_b38', chrom=17, pos=19336119, logp=31.544162730868536, target='ENSG00000072134', maf=0.297762),
#               SNPRes(rsid='chr17_19338192_G_A_b38', chrom=17, pos=19338192, logp=31.886601527828294, target='ENSG00000072134', maf=0.296041),
#               SNPRes(rsid='chr17_19343762_G_A_b38', chrom=17, pos=19343762, logp=31.859542239986297, target='ENSG00000072134', maf=0.295181),
#               SNPRes(rsid='chr17_19353811_A_G_b38', chrom=17, pos=19353811, logp=31.756418802575723, target='ENSG00000072134', maf=0.295181),
#               SNPRes(rsid='chr17_19378515_T_G_b38', chrom=17, pos=19378515, logp=26.675491194252942, target='ENSG00000072134', maf=0.324441),
#               SNPRes(rsid='chr17_19388755_A_G_b38', chrom=17, pos=19388755, logp=26.442847837561427, target='ENSG00000072134', maf=0.32358),
#               SNPRes(rsid='chr17_19390414_G_A_b38', chrom=17, pos=19390414, logp=26.442847837561427, target='ENSG00000072134', maf=0.32358),
#               SNPRes(rsid='chr17_19391511_G_T_b38', chrom=17, pos=19391511, logp=21.457503218112002, target='ENSG00000072134', maf=0.2642),
#               SNPRes(rsid='chr17_19392137_G_T_b38', chrom=17, pos=19392137, logp=27.151178075145985, target='ENSG00000072134', maf=0.327022),
#               SNPRes(rsid='chr17_19238913_C_T_b38', chrom=17, pos=19238913, logp=3.9923844929151957, target='ENSG00000108641', maf=0.247849),
#               SNPRes(rsid='chr17_19268883_T_G_b38', chrom=17, pos=19268883, logp=5.694208109647283, target='ENSG00000108641', maf=0.296041),
#               SNPRes(rsid='chr17_19269192_A_G_b38', chrom=17, pos=19269192, logp=5.694208109647283, target='ENSG00000108641', maf=0.296041),
#               SNPRes(rsid='chr17_19271561_T_C_b38', chrom=17, pos=19271561, logp=5.491192959781508, target='ENSG00000108641', maf=0.297762),
#               SNPRes(rsid='chr17_19272004_A_G_b38', chrom=17, pos=19272004, logp=5.694208109647283, target='ENSG00000108641', maf=0.296041),
#               SNPRes(rsid='chr17_19301550_T_C_b38', chrom=17, pos=19301550, logp=5.694208109647283, target='ENSG00000108641', maf=0.296041),
#               SNPRes(rsid='chr17_19313948_C_T_b38', chrom=17, pos=19313948, logp=5.694208109647283, target='ENSG00000108641', maf=0.296041),
#               SNPRes(rsid='chr17_19317353_G_A_b38', chrom=17, pos=19317353, logp=5.378988947792443, target='ENSG00000108641', maf=0.296902),
#               SNPRes(rsid='chr17_19336119_C_T_b38', chrom=17, pos=19336119, logp=5.6194450778457865, target='ENSG00000108641', maf=0.297762),
#               SNPRes(rsid='chr17_19338192_G_A_b38', chrom=17, pos=19338192, logp=5.694208109647283, target='ENSG00000108641', maf=0.296041),
#               SNPRes(rsid='chr17_19343762_G_A_b38', chrom=17, pos=19343762, logp=5.422133811314928, target='ENSG00000108641', maf=0.295181),
#               SNPRes(rsid='chr17_19353811_A_G_b38', chrom=17, pos=19353811, logp=5.767148678567981, target='ENSG00000108641', maf=0.295181),
#               SNPRes(rsid='chr17_19378515_T_G_b38', chrom=17, pos=19378515, logp=4.973626101352703, target='ENSG00000108641', maf=0.324441),
#               SNPRes(rsid='chr17_19388755_A_G_b38', chrom=17, pos=19388755, logp=5.205124537536084, target='ENSG00000108641', maf=0.32358),
#               SNPRes(rsid='chr17_19390414_G_A_b38', chrom=17, pos=19390414, logp=5.205124537536084, target='ENSG00000108641', maf=0.32358),
#               SNPRes(rsid='chr17_19391511_G_T_b38', chrom=17, pos=19391511, logp=3.6571570465740115, target='ENSG00000108641', maf=0.2642),
#               SNPRes(rsid='chr17_19392137_G_T_b38', chrom=17, pos=19392137, logp=5.074938138322538, target='ENSG00000108641', maf=0.327022),
#               SNPRes(rsid='chr17_60439553_G_A_b38', chrom=17, pos=60439553, logp=3.722166248187536, target='ENSG00000266992', maf=0.0895009),
#               SNPRes(rsid='chr19_7882640_C_T_b38', chrom=19, pos=7882640, logp=8.28396408550045, target='ENSG00000142459', maf=0.194492),
#               SNPRes(rsid='chr19_18216532_C_T_b38', chrom=19, pos=18216532, logp=4.595688092075895, target='ENSG00000268650', maf=0.0714286),
#               SNPRes(rsid='chr19_39387366_G_A_b38', chrom=19, pos=39387366, logp=5.224313111243299, target='ENSG00000128011', maf=0.182444),
#               SNPRes(rsid='chr22_41435263_A_C_b38', chrom=22, pos=41435263, logp=3.7957850258154786, target='ENSG00000100413', maf=0.0309811)],
#              'av': [SNPRes(rsid='chr1_1387698_A_G_b38', chrom=1, pos=1387698, logp=4.122903487051224, target='ENSG00000184163', maf=0.26226),
#               SNPRes(rsid='chr1_1411323_A_C_b38', chrom=1, pos=1411323, logp=4.306847508360431, target='ENSG00000184163', maf=0.26226),
#               SNPRes(rsid='chr1_1387698_A_G_b38', chrom=1, pos=1387698, logp=5.091566456110376, target='ENSG00000127054', maf=0.26226),
#               SNPRes(rsid='chr1_1411323_A_C_b38', chrom=1, pos=1411323, logp=4.551554953572729, target='ENSG00000127054', maf=0.26226),
#               SNPRes(rsid='chr1_1387698_A_G_b38', chrom=1, pos=1387698, logp=18.824241827746707, target='ENSG00000242485', maf=0.26226),
#               SNPRes(rsid='chr1_1411323_A_C_b38', chrom=1, pos=1411323, logp=18.655022511029312, target='ENSG00000242485', maf=0.26226),
#               SNPRes(rsid='chr1_1387698_A_G_b38', chrom=1, pos=1387698, logp=18.618287611008864, target='ENSG00000235098', maf=0.26226),
#               SNPRes(rsid='chr1_1411323_A_C_b38', chrom=1, pos=1411323, logp=19.831378786693808, target='ENSG00000235098', maf=0.26226),
#               SNPRes(rsid='chr1_1519934_T_G_b38', chrom=1, pos=1519934, logp=4.135389849397229, target='ENSG00000235098', maf=0.317697),
#               SNPRes(rsid='chr1_1519938_T_C_b38', chrom=1, pos=1519938, logp=4.135389849397229, target='ENSG00000235098', maf=0.317697),
#               SNPRes(rsid='chr1_1519934_T_G_b38', chrom=1, pos=1519934, logp=5.221731505933428, target='ENSG00000197785', maf=0.317697),
#               SNPRes(rsid='chr1_1519938_T_C_b38', chrom=1, pos=1519938, logp=5.221731505933428, target='ENSG00000197785', maf=0.317697),
#               SNPRes(rsid='chr1_35029209_T_G_b38', chrom=1, pos=35029209, logp=5.154911266395781, target='ENSG00000197056', maf=0.158849),
#               SNPRes(rsid='chr1_35438311_A_G_b38', chrom=1, pos=35438311, logp=4.405284887536836, target='ENSG00000142686', maf=0.178038),
#               SNPRes(rsid='chr1_35460549_T_C_b38', chrom=1, pos=35460549, logp=6.090947552148362, target='ENSG00000142686', maf=0.214286),
#               SNPRes(rsid='chr1_35485437_A_G_b38', chrom=1, pos=35485437, logp=4.222342678446882, target='ENSG00000142686', maf=0.176972),
#               SNPRes(rsid='chr1_35571621_A_G_b38', chrom=1, pos=35571621, logp=5.8203161023012715, target='ENSG00000142686', maf=0.214286),
#               SNPRes(rsid='chr1_35666945_C_T_b38', chrom=1, pos=35666945, logp=7.006989895717758, target='ENSG00000142686', maf=0.190832),
#               SNPRes(rsid='chr2_10374170_C_T_b38', chrom=2, pos=10374170, logp=4.192352015938839, target='ENSG00000260077', maf=0.0938166),
#               SNPRes(rsid='chr2_152319675_G_A_b38', chrom=2, pos=152319675, logp=3.9199257498788556, target='ENSG00000115145', maf=0.498934),
#               SNPRes(rsid='chr2_152340776_C_T_b38', chrom=2, pos=152340776, logp=3.9199257498788556, target='ENSG00000115145', maf=0.498934),
#               SNPRes(rsid='chr2_152350372_T_C_b38', chrom=2, pos=152350372, logp=4.498883200999932, target='ENSG00000115145', maf=0.484009),
#               SNPRes(rsid='chr2_189962297_A_G_b38', chrom=2, pos=189962297, logp=7.308997236415555, target='ENSG00000128699', maf=0.369936),
#               SNPRes(rsid='chr4_38797027_C_A_b38', chrom=4, pos=38797027, logp=4.780611972310432, target='ENSG00000197712', maf=0.373134),
#               SNPRes(rsid='chr5_1006946_G_A_b38', chrom=5, pos=1006946, logp=5.58546617993845, target='ENSG00000215246', maf=0.197228),
#               SNPRes(rsid='chr5_1012168_C_T_b38', chrom=5, pos=1012168, logp=5.807028545287861, target='ENSG00000215246', maf=0.195096),
#               SNPRes(rsid='chr5_1013579_T_C_b38', chrom=5, pos=1013579, logp=5.58546617993845, target='ENSG00000215246', maf=0.197228),
#               SNPRes(rsid='chr5_132697920_C_T_b38', chrom=5, pos=132697920, logp=10.871642740964724, target='ENSG00000131437', maf=0.236674),
#               SNPRes(rsid='chr5_132743502_A_G_b38', chrom=5, pos=132743502, logp=9.271176459970182, target='ENSG00000131437', maf=0.181237),
#               SNPRes(rsid='chr5_132746205_A_G_b38', chrom=5, pos=132746205, logp=9.271176459970182, target='ENSG00000131437', maf=0.181237),
#               SNPRes(rsid='chr5_132749264_G_A_b38', chrom=5, pos=132749264, logp=9.516086213513898, target='ENSG00000131437', maf=0.182303),
#               SNPRes(rsid='chr5_132755136_T_C_b38', chrom=5, pos=132755136, logp=12.04067569256622, target='ENSG00000131437', maf=0.208955),
#               SNPRes(rsid='chr5_132757957_T_C_b38', chrom=5, pos=132757957, logp=12.04067569256622, target='ENSG00000131437', maf=0.208955),
#               SNPRes(rsid='chr5_132759282_G_A_b38', chrom=5, pos=132759282, logp=12.04067569256622, target='ENSG00000131437', maf=0.208955),
#               SNPRes(rsid='chr5_132762728_A_C_b38', chrom=5, pos=132762728, logp=11.919842689029815, target='ENSG00000131437', maf=0.197228),
#               SNPRes(rsid='chr5_132763546_A_G_b38', chrom=5, pos=132763546, logp=11.07800364765545, target='ENSG00000131437', maf=0.202559),
#               SNPRes(rsid='chr5_132764307_A_G_b38', chrom=5, pos=132764307, logp=12.04067569256622, target='ENSG00000131437', maf=0.208955),
#               SNPRes(rsid='chr5_132764780_T_C_b38', chrom=5, pos=132764780, logp=11.145207092495678, target='ENSG00000131437', maf=0.206823),
#               SNPRes(rsid='chr5_132766211_G_A_b38', chrom=5, pos=132766211, logp=10.140044340830624, target='ENSG00000131437', maf=0.186567),
#               SNPRes(rsid='chr5_132767579_G_A_b38', chrom=5, pos=132767579, logp=11.07800364765545, target='ENSG00000131437', maf=0.202559),
#               SNPRes(rsid='chr5_132771359_G_T_b38', chrom=5, pos=132771359, logp=11.07800364765545, target='ENSG00000131437', maf=0.202559),
#               SNPRes(rsid='chr5_132771703_A_G_b38', chrom=5, pos=132771703, logp=11.07800364765545, target='ENSG00000131437', maf=0.202559),
#               SNPRes(rsid='chr5_132772334_G_A_b38', chrom=5, pos=132772334, logp=11.07800364765545, target='ENSG00000131437', maf=0.202559),
#               SNPRes(rsid='chr5_132773793_A_G_b38', chrom=5, pos=132773793, logp=11.07800364765545, target='ENSG00000131437', maf=0.202559),
#               SNPRes(rsid='chr5_132773927_T_C_b38', chrom=5, pos=132773927, logp=11.07800364765545, target='ENSG00000131437', maf=0.202559),
#               SNPRes(rsid='chr5_132774050_G_A_b38', chrom=5, pos=132774050, logp=11.07800364765545, target='ENSG00000131437', maf=0.202559),
#               SNPRes(rsid='chr5_132774274_T_C_b38', chrom=5, pos=132774274, logp=11.07800364765545, target='ENSG00000131437', maf=0.202559),
# ...
#               SNPRes(rsid='chr18_8790588_A_G_b38', chrom=18, pos=8790588, logp=7.109573950790205, target='ENSG00000272788', maf=0.423913),
#               SNPRes(rsid='chr18_73171355_T_C_b38', chrom=18, pos=73171355, logp=5.528063195405271, target='ENSG00000263711', maf=0.161491),
#               SNPRes(rsid='chr19_2889168_C_T_b38', chrom=19, pos=2889168, logp=4.594950899377506, target='ENSG00000253392', maf=0.175466),
#               SNPRes(rsid='chr19_4539074_A_G_b38', chrom=19, pos=4539074, logp=4.7403392382254, target='ENSG00000105251', maf=0.192547),
#               SNPRes(rsid='chr19_4541391_T_C_b38', chrom=19, pos=4541391, logp=4.660361762801013, target='ENSG00000105251', maf=0.184783),
#               SNPRes(rsid='chr19_5799795_A_G_b38', chrom=19, pos=5799795, logp=35.68355785169179, target='ENSG00000141994', maf=0.223602),
#               SNPRes(rsid='chr20_2846822_G_A_b38', chrom=20, pos=2846822, logp=20.720755238395636, target='ENSG00000215305', maf=0.39441),
#               SNPRes(rsid='chr20_2853133_G_A_b38', chrom=20, pos=2853133, logp=20.720755238395636, target='ENSG00000215305', maf=0.39441),
#               SNPRes(rsid='chr20_2855611_T_C_b38', chrom=20, pos=2855611, logp=20.819983142416746, target='ENSG00000215305', maf=0.392857),
#               SNPRes(rsid='chr20_2855618_C_T_b38', chrom=20, pos=2855618, logp=20.819983142416746, target='ENSG00000215305', maf=0.392857),
#               SNPRes(rsid='chr20_2856034_T_G_b38', chrom=20, pos=2856034, logp=20.819983142416746, target='ENSG00000215305', maf=0.392857),
#               SNPRes(rsid='chr20_22352470_T_C_b38', chrom=20, pos=22352470, logp=4.562117900743439, target='ENSG00000204684', maf=0.295031),
#               SNPRes(rsid='chr20_22422649_T_C_b38', chrom=20, pos=22422649, logp=7.688604314736716, target='ENSG00000204684', maf=0.170807),
#               SNPRes(rsid='chr20_32566653_T_C_b38', chrom=20, pos=32566653, logp=3.797876927201956, target='ENSG00000204393', maf=0.161491),
#               SNPRes(rsid='chr20_63530987_T_C_b38', chrom=20, pos=63530987, logp=13.906266715286414, target='ENSG00000125534', maf=0.32764),
#               SNPRes(rsid='chr20_63506110_G_A_b38', chrom=20, pos=63506110, logp=4.686223442796127, target='ENSG00000101213', maf=0.245342),
#               SNPRes(rsid='chr20_63506618_A_G_b38', chrom=20, pos=63506618, logp=4.38561960664357, target='ENSG00000101213', maf=0.209627),
#               SNPRes(rsid='chr20_63522320_T_G_b38', chrom=20, pos=63522320, logp=4.470048907243874, target='ENSG00000101213', maf=0.206522),
#               SNPRes(rsid='chr20_63522433_G_A_b38', chrom=20, pos=63522433, logp=4.145023900393014, target='ENSG00000101213', maf=0.270186),
#               SNPRes(rsid='chr22_23393578_C_T_b38', chrom=22, pos=23393578, logp=4.720670769067779, target='ENSG00000133519', maf=0.32764),
#               SNPRes(rsid='chr22_23570536_A_G_b38', chrom=22, pos=23570536, logp=4.423605662188167, target='ENSG00000133519', maf=0.368012),
#               SNPRes(rsid='chr22_23570536_A_G_b38', chrom=22, pos=23570536, logp=10.32404669305591, target='ENSG00000280623', maf=0.368012),
#               SNPRes(rsid='chr22_23570536_A_G_b38', chrom=22, pos=23570536, logp=15.757239988763601, target='ENSG00000224277', maf=0.368012),
#               SNPRes(rsid='chr22_36358218_C_T_b38', chrom=22, pos=36358218, logp=9.573911853163946, target='ENSG00000100345', maf=0.450311),
#               SNPRes(rsid='chr22_41527647_T_C_b38', chrom=22, pos=41527647, logp=5.693866744756855, target='ENSG00000100413', maf=0.0854037),
#               SNPRes(rsid='chr22_45338979_T_C_b38', chrom=22, pos=45338979, logp=8.407264905691724, target='ENSG00000100376', maf=0.333851),
#               SNPRes(rsid='chr22_45341600_T_C_b38', chrom=22, pos=45341600, logp=9.23882870292822, target='ENSG00000100376', maf=0.372671),
#               SNPRes(rsid='chr22_45342606_A_G_b38', chrom=22, pos=45342606, logp=9.705110708189588, target='ENSG00000100376', maf=0.371118),
#               SNPRes(rsid='chr22_45343973_A_G_b38', chrom=22, pos=45343973, logp=9.705110708189588, target='ENSG00000100376', maf=0.371118),
#               SNPRes(rsid='chr22_45341600_T_C_b38', chrom=22, pos=45341600, logp=4.905085369816545, target='ENSG00000077935', maf=0.372671),
#               SNPRes(rsid='chr22_45342606_A_G_b38', chrom=22, pos=45342606, logp=4.841233560680399, target='ENSG00000077935', maf=0.371118),
#               SNPRes(rsid='chr22_45343973_A_G_b38', chrom=22, pos=45343973, logp=4.841233560680399, target='ENSG00000077935', maf=0.371118)],
#              'ut': [SNPRes(rsid='chr1_1309988_G_A_b38', chrom=1, pos=1309988, logp=6.304229473662854, target='ENSG00000127054', maf=0.302326),
#               SNPRes(rsid='chr1_1330125_G_A_b38', chrom=1, pos=1330125, logp=5.232738728220506, target='ENSG00000127054', maf=0.306202),
#               SNPRes(rsid='chr1_1387698_A_G_b38', chrom=1, pos=1387698, logp=5.659232763381842, target='ENSG00000127054', maf=0.294574),
#               SNPRes(rsid='chr1_1400410_A_G_b38', chrom=1, pos=1400410, logp=6.2216866432677485, target='ENSG00000127054', maf=0.275194),
#               SNPRes(rsid='chr1_1411323_A_C_b38', chrom=1, pos=1411323, logp=4.915620360785649, target='ENSG00000127054', maf=0.290698),
#               SNPRes(rsid='chr1_1306420_A_G_b38', chrom=1, pos=1306420, logp=6.282027592576997, target='ENSG00000235098', maf=0.20155),
#               SNPRes(rsid='chr1_1309988_G_A_b38', chrom=1, pos=1309988, logp=7.41983028156749, target='ENSG00000235098', maf=0.302326),
#               SNPRes(rsid='chr1_1330125_G_A_b38', chrom=1, pos=1330125, logp=5.965844993859616, target='ENSG00000235098', maf=0.306202),
#               SNPRes(rsid='chr1_1387698_A_G_b38', chrom=1, pos=1387698, logp=7.445281941730927, target='ENSG00000235098', maf=0.294574),
#               SNPRes(rsid='chr1_1400410_A_G_b38', chrom=1, pos=1400410, logp=5.568604067070812, target='ENSG00000235098', maf=0.275194),
#               SNPRes(rsid='chr1_1411323_A_C_b38', chrom=1, pos=1411323, logp=7.606314263111428, target='ENSG00000235098', maf=0.290698),
#               SNPRes(rsid='chr1_1421170_A_G_b38', chrom=1, pos=1421170, logp=9.52019587102115, target='ENSG00000235098', maf=0.186047),
#               SNPRes(rsid='chr1_1422081_C_T_b38', chrom=1, pos=1422081, logp=9.444822087800933, target='ENSG00000235098', maf=0.197674),
#               SNPRes(rsid='chr1_1421170_A_G_b38', chrom=1, pos=1421170, logp=5.781128532299452, target='ENSG00000225905', maf=0.186047),
#               SNPRes(rsid='chr1_1422081_C_T_b38', chrom=1, pos=1422081, logp=5.566623848848044, target='ENSG00000225905', maf=0.197674),
#               SNPRes(rsid='chr3_129352535_T_C_b38', chrom=3, pos=129352535, logp=11.550771604216852, target='ENSG00000270773', maf=0.170543),
#               SNPRes(rsid='chr3_129353642_T_C_b38', chrom=3, pos=129353642, logp=9.390716217054253, target='ENSG00000270773', maf=0.186047),
#               SNPRes(rsid='chr3_129356400_C_T_b38', chrom=3, pos=129356400, logp=11.550771604216852, target='ENSG00000270773', maf=0.170543),
#               SNPRes(rsid='chr3_129365923_A_G_b38', chrom=3, pos=129365923, logp=8.752780655482434, target='ENSG00000270773', maf=0.182171),
#               SNPRes(rsid='chr3_129366295_A_C_b38', chrom=3, pos=129366295, logp=8.752780655482434, target='ENSG00000270773', maf=0.182171),
#               SNPRes(rsid='chr3_129426770_G_A_b38', chrom=3, pos=129426770, logp=9.619323950102347, target='ENSG00000251474', maf=0.27907),
#               SNPRes(rsid='chr3_129442145_G_A_b38', chrom=3, pos=129442145, logp=9.619323950102347, target='ENSG00000251474', maf=0.27907),
#               SNPRes(rsid='chr3_129461746_G_A_b38', chrom=3, pos=129461746, logp=9.619323950102347, target='ENSG00000251474', maf=0.27907),
#               SNPRes(rsid='chr3_129497279_T_G_b38', chrom=3, pos=129497279, logp=9.619323950102347, target='ENSG00000251474', maf=0.27907),
#               SNPRes(rsid='chr3_129497829_A_G_b38', chrom=3, pos=129497829, logp=9.619323950102347, target='ENSG00000251474', maf=0.27907),
#               SNPRes(rsid='chr3_129524695_G_A_b38', chrom=3, pos=129524695, logp=9.619323950102347, target='ENSG00000251474', maf=0.27907),
#               SNPRes(rsid='chr3_129527571_T_C_b38', chrom=3, pos=129527571, logp=8.965523954143713, target='ENSG00000251474', maf=0.275194),
#               SNPRes(rsid='chr3_129527956_C_A_b38', chrom=3, pos=129527956, logp=8.965523954143713, target='ENSG00000251474', maf=0.275194),
#               SNPRes(rsid='chr3_129528708_A_G_b38', chrom=3, pos=129528708, logp=9.139232104968992, target='ENSG00000251474', maf=0.271318),
#               SNPRes(rsid='chr7_99529017_T_C_b38', chrom=7, pos=99529017, logp=4.713563740911165, target='ENSG00000244219', maf=0.20155),
#               SNPRes(rsid='chr10_109948435_A_G_b38', chrom=10, pos=109948435, logp=4.72160769944101, target='ENSG00000148700', maf=0.236434),
#               SNPRes(rsid='chr10_109969745_C_T_b38', chrom=10, pos=109969745, logp=4.72160769944101, target='ENSG00000148700', maf=0.236434),
#               SNPRes(rsid='chr10_110086929_A_G_b38', chrom=10, pos=110086929, logp=4.693109829518084, target='ENSG00000148700', maf=0.255814),
#               SNPRes(rsid='chr10_110141809_G_A_b38', chrom=10, pos=110141809, logp=4.73617936589667, target='ENSG00000148700', maf=0.248062),
#               SNPRes(rsid='chr12_53013054_A_G_b38', chrom=12, pos=53013054, logp=6.167818847809004, target='ENSG00000063046', maf=0.248062),
#               SNPRes(rsid='chr12_53014796_A_G_b38', chrom=12, pos=53014796, logp=6.167818847809004, target='ENSG00000063046', maf=0.248062),
#               SNPRes(rsid='chr12_53040321_C_A_b38', chrom=12, pos=53040321, logp=6.167818847809004, target='ENSG00000063046', maf=0.248062),
#               SNPRes(rsid='chr12_53043071_T_C_b38', chrom=12, pos=53043071, logp=6.167818847809004, target='ENSG00000063046', maf=0.248062),
#               SNPRes(rsid='chr14_76955317_T_C_b38', chrom=14, pos=76955317, logp=5.602046094126895, target='ENSG00000258602', maf=0.321705),
#               SNPRes(rsid='chr14_76955317_T_C_b38', chrom=14, pos=76955317, logp=5.7270890705844595, target='ENSG00000243225', maf=0.321705),
#               SNPRes(rsid='chr14_104818822_A_G_b38', chrom=14, pos=104818822, logp=9.355332998227635, target='ENSG00000258701', maf=0.313953),
#               SNPRes(rsid='chr14_104823579_G_A_b38', chrom=14, pos=104823579, logp=9.355332998227635, target='ENSG00000258701', maf=0.313953),
#               SNPRes(rsid='chr14_104848305_T_C_b38', chrom=14, pos=104848305, logp=9.471984946374171, target='ENSG00000258701', maf=0.317829),
#               SNPRes(rsid='chr14_104818822_A_G_b38', chrom=14, pos=104818822, logp=6.293744061013886, target='ENSG00000258811', maf=0.313953),
#               SNPRes(rsid='chr14_104823579_G_A_b38', chrom=14, pos=104823579, logp=6.293744061013886, target='ENSG00000258811', maf=0.313953),
#               SNPRes(rsid='chr14_104848305_T_C_b38', chrom=14, pos=104848305, logp=6.491517416320959, target='ENSG00000258811', maf=0.317829),
#               SNPRes(rsid='chr15_41857274_T_C_b38', chrom=15, pos=41857274, logp=5.824725983018778, target='ENSG00000137877', maf=0.430233),
#               SNPRes(rsid='chr15_45095352_A_G_b38', chrom=15, pos=45095352, logp=5.912978552449125, target='ENSG00000259479', maf=0.170543),
#               SNPRes(rsid='chr15_45096184_C_T_b38', chrom=15, pos=45096184, logp=5.912978552449125, target='ENSG00000259479', maf=0.170543),
#               SNPRes(rsid='chr15_45099877_G_A_b38', chrom=15, pos=45099877, logp=5.865064655398692, target='ENSG00000259479', maf=0.170543),
#               SNPRes(rsid='chr15_45110742_A_G_b38', chrom=15, pos=45110742, logp=5.238605965422612, target='ENSG00000259479', maf=0.174419),
#               SNPRes(rsid='chr15_45116501_C_T_b38', chrom=15, pos=45116501, logp=5.242215405967699, target='ENSG00000259479', maf=0.182171),
#               SNPRes(rsid='chr15_45117073_C_T_b38', chrom=15, pos=45117073, logp=5.242215405967699, target='ENSG00000259479', maf=0.182171),
#               SNPRes(rsid='chr16_963537_A_G_b38', chrom=16, pos=963537, logp=5.931695373097727, target='ENSG00000103227', maf=0.410853),
#               SNPRes(rsid='chr16_22316773_G_T_b38', chrom=16, pos=22316773, logp=5.037634453175138, target='ENSG00000237296', maf=0.399225),
#               SNPRes(rsid='chr16_48969867_C_T_b38', chrom=16, pos=48969867, logp=6.273755427408948, target='ENSG00000102924', maf=0.244186),
#               SNPRes(rsid='chr16_48970373_G_A_b38', chrom=16, pos=48970373, logp=6.273755427408948, target='ENSG00000102924', maf=0.244186),
#               SNPRes(rsid='chr16_48969867_C_T_b38', chrom=16, pos=48969867, logp=6.497898039718479, target='ENSG00000260614', maf=0.244186),
#               SNPRes(rsid='chr16_48970373_G_A_b38', chrom=16, pos=48970373, logp=6.497898039718479, target='ENSG00000260614', maf=0.244186),
#               SNPRes(rsid='chr17_19238913_C_T_b38', chrom=17, pos=19238913, logp=6.255861199221098, target='ENSG00000279825', maf=0.251938),
#               SNPRes(rsid='chr17_19391511_G_T_b38', chrom=17, pos=19391511, logp=5.626968398493666, target='ENSG00000279825', maf=0.271318),
#               SNPRes(rsid='chr17_19238913_C_T_b38', chrom=17, pos=19238913, logp=5.278984533286663, target='ENSG00000228157', maf=0.251938),
#               SNPRes(rsid='chr17_19011465_C_T_b38', chrom=17, pos=19011465, logp=5.000869023548035, target='ENSG00000262319', maf=0.44186),
#               SNPRes(rsid='chr17_19020505_G_A_b38', chrom=17, pos=19020505, logp=5.70198576877207, target='ENSG00000262319', maf=0.329457),
#               SNPRes(rsid='chr17_19238913_C_T_b38', chrom=17, pos=19238913, logp=8.064942375999784, target='ENSG00000262319', maf=0.251938),
#               SNPRes(rsid='chr17_19268883_T_G_b38', chrom=17, pos=19268883, logp=7.38398896211747, target='ENSG00000262319', maf=0.325581),
#               SNPRes(rsid='chr17_19269192_A_G_b38', chrom=17, pos=19269192, logp=7.38398896211747, target='ENSG00000262319', maf=0.325581),
#               SNPRes(rsid='chr17_19271561_T_C_b38', chrom=17, pos=19271561, logp=8.232337381594954, target='ENSG00000262319', maf=0.329457),
#               SNPRes(rsid='chr17_19272004_A_G_b38', chrom=17, pos=19272004, logp=7.38398896211747, target='ENSG00000262319', maf=0.325581),
#               SNPRes(rsid='chr17_19301550_T_C_b38', chrom=17, pos=19301550, logp=7.38398896211747, target='ENSG00000262319', maf=0.325581),
#               SNPRes(rsid='chr17_19313948_C_T_b38', chrom=17, pos=19313948, logp=7.38398896211747, target='ENSG00000262319', maf=0.325581),
#               SNPRes(rsid='chr17_19317353_G_A_b38', chrom=17, pos=19317353, logp=7.38398896211747, target='ENSG00000262319', maf=0.325581),
#               SNPRes(rsid='chr17_19336119_C_T_b38', chrom=17, pos=19336119, logp=7.38398896211747, target='ENSG00000262319', maf=0.325581),
#               SNPRes(rsid='chr17_19338192_G_A_b38', chrom=17, pos=19338192, logp=7.38398896211747, target='ENSG00000262319', maf=0.325581),
#               SNPRes(rsid='chr17_19343762_G_A_b38', chrom=17, pos=19343762, logp=7.38398896211747, target='ENSG00000262319', maf=0.325581),
#               SNPRes(rsid='chr17_19353811_A_G_b38', chrom=17, pos=19353811, logp=7.38398896211747, target='ENSG00000262319', maf=0.325581),
#               SNPRes(rsid='chr17_19378515_T_G_b38', chrom=17, pos=19378515, logp=6.854235062168666, target='ENSG00000262319', maf=0.364341),
#               SNPRes(rsid='chr17_19388755_A_G_b38', chrom=17, pos=19388755, logp=6.854235062168666, target='ENSG00000262319', maf=0.364341),
#               SNPRes(rsid='chr17_19390414_G_A_b38', chrom=17, pos=19390414, logp=6.854235062168666, target='ENSG00000262319', maf=0.364341),
#               SNPRes(rsid='chr17_19391511_G_T_b38', chrom=17, pos=19391511, logp=6.763992073967879, target='ENSG00000262319', maf=0.271318),
#               SNPRes(rsid='chr17_19392137_G_T_b38', chrom=17, pos=19392137, logp=6.492721773278338, target='ENSG00000262319', maf=0.372093),
#               SNPRes(rsid='chr19_40088753_C_T_b38', chrom=19, pos=40088753, logp=5.065600033671099, target='ENSG00000197782', maf=0.244186)]})

# %%
# ###### Old enrichment calculation, everything in one go

# gtexportal_dir = "/cbscratch/franco/datasets/gtex_v8/expression/gtex_portal/eQTLs/GTEx_Analysis_v8_eQTL/"
# dataset = "gtex_v8"
# # meqtl_expr  = "tmm_cclm"
# tejaas_expr = "raw"
# K = 30
# pcutoff = 5e-8
# MIN_TRANS = 1
# MIN_CIS   = 1

# res_dict = dict()
# res_dict_cistype = collections.defaultdict(dict)
# res_dict_randomtype = collections.defaultdict(dict)
# for tissue in tissues:
#     gtex_t = "-".join([dataset, tissue])
    
#     snp_maf_dict = load_snp_maf(maffile, tissue)
    
#     tejaas_file = os.path.join(basepath, tejaas_expr, gtex_t, "tejaas", "permnull_sb0.1_knn{:d}".format(K), "trans_eqtls_{:g}.txt".format(pcutoff))
#     if not os.path.exists(tejaas_file):
#         print("{:s} has no trans-eqtl results".format(tissue))
#         continue
#     transeqtls = tejaas(tejaas_file)
#     transeqtls = [x for x in transeqtls if snp_maf_dict[x.rsid]]
    
#     if len(transeqtls) < MIN_TRANS:
#         print("{:s} has less than {:d} trans-eqtls".format(tissue, MIN_TRANS))
#         continue
    
#     signif_cisfile = os.path.join(gtexportal_dir, "{:s}.v8.signif_variant_gene_pairs.txt.gz".format(tissue_names[tissue].replace(" ", "_")))
#     if not os.path.exists(signif_cisfile) or os.stat(signif_cisfile).st_size == 0:
#         print("{:s} has no cis-file in GTEx!".format(tissue_names[tissue]))
#         continue
#     ciseqtls = read_cis(signif_cisfile)
#     cis_ids = list(set([x.rsid for x in ciseqtls]))
    
#     if len(ciseqtls) < MIN_CIS:
#         print("{:s} has less than {:d} cis-eqtls".format(tissue, MIN_CIS))
#         continue
    
#     cis_trans_eqtls_ids, cistrans_target_eqtls = crossref_trans_tejaas(transeqtls, ciseqtls)

    
#     valid_types = []
#     genetarget_counts = dict()
#     for genetype in genetypes:
#         cis_types_eqtls, uniq_cis_snps, unique_targets = cis_typespecific_eqtls(cistrans_target_eqtls, alltypes_dict[genetype])
#         if len(uniq_cis_snps) > 0:
#             # print(genetype, len(uniq_cis_snps), len(unique_targets))
#             valid_types.append(genetype)
#             genetarget_counts[genetype] = [cis_types_eqtls, uniq_cis_snps, unique_targets]
    
#     # randtrans: contains avg number of random snps that are cis-trans-eQTLs
#     # rand_res_dict: contains, for each genetype, a list with the number of those random cis-trans-eQTLs targeting that genetype
#     randtrans, rand_res_dict = sample_background_50000(ciseqtls, randompath, valid_types, alltypes_dict)
#     FRAC_CISTRANS = len(cis_trans_eqtls_ids) / len(transeqtls)
#     FRAC_RANDOM_GWCISTRANS = randtrans / 50000 
    
#     enrichment = FRAC_CISTRANS / FRAC_RANDOM_GWCISTRANS
   
#     ncis = len(cis_ids)
#     ntrans = len(transeqtls)
#     ncistrans = len(cis_trans_eqtls_ids)
    
#     randtrans1k_bin = sample_binomial(ntrans, FRAC_RANDOM_GWCISTRANS, 10000000)
#     num_null = np.array(randtrans1k_bin) /  ntrans

#     null_enrichments = num_null / FRAC_RANDOM_GWCISTRANS
#     ecdf = ECDF(null_enrichments)
#     pval = 1 - ecdf(enrichment)
    
    
#     res_dict[tissue] = CisTrans(tissue=tissue, ncis=ncis, ntrans=ntrans, 
#                                 ncistrans=ncistrans, randtrans=FRAC_RANDOM_GWCISTRANS,
#                                 enrichment=enrichment, pval=pval)
    
#     print(f"########## Tissue: {tissue} - {ntrans} trans-eqtls - {ncistrans} cis-trans-eqtls #########")
#     print(f"{tissue:>20}        Enrichment: {enrichment:>g} - pval: {pval:>g}")
    
#     cistype_fracs_dict = get_cistype_fractions(ciseqtls, valid_types, alltypes_dict)
    
#     for vt in valid_types:
#         # from the 50000 random SNPs, randtrans is the nº that are cistrans
#         FRAC_RANDOM_TYPE_NULL = np.mean(np.array(rand_res_dict[vt])) / 50000 #randtrans
#         FRAC_CIS_TYPE_NULL    = cistype_fracs_dict[vt]
#         uniq_snps_targettype  = len(genetarget_counts[vt][1]) # contains --> genetarget_counts[genetype] = [cis_types_eqtls, uniq_cis_snps, unique_targets]
#         FRAC_CISTYPE =  uniq_snps_targettype / ntrans
        
#         if FRAC_CIS_TYPE_NULL != 1.0:        
#             cis_type_enrichment    = FRAC_CISTYPE / FRAC_CIS_TYPE_NULL
#             # Calculate pvalue
#             randtrans1k_bin = sample_binomial(ntrans, FRAC_CIS_TYPE_NULL, 10000000)
#             num_null = np.array(randtrans1k_bin) /  ntrans
#             null_enrichments = num_null / FRAC_CIS_TYPE_NULL
#             ecdf = ECDF(null_enrichments)
#             cis_pval = 1 - ecdf(cis_type_enrichment)
#         else:
#             cis_pval = 1.0
#             cis_type_enrichment = 1.0
          
#         random_type_enrichment = FRAC_CISTYPE / FRAC_RANDOM_TYPE_NULL
#         # Calculate pvalue
#         randtrans1k_bin = sample_binomial(ntrans, FRAC_RANDOM_TYPE_NULL, 10000000)
#         num_null = np.array(randtrans1k_bin) /  ntrans
#         null_enrichments = num_null / FRAC_RANDOM_TYPE_NULL
#         ecdf = ECDF(null_enrichments)
#         random_pval = 1 - ecdf(random_type_enrichment)
                  
#         print(f"{vt:>20}    CIS Enrichment: {cis_type_enrichment:>g} - pval: {cis_pval:>g}")
#         print(f"{vt:>20} RANDOM Enrichment: {random_type_enrichment:>g} - pval: {random_pval:>g}")
    
#         res_dict_cistype[tissue][vt]    = CisTrans_type(tissue=tissue, genetype=vt,
#                                                         hits=uniq_snps_targettype,
#                                                         frac=FRAC_CIS_TYPE_NULL,
#                                                         enrichment=cis_type_enrichment, pval=cis_pval)
#         res_dict_randomtype[tissue][vt] = CisTrans_type(tissue=tissue, genetype=vt, 
#                                                         hits=uniq_snps_targettype,
#                                                         frac=FRAC_RANDOM_TYPE_NULL,
#                                                         enrichment=random_type_enrichment, pval=random_pval)
