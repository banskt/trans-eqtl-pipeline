# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
import time
from statsmodels.distributions.empirical_distribution import ECDF
sys.path.append('../')
sys.path.append('/usr/users/fsimone/tejaas')
from utils import readgtf

base_dir = "/cbscratch/franco/datasets"

import collections

GENEINFO_FIELDS = ['name', 'ensembl_id', 'chrom', 'start', 'end', 'typ']
class GeneInfo(collections.namedtuple('_GeneInfo', GENEINFO_FIELDS)):
    __slots__ = ()

def read_TFannot(infile):
    TF_list = list()
    with open(infile) as instream:
        next(instream)
        for line in instream:
            arr = line.rstrip().split()
            TF_list.append(GeneInfo(ensembl_id=arr[0], chrom=int(arr[1]), start=int(arr[2]), end=int(arr[3]), name=arr[4], typ="TF"))
    return TF_list

TF_annot = read_TFannot("../TF_annotation.txt")

import collections
TF_dict = collections.defaultdict(dict)
for g in TF_annot:
    TF_dict[g.chrom][g.ensembl_id] = "TF"

# %%
from utils import readgtf

gene_info = readgtf.gencode_v12("/cbscratch/franco/datasets/GENCODE/gencode.v26.annotation.gtf.gz", trim=True)
gene_info_dict = collections.defaultdict(dict)
for gene in gene_info:
    gene_info_dict[gene.chrom][gene.ensembl_id] = gene.typ

# %%
import mpmath
from operator import attrgetter

mpmath.mp.dps = 50
def pvalue(x): return float(mpmath.log10(1 - 0.5 * (1 + mpmath.erf(x/mpmath.sqrt(2)))))

SNPRES_FIELDS = ['rsid', 'chrom', 'pos', 'logp', 'fdr', 'target', 'maf']
class SNPRes(collections.namedtuple('_SNPRes', SNPRES_FIELDS)):
    __slots__ = ()
    
CT_FIELDS = ['tissue', 'ncis', 'ntrans', 'ncistrans', 'randtrans', 'enrichment', 'pval']
class CisTrans(collections.namedtuple('_CisTrans', CT_FIELDS)):
    __slots__ = ()
    
# def tejaas_saikat(filepath):
#     res = list()
#     with open(filepath, 'r') as mfile:
#         next(mfile)
#         for line in mfile:
#             arr   = line.strip().split("\t")
#             rsid  = arr[0]
#             chrom = int(arr[1])
#             pos   = int(arr[2])
#             p     = float(arr[3])
#             logp  = np.log10(p) if p!=0 else np.log10(10e-30)
#             res.append(SNPRes(rsid=rsid, chrom=chrom, pos=pos, logp=-logp, fdr=None, target=None))
#     return res

def load_snp_maf(filepath, tissue):
    snp_maf_dict = collections.defaultdict(lambda:False)
    for chrm in np.arange(1,23):
        with open(filepath.format(tissue, chrm)) as instream:
            for line in instream:
                arr = line.strip().split("\t")
                snp_maf_dict[arr[0]] = float(arr[1])
    return snp_maf_dict

def tejaas(filepath, mafcutoff=0.01):
    res = list()
    with open(filepath, 'r') as mfile:
        next(mfile)
        for line in mfile:
            arr   = line.strip().split("\t")
            rsid  = arr[0]
            chrom = int(arr[1])
            pos   = int(arr[2])
            maf   = float(arr[3])
            if maf < mafcutoff or maf > (1-mafcutoff):
                continue
            q     = float(arr[4])
            mu    = float(arr[5])
            sigma = float(arr[6])
            p     = float(arr[7])
            if sigma == 0:
                continue
            logp  = np.log10(p) if p != 0 else pvalue( (q - mu) / sigma)
            res.append(SNPRes(rsid=rsid, chrom=chrom, pos=pos, logp=-logp, maf=maf, fdr=None, target=None))
    return res

def matrixeqtl(filepath, chrom, fdrcutoff):
    res = list()
    if not os.path.exists(filepath) or os.stat(filepath).st_size == 0:
        print("File empty or does not exist")
        return res
    with open(filepath, 'r') as mfile:
        next(mfile)
        for line in mfile:
            arr  = line.strip().split("\t")
            rsid = arr[0]
            pos = int(rsid.split("_")[1])
            gene = arr[1].split(".")[0]
            logp = np.log10(float(arr[4]))
            fdr  = np.log10(float(arr[5]))
            if fdr > fdrcutoff:
                break
            res.append(SNPRes(rsid=rsid, chrom=chrom, pos=pos, logp=-logp, maf=None, fdr=-fdr, target=gene))
    return res

def matrixeqtl_signif(filepath, snp_maf_dict):
    res = list()
    discard = 0
    with open(filepath, 'r') as mfile:
        next(mfile)
        for line in mfile:
            arr  = line.strip().split("\t")
            chrom = arr[0]
            rsid = arr[1]
            if not snp_maf_dict[rsid]:
                discard += 1
                continue
            pos = arr[2]
            gene = arr[5]
            logp = float(arr[3])
            fdr  = float(arr[4])
            res.append(SNPRes(rsid=rsid, chrom=chrom, pos=pos, logp=logp, maf=None, fdr=fdr, target=gene))
    # print("Discarded {:d} SNPs with low MAF".format(discard))
    return res

# %%
# Filter by allowed snps according to MAF
basepath = "/cbscratch/franco/trans-eqtl/dev-pipeline/gtex_v8_lncRNA_freeze/"
baseoutdir = os.path.join(basepath, "cis_eqtls_analysis")
if not os.path.exists(baseoutdir): os.makedirs(baseoutdir)

maf = 0.01    
    
title = "maf{:g}".format(maf*100)
# maffile = "/cbscratch/franco/datasets/gtex_v8/genotypes/vcfs_{:g}/gtex_v8_snpinfo.txt".format(maf)
maffile = "/cbscratch/franco/datasets/gtex_v8/genotypes/snpMAFs/{:s}_snp_CHR{:d}.maf"
randompath = "/usr/users/fsimone/vcfs_{:g}/".format(maf)

# title = "maf5"
# maffile = "/cbscratch/franco/datasets/gtex_v8/genotypes/vcfs_0.05/gtex_v8_snpinfo.txt"
# randompath = "/usr/users/fsimone/vcfs_0.05/"

outdir = os.path.join(baseoutdir, title)
if not os.path.exists(outdir): os.makedirs(outdir)


# NTOT_SNPS_MAF1 = 4522283
# NTOT_SNPS_MAF5 = 2135526

# NTOT_SNPS = 0
# snp_maf_dict = collections.defaultdict(lambda:False)
# with open(maffile) as instream:
#     for line in instream:
#         snp_maf_dict[line.rstrip().split()[1]] = True
#         NTOT_SNPS += 1
# print(NTOT_SNPS)

# %%
import os 
from utils import utils
tissue_file = "/usr/users/fsimone/trans-eqtl-pipeline/main/tissues.txt"
tissues, descriptions = utils.read_tissues(tissue_file)

dataset = "gtex_v8"
expressions = ["tmm_cclm"]
methods = ["matrixeqtl"]
chroms = [str(x) for x in np.arange(1,23)]
fdrcutoff = np.log10(0.05)

# %%
def write_eqtls(snp_res, outfile):
    with open(outfile, 'w') as outstream:
        for g in snp_res:
            line = "{:s}\t{:s}\t{:d}\t{:g}\t{:g}\t{:s}\n".format(g.chrom, g.rsid, g.pos, g.logp, g.fdr, g.target)
            outstream.write(line)

basepath_patch="/cbscratch/franco/trans-eqtl/dev-pipeline/gtex_v8_pc_freeze/"
for tissue in tissues:
    gtex_t = "-".join([dataset, tissue])
    print("Processing: {:s}".format(tissue), end=" ")
    for expression in expressions:
        for method in methods:
            tissue_path = os.path.join(basepath_patch, expression, gtex_t)
            signif_cisfile = os.path.join(basepath_patch, expression, gtex_t, method, "cis_eqtl_signif_fdr0.05.txt")
            signif_transfile = os.path.join(basepath_patch, expression, gtex_t, method, "trans_eqtl_signif_fdr0.05.txt")
            if os.path.exists(tissue_path):
                print("")
                if not os.path.exists(signif_cisfile) and not os.path.exists(signif_transfile):
                    snp_res = list()
                    trans_snp_res = list()
                    for chrom in chroms:
                        cisfile = os.path.join(basepath_patch, expression, gtex_t, method, "chr"+chrom, "cis_eqtl.txt.pos")
                        snp_res += matrixeqtl(cisfile, chrom, fdrcutoff)        
                        transfile = os.path.join(basepath_patch, expression, gtex_t, method, "chr"+chrom, "trans_eqtl.txt.pos")
                        trans_snp_res += matrixeqtl(transfile, chrom, fdrcutoff)
                    write_eqtls(snp_res, signif_cisfile)
                    write_eqtls(trans_snp_res, signif_transfile)
                else:
                    print(" - Files exists")
            else:
                print(tissue_path, "does not exist")
# Out:
# Processing: as
#  - Files exists
# Processing: av
#  - Files exists
# Processing: ag
#  - Files exists
# Processing: aa
#  - Files exists
# Processing: ac
#  - Files exists
# Processing: at
#  - Files exists
# Processing: bam
#  - Files exists
# Processing: ban
#  - Files exists
# Processing: bca
#  - Files exists
# Processing: bceh
#  - Files exists
# Processing: bce
#  - Files exists
# Processing: bco
#  - Files exists
# Processing: bfr
#  - Files exists
# Processing: bhi
#  - Files exists
# Processing: bhy
#  - Files exists
# Processing: bnu
#  - Files exists
# Processing: bpu
#  - Files exists
# Processing: bsp
#  - Files exists
# Processing: bsu
#  - Files exists
# Processing: br
#  - Files exists
# Processing: ebv
#  - Files exists
# Processing: fib
#  - Files exists
# Processing: cols
#  - Files exists
# Processing: colt
#  - Files exists
# Processing: esog
#  - Files exists
# Processing: esom
#  - Files exists
# Processing: esomu
#  - Files exists
# Processing: haa
#  - Files exists
# Processing: hlv
#  - Files exists
# Processing: kc
#  - Files exists
# Processing: liv
#  - Files exists
# Processing: lu
#  - Files exists
# Processing: msg
#  - Files exists
# Processing: ms
#  - Files exists
# Processing: nt
#  - Files exists
# Processing: pan
#  - Files exists
# Processing: pit
#  - Files exists
# Processing: snse
#  - Files exists
# Processing: sse
#  - Files exists
# Processing: si
#  - Files exists
# Processing: spl
#  - Files exists
# Processing: sto
#  - Files exists
# Processing: thy
#  - Files exists
# Processing: wb
#  - Files exists
# Processing: ov /cbscratch/franco/trans-eqtl/dev-pipeline/gtex_v8_pc_freeze/tmm_cclm/gtex_v8-ov does not exist
# Processing: pro /cbscratch/franco/trans-eqtl/dev-pipeline/gtex_v8_pc_freeze/tmm_cclm/gtex_v8-pro does not exist
# Processing: tes /cbscratch/franco/trans-eqtl/dev-pipeline/gtex_v8_pc_freeze/tmm_cclm/gtex_v8-tes does not exist
# Processing: ut /cbscratch/franco/trans-eqtl/dev-pipeline/gtex_v8_pc_freeze/tmm_cclm/gtex_v8-ut does not exist
# Processing: va /cbscratch/franco/trans-eqtl/dev-pipeline/gtex_v8_pc_freeze/tmm_cclm/gtex_v8-va does not exist
# Processing: bl /cbscratch/franco/trans-eqtl/dev-pipeline/gtex_v8_pc_freeze/tmm_cclm/gtex_v8-bl does not exist

# %%
def cis_typespecific_eqtls(cistrans_target_eqtls, genetype_dict):
    cis_typespecific_eqtls = [x for x in cistrans_target_eqtls if genetype_dict[x.target]]
    
    uniq_cis_snps = list(set([x.rsid for x in cis_typespecific_eqtls]))
    unique_targets = list(set([x.target for x in cis_typespecific_eqtls]))
    return cis_typespecific_eqtls, uniq_cis_snps, unique_targets

def cross_ref_cis_trans(trans_ids, cis_eqtls):
    cis_ids = list(set([x.rsid for x in cis_eqtls]))
    
    #Intersection between cis-eqtls (MatrixEQTL) and trans-eqtls (TEJAAS)
    cis_trans_eqtls_ids = list(set.intersection(set(trans_ids), set(cis_ids)))
    
    #set up a dict for fast look up later
    cis_trans_dict = dict()
    for x in cis_trans_eqtls_ids:
        cis_trans_dict[x] = True
    
    # List of cis-trans-eqtls with its target gene
    cis_target_eqtls = [x for x in cis_eqtls if cis_trans_dict.get(x.rsid, False)]

    return cis_trans_eqtls_ids, cis_target_eqtls

def crossref_trans_tejaas(transeqtls, cis_eqtls):
    trans_ids = [x.rsid for x in transeqtls]
    a, b = cross_ref_cis_trans(trans_ids, cis_eqtls)
    return a, b

import random

def get_cistype_fractions(ciseqtls, valid_types, alltypes_dict):
    cistype_frac_dict = dict()
    NCIS = len(list(set([x.rsid for x in ciseqtls])))
    for gtype in valid_types:
        cishits = list()
        for ciseqtl in ciseqtls:
            if alltypes_dict[gtype][ciseqtl.target]:
                cishits.append(ciseqtl.rsid)
        NCIS_TYPE = len(list(set(cishits)))
        cistype_frac_dict[gtype] = NCIS_TYPE / NCIS
        # print("CIS_frac:", gtype, NCIS_TYPE, NCIS)
    return cistype_frac_dict

def sample_background_50000(ciseqtls, randompath, valid_types = [], alltypes_dict = dict()):
    randtrans = list()
    res_dict  = collections.defaultdict(list)
    chroms    = [str(x) for x in np.arange(1,23)]
    for nid in ["{:03d}".format(x) for x in np.arange(1, 11)]:
        Nrand="50000"
        randomfile = randompath+"random_"+Nrand+"_"+nid

        rand_ids = list()
        for chrm in chroms:
            with open(os.path.join(randomfile, "chr{:s}.txt".format(chrm))) as ins:
                rand_ids += [line.rstrip() for line in ins]

        a, b = cross_ref_cis_trans(rand_ids, ciseqtls)
        randtrans.append( len(a) )
        if len(valid_types) > 0:
            for gtype in valid_types:
                cis_types_eqtls, uniq_cis_snps, uniq_targets = cis_typespecific_eqtls(b, alltypes_dict[gtype])
                # save only the number of uniq cistrans snps found for that gene type
                res_dict[gtype].append(len(uniq_cis_snps)) 
    return np.mean(randtrans), res_dict


def sample_binomial(n, p, NTIMES):
    array_n = list()
    for i in range(NTIMES):
        n_success = np.random.binomial(n, p)
        array_n.append(n_success)
    return array_n

# %%
# Reformat genetype dict, we can add as many gene annotations as we want here
alltypes_dict = collections.defaultdict(dict)
genetypes = []
for chrm in range(1,23):
    gene_info_dict[chrm]
    for k in gene_info_dict[chrm].keys():
        genetype = gene_info_dict[chrm][k]
        if genetype not in alltypes_dict:
            alltypes_dict[genetype] = collections.defaultdict(lambda:False)
            genetypes.append(genetype)
        alltypes_dict[genetype][k] = True
    # Add TF dictionary
    for k in TF_dict[chrm].keys():
        genetype = "TF"
        if genetype not in alltypes_dict:
            alltypes_dict[genetype] = collections.defaultdict(lambda:False)
            genetypes.append(genetype)
        alltypes_dict[genetype][k] = True

# %%
###################################
########### MAF 0.01 ##############
###################################

CT_TYPE_FIELDS = ['tissue', 'genetype', 'hits', 'enrichment', 'pval', 'frac']
class CisTrans_type(collections.namedtuple('_CisTransType', CT_TYPE_FIELDS)):
    __slots__ = ()
    
    
meqtl_expr  = "tmm_cclm"
tejaas_expr = "raw"

res_dict = dict()
res_dict_cistype = collections.defaultdict(dict)
res_dict_randomtype = collections.defaultdict(dict)
for tissue in tissues:
    gtex_t = "-".join([dataset, tissue])
    
    snp_maf_dict = load_snp_maf(maffile, tissue)
#     tejaas_file = os.path.join(basepath+"_tejaas_permnull_sb0.1_knn", tissue, "trans_eqtls.txt")
#     if not os.path.exists(tejaas_file):
#         print("{:s} has no trans-eqtl results".format(tissue))
#         continue
#     transeqtls = tejaas_saikat(tejaas_file)
    
    tejaas_file = os.path.join(basepath, "raw", "gtex_v8-"+tissue, "tejaas", "permnull_sb0.1_knn30", "trans_eqtls_5e-08.txt")
    if not os.path.exists(tejaas_file):
        print("{:s} has no trans-eqtl results".format(tissue))
        continue
    transeqtls = tejaas(tejaas_file)
    transeqtls = [x for x in transeqtls if snp_maf_dict[x.rsid]]
    
    
    if len(transeqtls) < 100:
        print("{:s} has less than 100 trans-eqtls".format(tissue))
        continue
    
    signif_cisfile = os.path.join(basepath, meqtl_expr, gtex_t, "matrixeqtl", "cis_eqtl_signif_fdr0.05.txt")
    if not os.path.exists(signif_cisfile) or os.stat(signif_cisfile).st_size == 0:
        print("{:s} has no cis-file (probably no covariates)".format(tissue))
        continue
    ciseqtls = matrixeqtl_signif(signif_cisfile, snp_maf_dict)
    cis_ids = list(set([x.rsid for x in ciseqtls]))
    
    if len(ciseqtls) < 100:
        print("{:s} has less than 100 cis-eqtls".format(tissue))
        continue
    
    cis_trans_eqtls_ids, cistrans_target_eqtls = crossref_trans_tejaas(transeqtls, ciseqtls)
    
    valid_types = []
    genetarget_counts = dict()
    for genetype in genetypes:
        cis_types_eqtls, uniq_cis_snps, unique_targets = cis_typespecific_eqtls(cistrans_target_eqtls, alltypes_dict[genetype])
        if len(uniq_cis_snps) > 0:
            # print(genetype, len(uniq_cis_snps), len(unique_targets))
            valid_types.append(genetype)
            genetarget_counts[genetype] = [cis_types_eqtls, uniq_cis_snps, unique_targets]
            
    # FRAC_GWCIS = len(ciseqtls)/NTOT_SNPS
    randtrans, rand_res_dict = sample_background_50000(ciseqtls, randompath, valid_types, alltypes_dict)
    FRAC_CISTRANS = len(cis_trans_eqtls_ids) / len(transeqtls)
    FRAC_RANDOM_GWCISTRANS = randtrans / 50000 
    
    enrichment = FRAC_CISTRANS / FRAC_RANDOM_GWCISTRANS

#     ### Calculate empirical p-value
#     ntrans = len(transeqtls)
#     randtrans1k = sample_1000_pval(ciseqtls, ntrans, randompath)
#     num_null = np.array(randtrans1k) /  ntrans
#     null_enrichments = num_null / FRAC_RANDOM_GWCISTRANS
#     ecdf = ECDF(null_enrichments)
#     pval = 1 - ecdf(actual_enrichment)
#     print("Empirical p-val:", pval)
    
    ncis = len(cis_ids)
    ntrans = len(transeqtls)
    ncistrans = len(cis_trans_eqtls_ids)
    
    randtrans1k_bin = sample_binomial(ntrans, FRAC_RANDOM_GWCISTRANS, 10000000)
    num_null = np.array(randtrans1k_bin) /  ntrans

    null_enrichments = num_null / FRAC_RANDOM_GWCISTRANS
    ecdf = ECDF(null_enrichments)
    pval = 1 - ecdf(enrichment)
    
    
    res_dict[tissue] = CisTrans(tissue=tissue, ncis=ncis, ntrans=ntrans, 
                                ncistrans=ncistrans, randtrans=FRAC_RANDOM_GWCISTRANS,
                                enrichment=enrichment, pval=pval)
    
    print(f"########## Tissue: {tissue} - {ntrans} trans-eqtls - {ncistrans} cis-trans-eqtls #########")
    print(f"{tissue:>20}        Enrichment: {enrichment:>g} - pval: {pval:>g}")
    
    cistype_fracs_dict = get_cistype_fractions(ciseqtls, valid_types, alltypes_dict)
    
    for vt in valid_types:
        # from the 50000 random SNPs, randtrans is the nº that are cistrans
        FRAC_RANDOM_TYPE_NULL = np.mean(np.array(rand_res_dict[vt])) / 50000 #randtrans
        FRAC_CIS_TYPE_NULL    = cistype_fracs_dict[vt]
        uniq_snps_targettype = len(genetarget_counts[vt][1])
        FRAC_CISTYPE =  uniq_snps_targettype / ntrans
        
        if FRAC_CIS_TYPE_NULL != 1.0:        
            cis_type_enrichment    = FRAC_CISTYPE / FRAC_CIS_TYPE_NULL
            # Calculate pvalue
            randtrans1k_bin = sample_binomial(ntrans, FRAC_CIS_TYPE_NULL, 10000000)
            num_null = np.array(randtrans1k_bin) /  ntrans
            null_enrichments = num_null / FRAC_CIS_TYPE_NULL
            ecdf = ECDF(null_enrichments)
            cis_pval = 1 - ecdf(cis_type_enrichment)
        else:
            cis_pval = 1.0
            cis_type_enrichment = 1.0
          
        random_type_enrichment = FRAC_CISTYPE / FRAC_RANDOM_TYPE_NULL
        # Calculate pvalue
        randtrans1k_bin = sample_binomial(ntrans, FRAC_RANDOM_TYPE_NULL, 10000000)
        num_null = np.array(randtrans1k_bin) /  ntrans
        null_enrichments = num_null / FRAC_RANDOM_TYPE_NULL
        ecdf = ECDF(null_enrichments)
        random_pval = 1 - ecdf(random_type_enrichment)
                  
        print(f"{vt:>20}    CIS Enrichment: {cis_type_enrichment:>g} - pval: {cis_pval:>g}")
        print(f"{vt:>20} RANDOM Enrichment: {random_type_enrichment:>g} - pval: {random_pval:>g}")
    
        res_dict_cistype[tissue][vt]    = CisTrans_type(tissue=tissue, genetype=vt,
                                                        hits=uniq_snps_targettype,
                                                        frac=FRAC_CIS_TYPE_NULL,
                                                        enrichment=cis_type_enrichment, pval=cis_pval)
        res_dict_randomtype[tissue][vt] = CisTrans_type(tissue=tissue, genetype=vt, 
                                                        hits=uniq_snps_targettype,
                                                        frac=FRAC_RANDOM_TYPE_NULL,
                                                        enrichment=random_type_enrichment, pval=random_pval)
# Out:
# ########## Tissue: as - 1280 trans-eqtls - 226 cis-trans-eqtls #########
#                   as        Enrichment: 0.787656 - pval: 0.999984
#              lincRNA    CIS Enrichment: 0.0350237 - pval: 1
#              lincRNA RANDOM Enrichment: 0.1565 - pval: 1
#       protein_coding    CIS Enrichment: 0.186786 - pval: 1
#       protein_coding RANDOM Enrichment: 0.833482 - pval: 0.998949
#            antisense    CIS Enrichment: 0.113785 - pval: 1
#            antisense RANDOM Enrichment: 0.510899 - pval: 0.999864
# processed_transcript    CIS Enrichment: 0.0751527 - pval: 1
# processed_transcript RANDOM Enrichment: 0.338937 - pval: 0.933684
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-a044789aba0b> in <module>()
#     116         random_type_enrichment = FRAC_CISTYPE / FRAC_RANDOM_TYPE_NULL
#     117         # Calculate pvalue
# --> 118         randtrans1k_bin = sample_binomial(ntrans, FRAC_RANDOM_TYPE_NULL, 10000000)
#     119         num_null = np.array(randtrans1k_bin) /  ntrans
#     120         null_enrichments = num_null / FRAC_RANDOM_TYPE_NULL
#
# <ipython-input-7-bf7fa09b1a79> in sample_binomial(n, p, NTIMES)
#      69     for i in range(NTIMES):
#      70         n_success = np.random.binomial(n, p)
# ---> 71         array_n.append(n_success)
#      72     return array_n
#
# KeyboardInterrupt:

# %%
cis_trans_eqtls_ids
# Out:
# ['chr14_94121934_G_A_b38',
#  'chr1_155687151_G_A_b38',
#  'chr2_84213880_T_C_b38',
#  'chr20_32574766_G_A_b38',
#  'chr20_20052966_A_C_b38',
#  'chr22_42480785_G_A_b38',
#  'chr20_19998228_C_T_b38',
#  'chr15_52289286_T_C_b38',
#  'chr10_89164501_A_G_b38',
#  'chr15_52242147_G_A_b38',
#  'chr20_20045611_C_A_b38',
#  'chr12_22356161_T_C_b38',
#  'chr13_49746825_T_C_b38',
#  'chr10_89494542_T_C_b38',
#  'chr11_2917931_G_A_b38',
#  'chr5_61259437_A_G_b38',
#  'chr10_114281518_G_A_b38',
#  'chr2_84278845_G_A_b38',
#  'chr2_84232904_A_C_b38',
#  'chr6_110932797_T_G_b38',
#  'chr6_54016213_G_A_b38',
#  'chr6_3714832_T_C_b38',
#  'chr20_32580637_C_T_b38',
#  'chr17_19338192_G_A_b38',
#  'chr12_22551497_G_A_b38',
#  'chr11_2307463_C_T_b38',
#  'chr9_85530029_T_C_b38',
#  'chr10_89195717_A_C_b38',
#  'chr20_20054592_T_C_b38',
#  'chr11_61954740_G_T_b38',
#  'chr15_52275027_C_T_b38',
#  'chr17_78035144_C_T_b38',
#  'chr17_19301550_T_C_b38',
#  'chr2_84263152_C_T_b38',
#  'chr2_84317935_C_T_b38',
#  'chr2_84225011_G_A_b38',
#  'chr2_84315354_T_C_b38',
#  'chr11_2918475_G_A_b38',
#  'chr15_52290413_G_A_b38',
#  'chr10_11114509_T_C_b38',
#  'chr2_84295323_G_A_b38',
#  'chr9_126837427_A_G_b38',
#  'chr2_84310850_G_A_b38',
#  'chr2_84248654_C_T_b38',
#  'chr12_22374260_C_T_b38',
#  'chr2_84305680_G_A_b38',
#  'chr20_32517220_A_G_b38',
#  'chr11_2302811_A_G_b38',
#  'chr1_156905315_C_A_b38',
#  'chr12_22376906_G_A_b38',
#  'chr10_89169790_G_A_b38',
#  'chr2_84248096_T_G_b38',
#  'chr1_155566947_G_A_b38',
#  'chr11_2307889_C_T_b38',
#  'chr2_84214222_G_A_b38',
#  'chr3_48781943_G_T_b38',
#  'chr20_19998735_G_A_b38',
#  'chr17_19272004_A_G_b38',
#  'chr6_144955508_C_T_b38',
#  'chr11_2309820_C_A_b38',
#  'chr5_944183_A_G_b38',
#  'chr20_32557005_A_G_b38',
#  'chr15_52235969_A_G_b38',
#  'chr10_89195482_G_T_b38',
#  'chr9_85558031_A_G_b38',
#  'chr13_113287986_G_A_b38',
#  'chr5_61262583_G_A_b38',
#  'chr20_20068901_C_T_b38',
#  'chr20_20022010_G_T_b38',
#  'chr1_204415772_C_T_b38',
#  'chr2_84317765_T_C_b38',
#  'chr16_29605798_A_C_b38',
#  'chr2_84301632_T_C_b38',
#  'chr10_89204857_T_G_b38',
#  'chr10_89171421_T_G_b38',
#  'chr3_50250119_C_T_b38',
#  'chr17_19391511_G_T_b38',
#  'chr2_84307854_C_T_b38',
#  'chr10_11107674_G_A_b38',
#  'chr5_132789134_T_C_b38',
#  'chr15_52259703_G_A_b38',
#  'chr17_19313948_C_T_b38',
#  'chr10_89198861_C_T_b38',
#  'chr3_50249828_T_G_b38',
#  'chr20_20035701_C_T_b38',
#  'chr6_110931131_G_A_b38',
#  'chr6_111019248_G_A_b38',
#  'chr19_39387366_G_A_b38',
#  'chr1_35240414_G_A_b38',
#  'chr2_84237103_A_G_b38',
#  'chr3_50257119_A_G_b38',
#  'chr11_68381982_A_C_b38',
#  'chr3_50254761_G_T_b38',
#  'chr12_128653733_A_G_b38',
#  'chr2_84317508_T_C_b38',
#  'chr10_89163071_G_A_b38',
#  'chr17_55708143_C_T_b38',
#  'chr15_52183103_G_A_b38',
#  'chr10_114313937_C_T_b38',
#  'chr6_159065354_C_A_b38',
#  'chr20_20048801_A_C_b38',
#  'chr17_19392137_G_T_b38',
#  'chr16_71531679_A_G_b38',
#  'chr12_22372419_A_C_b38',
#  'chr17_19353811_A_G_b38',
#  'chr1_156900823_G_A_b38',
#  'chr11_2309823_A_G_b38',
#  'chr10_89206789_C_T_b38',
#  'chr20_32555011_G_T_b38',
#  'chr6_110830956_A_G_b38',
#  'chr13_113288632_G_A_b38',
#  'chr11_2309170_G_A_b38',
#  'chr1_211547623_C_T_b38',
#  'chr2_84255772_T_C_b38',
#  'chr10_89204269_A_G_b38',
#  'chr2_84217319_A_G_b38',
#  'chr6_144683275_C_T_b38',
#  'chr2_84308549_A_G_b38',
#  'chr17_19317353_G_A_b38',
#  'chr2_84213179_T_G_b38',
#  'chr11_2309984_A_C_b38',
#  'chr10_89204529_A_G_b38',
#  'chr10_89222130_T_G_b38',
#  'chr2_84225086_C_A_b38',
#  'chr2_84211610_C_T_b38',
#  'chr2_84247081_T_C_b38',
#  'chr10_89163133_C_T_b38',
#  'chr10_89499900_C_T_b38',
#  'chr17_19388755_A_G_b38',
#  'chr11_32539846_C_T_b38',
#  'chr2_84247615_C_A_b38',
#  'chr6_144715196_T_C_b38',
#  'chr10_89165910_T_G_b38',
#  'chr17_19020505_G_A_b38',
#  'chr12_19034411_T_C_b38',
#  'chr2_84217551_A_C_b38',
#  'chr17_19390414_G_A_b38',
#  'chr6_110932599_A_G_b38',
#  'chr16_21979439_T_C_b38',
#  'chr1_156905300_G_A_b38',
#  'chr12_22564999_G_T_b38',
#  'chr15_52281323_A_C_b38',
#  'chr20_20070420_T_C_b38',
#  'chr3_50246005_T_C_b38',
#  'chr19_7882640_C_T_b38',
#  'chr3_50270519_G_A_b38',
#  'chr6_111005884_T_G_b38',
#  'chr6_169617611_G_A_b38',
#  'chr11_2309700_C_T_b38',
#  'chr11_2309249_G_A_b38',
#  'chr2_84292539_G_T_b38',
#  'chr6_169621385_C_T_b38',
#  'chr11_68393036_G_T_b38',
#  'chr2_84314440_C_T_b38',
#  'chr11_2307848_T_G_b38',
#  'chr10_89209002_C_T_b38',
#  'chr13_49651403_C_T_b38',
#  'chr2_84317769_A_G_b38',
#  'chr1_156905245_T_G_b38',
#  'chr17_19268883_T_G_b38',
#  'chr10_89163767_G_A_b38',
#  'chr20_20068264_A_C_b38',
#  'chr6_143079531_A_G_b38',
#  'chr1_156902975_T_C_b38',
#  'chr5_132746205_A_G_b38',
#  'chr17_19271561_T_C_b38',
#  'chr17_19269192_A_G_b38',
#  'chr2_84308773_G_A_b38',
#  'chr1_156903671_T_C_b38',
#  'chr5_132749264_G_A_b38',
#  'chr5_61262644_C_T_b38',
#  'chr17_19343762_G_A_b38',
#  'chr12_22543911_G_A_b38',
#  'chr15_52275326_T_C_b38',
#  'chr2_84250832_T_C_b38',
#  'chr2_84206517_G_T_b38',
#  'chr1_211735888_C_T_b38',
#  'chr2_84221215_T_C_b38',
#  'chr11_2301799_T_C_b38',
#  'chr20_20022103_G_A_b38',
#  'chr15_69278613_T_C_b38',
#  'chr2_84206772_G_A_b38',
#  'chr6_54012383_G_A_b38',
#  'chr11_2309747_T_C_b38',
#  'chr2_84262138_T_C_b38',
#  'chr15_52273111_G_A_b38',
#  'chr13_49653360_T_G_b38',
#  'chr17_60558968_A_G_b38',
#  'chr6_54014520_G_T_b38',
#  'chr17_19336119_C_T_b38',
#  'chr2_84306251_T_C_b38',
#  'chr6_144955490_G_A_b38',
#  'chr2_131474964_C_T_b38',
#  'chr5_132755136_T_C_b38',
#  'chr20_20054645_A_C_b38',
#  'chr11_2309866_G_A_b38',
#  'chr11_2307477_A_G_b38',
#  'chr10_89204638_G_T_b38',
#  'chr3_50380247_C_T_b38',
#  'chr10_89167406_G_A_b38',
#  'chr12_22338706_G_A_b38',
#  'chr2_84243387_T_C_b38',
#  'chr17_19378515_T_G_b38',
#  'chr15_52223481_G_T_b38',
#  'chr2_84307204_C_A_b38',
#  'chr15_69247558_A_G_b38',
#  'chr12_22366801_T_G_b38',
#  'chr11_61955173_C_A_b38',
#  'chr6_144718923_G_A_b38',
#  'chr17_19238913_C_T_b38',
#  'chr12_80460849_C_T_b38',
#  'chr4_139367077_A_G_b38',
#  'chr2_84249811_A_G_b38',
#  'chr3_93927081_C_T_b38',
#  'chr14_94125298_C_A_b38',
#  'chr10_11108882_T_C_b38',
#  'chr13_113286646_A_G_b38',
#  'chr13_113295721_C_T_b38',
#  'chr6_111020491_G_A_b38',
#  'chr10_89205934_T_C_b38',
#  'chr10_89221804_A_G_b38',
#  'chr10_89207336_T_C_b38',
#  'chr10_89202042_G_A_b38',
#  'chr5_132743502_A_G_b38',
#  'chr2_131475952_G_A_b38',
#  'chr10_89179145_G_T_b38']

# %%
cistrans_target_eqtls
# Out:
# [SNPRes(rsid='chr1_204415772_C_T_b38', chrom='1', pos='204415772', logp=34.0452, fdr=31.2018, target='ENSG00000226330', maf=None),
#  SNPRes(rsid='chr1_204415772_C_T_b38', chrom='1', pos='204415772', logp=25.4566, fdr=22.9629, target='ENSG00000158615', maf=None),
#  SNPRes(rsid='chr1_156905245_T_G_b38', chrom='1', pos='156905245', logp=18.2561, fdr=16.0195, target='ENSG00000187800', maf=None),
#  SNPRes(rsid='chr1_156903671_T_C_b38', chrom='1', pos='156903671', logp=17.0857, fdr=14.8949, target='ENSG00000187800', maf=None),
#  SNPRes(rsid='chr1_156905300_G_A_b38', chrom='1', pos='156905300', logp=16.023, fdr=13.8701, target='ENSG00000187800', maf=None),
#  SNPRes(rsid='chr1_156905315_C_A_b38', chrom='1', pos='156905315', logp=15.827, fdr=13.6813, target='ENSG00000187800', maf=None),
#  SNPRes(rsid='chr1_156902975_T_C_b38', chrom='1', pos='156902975', logp=15.6949, fdr=13.5544, target='ENSG00000187800', maf=None),
#  SNPRes(rsid='chr1_156900823_G_A_b38', chrom='1', pos='156900823', logp=15.3358, fdr=13.2119, target='ENSG00000187800', maf=None),
#  SNPRes(rsid='chr1_204415772_C_T_b38', chrom='1', pos='204415772', logp=12.3087, fdr=10.309, target='ENSG00000133056', maf=None),
#  SNPRes(rsid='chr1_211735888_C_T_b38', chrom='1', pos='211735888', logp=9.7416, fdr=7.8558, target='ENSG00000123684', maf=None),
#  SNPRes(rsid='chr1_155687151_G_A_b38', chrom='1', pos='155687151', logp=5.1977, fdr=3.58091, target='ENSG00000160767', maf=None),
#  SNPRes(rsid='chr1_35240414_G_A_b38', chrom='1', pos='35240414', logp=5.156, fdr=3.54218, target='ENSG00000116560', maf=None),
#  SNPRes(rsid='chr1_155566947_G_A_b38', chrom='1', pos='155566947', logp=4.40252, fdr=2.85116, target='ENSG00000160767', maf=None),
#  SNPRes(rsid='chr1_211547623_C_T_b38', chrom='1', pos='211547623', logp=3.82504, fdr=2.32934, target='ENSG00000170385', maf=None),
#  SNPRes(rsid='chr1_156905245_T_G_b38', chrom='1', pos='156905245', logp=3.65792, fdr=2.17992, target='ENSG00000160838', maf=None),
#  SNPRes(rsid='chr1_156905245_T_G_b38', chrom='1', pos='156905245', logp=3.65102, fdr=2.17386, target='ENSG00000132694', maf=None),
#  SNPRes(rsid='chr1_156903671_T_C_b38', chrom='1', pos='156903671', logp=3.17578, fdr=1.75494, target='ENSG00000160838', maf=None),
#  SNPRes(rsid='chr1_156903671_T_C_b38', chrom='1', pos='156903671', logp=3.04827, fdr=1.64458, target='ENSG00000132694', maf=None),
#  SNPRes(rsid='chr2_131475952_G_A_b38', chrom='2', pos='131475952', logp=12.3504, fdr=10.3471, target='ENSG00000163040', maf=None),
#  SNPRes(rsid='chr2_131474964_C_T_b38', chrom='2', pos='131474964', logp=12.2652, fdr=10.2656, target='ENSG00000163040', maf=None),
#  SNPRes(rsid='chr2_84305680_G_A_b38', chrom='2', pos='84305680', logp=8.93771, fdr=7.10143, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84306251_T_C_b38', chrom='2', pos='84306251', logp=8.93771, fdr=7.10143, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84314440_C_T_b38', chrom='2', pos='84314440', logp=8.58713, fdr=6.7706, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84315354_T_C_b38', chrom='2', pos='84315354', logp=8.42214, fdr=6.61472, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84310850_G_A_b38', chrom='2', pos='84310850', logp=8.40428, fdr=6.59795, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84317769_A_G_b38', chrom='2', pos='84317769', logp=8.31806, fdr=6.5166, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84317508_T_C_b38', chrom='2', pos='84317508', logp=8.31719, fdr=6.51579, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84317765_T_C_b38', chrom='2', pos='84317765', logp=8.31719, fdr=6.51579, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84317935_C_T_b38', chrom='2', pos='84317935', logp=8.31719, fdr=6.51579, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84308773_G_A_b38', chrom='2', pos='84308773', logp=8.29911, fdr=6.49857, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84307204_C_A_b38', chrom='2', pos='84307204', logp=8.2849, fdr=6.48518, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84301632_T_C_b38', chrom='2', pos='84301632', logp=8.28282, fdr=6.48324, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84308549_A_G_b38', chrom='2', pos='84308549', logp=8.19626, fdr=6.40152, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84295323_G_A_b38', chrom='2', pos='84295323', logp=8.01882, fdr=6.2347, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84307854_C_T_b38', chrom='2', pos='84307854', logp=7.93903, fdr=6.15973, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84305680_G_A_b38', chrom='2', pos='84305680', logp=7.26411, fdr=5.52618, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84306251_T_C_b38', chrom='2', pos='84306251', logp=7.26411, fdr=5.52618, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84307204_C_A_b38', chrom='2', pos='84307204', logp=7.2232, fdr=5.48787, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_131474964_C_T_b38', chrom='2', pos='131474964', logp=7.06095, fdr=5.33576, target='ENSG00000173272', maf=None),
#  SNPRes(rsid='chr2_131475952_G_A_b38', chrom='2', pos='131475952', logp=7.04296, fdr=5.319, target='ENSG00000173272', maf=None),
#  SNPRes(rsid='chr2_84308773_G_A_b38', chrom='2', pos='84308773', logp=6.93312, fdr=5.2159, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84295323_G_A_b38', chrom='2', pos='84295323', logp=6.89592, fdr=5.18063, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84305680_G_A_b38', chrom='2', pos='84305680', logp=6.86325, fdr=5.15018, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84306251_T_C_b38', chrom='2', pos='84306251', logp=6.86325, fdr=5.15018, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84310850_G_A_b38', chrom='2', pos='84310850', logp=6.8038, fdr=5.09425, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84307204_C_A_b38', chrom='2', pos='84307204', logp=6.76843, fdr=5.06183, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84307854_C_T_b38', chrom='2', pos='84307854', logp=6.75568, fdr=5.04996, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84301632_T_C_b38', chrom='2', pos='84301632', logp=6.72078, fdr=5.01767, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84317508_T_C_b38', chrom='2', pos='84317508', logp=6.71104, fdr=5.00862, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84317765_T_C_b38', chrom='2', pos='84317765', logp=6.71104, fdr=5.00862, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84317935_C_T_b38', chrom='2', pos='84317935', logp=6.71104, fdr=5.00862, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84308549_A_G_b38', chrom='2', pos='84308549', logp=6.71058, fdr=5.00822, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84315354_T_C_b38', chrom='2', pos='84315354', logp=6.57823, fdr=4.8838, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84314440_C_T_b38', chrom='2', pos='84314440', logp=6.49565, fdr=4.80619, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84295323_G_A_b38', chrom='2', pos='84295323', logp=6.48486, fdr=4.7962, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84317769_A_G_b38', chrom='2', pos='84317769', logp=6.33934, fdr=4.66059, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84247615_C_A_b38', chrom='2', pos='84247615', logp=6.31432, fdr=4.63696, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84248096_T_G_b38', chrom='2', pos='84248096', logp=6.31432, fdr=4.63696, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84248654_C_T_b38', chrom='2', pos='84248654', logp=6.31432, fdr=4.63696, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84249811_A_G_b38', chrom='2', pos='84249811', logp=6.28552, fdr=4.60995, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84255772_T_C_b38', chrom='2', pos='84255772', logp=6.28552, fdr=4.60995, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84247081_T_C_b38', chrom='2', pos='84247081', logp=6.17791, fdr=4.51012, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84262138_T_C_b38', chrom='2', pos='84262138', logp=6.17791, fdr=4.51012, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84250832_T_C_b38', chrom='2', pos='84250832', logp=6.14959, fdr=4.48383, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84263152_C_T_b38', chrom='2', pos='84263152', logp=6.14959, fdr=4.48383, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84278845_G_A_b38', chrom='2', pos='84278845', logp=6.14959, fdr=4.48383, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84317508_T_C_b38', chrom='2', pos='84317508', logp=6.14136, fdr=4.47607, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84317765_T_C_b38', chrom='2', pos='84317765', logp=6.14136, fdr=4.47607, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84317935_C_T_b38', chrom='2', pos='84317935', logp=6.14136, fdr=4.47607, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84307854_C_T_b38', chrom='2', pos='84307854', logp=6.03418, fdr=4.37646, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84232904_A_C_b38', chrom='2', pos='84232904', logp=6.02294, fdr=4.36598, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84237103_A_G_b38', chrom='2', pos='84237103', logp=5.96247, fdr=4.3097, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84221215_T_C_b38', chrom='2', pos='84221215', logp=5.94892, fdr=4.29717, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84225086_C_A_b38', chrom='2', pos='84225086', logp=5.94892, fdr=4.29717, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84308773_G_A_b38', chrom='2', pos='84308773', logp=5.93307, fdr=4.28282, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84308549_A_G_b38', chrom='2', pos='84308549', logp=5.92893, fdr=4.27904, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84301632_T_C_b38', chrom='2', pos='84301632', logp=5.91164, fdr=4.26318, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84237103_A_G_b38', chrom='2', pos='84237103', logp=5.89496, fdr=4.24756, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84249811_A_G_b38', chrom='2', pos='84249811', logp=5.87463, fdr=4.22839, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84255772_T_C_b38', chrom='2', pos='84255772', logp=5.87463, fdr=4.22839, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84221215_T_C_b38', chrom='2', pos='84221215', logp=5.86526, fdr=4.2195, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84225086_C_A_b38', chrom='2', pos='84225086', logp=5.86526, fdr=4.2195, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84232904_A_C_b38', chrom='2', pos='84232904', logp=5.84572, fdr=4.20132, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84250832_T_C_b38', chrom='2', pos='84250832', logp=5.82713, fdr=4.18375, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84263152_C_T_b38', chrom='2', pos='84263152', logp=5.82713, fdr=4.18375, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84278845_G_A_b38', chrom='2', pos='84278845', logp=5.82713, fdr=4.18375, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84213179_T_G_b38', chrom='2', pos='84213179', logp=5.78759, fdr=4.14634, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84213880_T_C_b38', chrom='2', pos='84213880', logp=5.78759, fdr=4.14634, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84217319_A_G_b38', chrom='2', pos='84217319', logp=5.78759, fdr=4.14634, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84217551_A_C_b38', chrom='2', pos='84217551', logp=5.78759, fdr=4.14634, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84225011_G_A_b38', chrom='2', pos='84225011', logp=5.76716, fdr=4.12723, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84214222_G_A_b38', chrom='2', pos='84214222', logp=5.75972, fdr=4.12029, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84243387_T_C_b38', chrom='2', pos='84243387', logp=5.74905, fdr=4.11058, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84206772_G_A_b38', chrom='2', pos='84206772', logp=5.74645, fdr=4.10816, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84206517_G_T_b38', chrom='2', pos='84206517', logp=5.7362, fdr=4.09885, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84211610_C_T_b38', chrom='2', pos='84211610', logp=5.7362, fdr=4.09885, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84206772_G_A_b38', chrom='2', pos='84206772', logp=5.72599, fdr=4.08934, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84225011_G_A_b38', chrom='2', pos='84225011', logp=5.67973, fdr=4.04607, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84243387_T_C_b38', chrom='2', pos='84243387', logp=5.59319, fdr=3.96608, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84247615_C_A_b38', chrom='2', pos='84247615', logp=5.58189, fdr=3.95577, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84248096_T_G_b38', chrom='2', pos='84248096', logp=5.58189, fdr=3.95577, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84248654_C_T_b38', chrom='2', pos='84248654', logp=5.58189, fdr=3.95577, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84247081_T_C_b38', chrom='2', pos='84247081', logp=5.53672, fdr=3.9141, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84262138_T_C_b38', chrom='2', pos='84262138', logp=5.53672, fdr=3.9141, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84206517_G_T_b38', chrom='2', pos='84206517', logp=5.52519, fdr=3.90342, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84211610_C_T_b38', chrom='2', pos='84211610', logp=5.52519, fdr=3.90342, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84214222_G_A_b38', chrom='2', pos='84214222', logp=5.4806, fdr=3.86224, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84292539_G_T_b38', chrom='2', pos='84292539', logp=5.45631, fdr=3.8395, target='ENSG00000186854', maf=None),
#  SNPRes(rsid='chr2_84315354_T_C_b38', chrom='2', pos='84315354', logp=5.39126, fdr=3.77969, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84310850_G_A_b38', chrom='2', pos='84310850', logp=5.33744, fdr=3.73083, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84317769_A_G_b38', chrom='2', pos='84317769', logp=5.29526, fdr=3.69189, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84314440_C_T_b38', chrom='2', pos='84314440', logp=5.29256, fdr=3.68938, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84213179_T_G_b38', chrom='2', pos='84213179', logp=5.19568, fdr=3.5998, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84213880_T_C_b38', chrom='2', pos='84213880', logp=5.19568, fdr=3.5998, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84217319_A_G_b38', chrom='2', pos='84217319', logp=5.19568, fdr=3.5998, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84217551_A_C_b38', chrom='2', pos='84217551', logp=5.19568, fdr=3.5998, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84292539_G_T_b38', chrom='2', pos='84292539', logp=4.96175, fdr=3.3839, target='ENSG00000115423', maf=None),
#  SNPRes(rsid='chr2_84249811_A_G_b38', chrom='2', pos='84249811', logp=4.33997, fdr=2.816, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84255772_T_C_b38', chrom='2', pos='84255772', logp=4.33997, fdr=2.816, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84250832_T_C_b38', chrom='2', pos='84250832', logp=4.30045, fdr=2.78067, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84263152_C_T_b38', chrom='2', pos='84263152', logp=4.30045, fdr=2.78067, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84278845_G_A_b38', chrom='2', pos='84278845', logp=4.30045, fdr=2.78067, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84247615_C_A_b38', chrom='2', pos='84247615', logp=4.26212, fdr=2.7463, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84248096_T_G_b38', chrom='2', pos='84248096', logp=4.26212, fdr=2.7463, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84248654_C_T_b38', chrom='2', pos='84248654', logp=4.26212, fdr=2.7463, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84247081_T_C_b38', chrom='2', pos='84247081', logp=4.22323, fdr=2.71146, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84262138_T_C_b38', chrom='2', pos='84262138', logp=4.22323, fdr=2.71146, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84237103_A_G_b38', chrom='2', pos='84237103', logp=4.08676, fdr=2.58978, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84243387_T_C_b38', chrom='2', pos='84243387', logp=4.01402, fdr=2.52435, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84232904_A_C_b38', chrom='2', pos='84232904', logp=3.92062, fdr=2.44044, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84221215_T_C_b38', chrom='2', pos='84221215', logp=3.86433, fdr=2.39065, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84225086_C_A_b38', chrom='2', pos='84225086', logp=3.86433, fdr=2.39065, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84237103_A_G_b38', chrom='2', pos='84237103', logp=3.83399, fdr=2.36345, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84206772_G_A_b38', chrom='2', pos='84206772', logp=3.79741, fdr=2.33079, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84214222_G_A_b38', chrom='2', pos='84214222', logp=3.74868, fdr=2.288, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84249811_A_G_b38', chrom='2', pos='84249811', logp=3.74268, fdr=2.28262, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84255772_T_C_b38', chrom='2', pos='84255772', logp=3.74268, fdr=2.28262, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84232904_A_C_b38', chrom='2', pos='84232904', logp=3.70808, fdr=2.25194, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84221215_T_C_b38', chrom='2', pos='84221215', logp=3.70185, fdr=2.24646, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84225086_C_A_b38', chrom='2', pos='84225086', logp=3.70185, fdr=2.24646, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84250832_T_C_b38', chrom='2', pos='84250832', logp=3.69275, fdr=2.23837, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84263152_C_T_b38', chrom='2', pos='84263152', logp=3.69275, fdr=2.23837, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84278845_G_A_b38', chrom='2', pos='84278845', logp=3.69275, fdr=2.23837, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84213179_T_G_b38', chrom='2', pos='84213179', logp=3.65374, fdr=2.20388, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84213880_T_C_b38', chrom='2', pos='84213880', logp=3.65374, fdr=2.20388, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84217319_A_G_b38', chrom='2', pos='84217319', logp=3.65374, fdr=2.20388, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84217551_A_C_b38', chrom='2', pos='84217551', logp=3.65374, fdr=2.20388, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84247615_C_A_b38', chrom='2', pos='84247615', logp=3.64895, fdr=2.19971, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84248096_T_G_b38', chrom='2', pos='84248096', logp=3.64895, fdr=2.19971, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84248654_C_T_b38', chrom='2', pos='84248654', logp=3.64895, fdr=2.19971, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84295323_G_A_b38', chrom='2', pos='84295323', logp=3.64566, fdr=2.19671, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84243387_T_C_b38', chrom='2', pos='84243387', logp=3.63366, fdr=2.18596, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84305680_G_A_b38', chrom='2', pos='84305680', logp=3.61322, fdr=2.16775, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84306251_T_C_b38', chrom='2', pos='84306251', logp=3.61322, fdr=2.16775, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84247081_T_C_b38', chrom='2', pos='84247081', logp=3.60001, fdr=2.15593, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84262138_T_C_b38', chrom='2', pos='84262138', logp=3.60001, fdr=2.15593, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84225011_G_A_b38', chrom='2', pos='84225011', logp=3.58756, fdr=2.14485, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84307204_C_A_b38', chrom='2', pos='84307204', logp=3.57715, fdr=2.13577, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84206772_G_A_b38', chrom='2', pos='84206772', logp=3.56357, fdr=2.12399, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84206517_G_T_b38', chrom='2', pos='84206517', logp=3.55608, fdr=2.11728, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84211610_C_T_b38', chrom='2', pos='84211610', logp=3.55608, fdr=2.11728, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84225011_G_A_b38', chrom='2', pos='84225011', logp=3.52585, fdr=2.09061, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84292539_G_T_b38', chrom='2', pos='84292539', logp=3.38332, fdr=1.96539, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84214222_G_A_b38', chrom='2', pos='84214222', logp=3.37607, fdr=1.95904, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84213179_T_G_b38', chrom='2', pos='84213179', logp=3.30746, fdr=1.89944, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84213880_T_C_b38', chrom='2', pos='84213880', logp=3.30746, fdr=1.89944, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84217319_A_G_b38', chrom='2', pos='84217319', logp=3.30746, fdr=1.89944, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84217551_A_C_b38', chrom='2', pos='84217551', logp=3.30746, fdr=1.89944, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84206517_G_T_b38', chrom='2', pos='84206517', logp=3.29703, fdr=1.89031, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84211610_C_T_b38', chrom='2', pos='84211610', logp=3.29703, fdr=1.89031, target='ENSG00000163541', maf=None),
#  SNPRes(rsid='chr2_84292539_G_T_b38', chrom='2', pos='84292539', logp=3.28133, fdr=1.87668, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84301632_T_C_b38', chrom='2', pos='84301632', logp=3.27769, fdr=1.87347, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84308773_G_A_b38', chrom='2', pos='84308773', logp=3.26698, fdr=1.86425, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84308549_A_G_b38', chrom='2', pos='84308549', logp=3.20954, fdr=1.81416, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr2_84307854_C_T_b38', chrom='2', pos='84307854', logp=3.099, fdr=1.72002, target='ENSG00000034510', maf=None),
#  SNPRes(rsid='chr3_93927081_C_T_b38', chrom='3', pos='93927081', logp=28.5376, fdr=25.9993, target='ENSG00000178700', maf=None),
#  SNPRes(rsid='chr3_93927081_C_T_b38', chrom='3', pos='93927081', logp=26.0347, fdr=23.5828, target='ENSG00000169379', maf=None),
#  SNPRes(rsid='chr3_50246005_T_C_b38', chrom='3', pos='50246005', logp=9.00148, fdr=7.17748, target='ENSG00000186792', maf=None),
#  SNPRes(rsid='chr3_50246005_T_C_b38', chrom='3', pos='50246005', logp=6.90554, fdr=5.20184, target='ENSG00000068001', maf=None),
#  SNPRes(rsid='chr3_50246005_T_C_b38', chrom='3', pos='50246005', logp=6.77584, fdr=5.07917, target='ENSG00000068028', maf=None),
#  SNPRes(rsid='chr3_50249828_T_G_b38', chrom='3', pos='50249828', logp=4.85329, fdr=3.29307, target='ENSG00000012171', maf=None),
#  SNPRes(rsid='chr3_50257119_A_G_b38', chrom='3', pos='50257119', logp=4.85329, fdr=3.29307, target='ENSG00000012171', maf=None),
#  SNPRes(rsid='chr3_50270519_G_A_b38', chrom='3', pos='50270519', logp=4.81274, fdr=3.25618, target='ENSG00000186792', maf=None),
#  SNPRes(rsid='chr3_50270519_G_A_b38', chrom='3', pos='50270519', logp=4.41212, fdr=2.89294, target='ENSG00000068028', maf=None),
#  SNPRes(rsid='chr3_50250119_C_T_b38', chrom='3', pos='50250119', logp=4.29146, fdr=2.78397, target='ENSG00000012171', maf=None),
#  SNPRes(rsid='chr3_50246005_T_C_b38', chrom='3', pos='50246005', logp=4.28617, fdr=2.77925, target='ENSG00000214706', maf=None),
#  SNPRes(rsid='chr3_50246005_T_C_b38', chrom='3', pos='50246005', logp=4.11185, fdr=2.62171, target='ENSG00000012171', maf=None),
#  SNPRes(rsid='chr3_50270519_G_A_b38', chrom='3', pos='50270519', logp=3.94493, fdr=2.47189, target='ENSG00000068001', maf=None),
#  SNPRes(rsid='chr3_48781943_G_T_b38', chrom='3', pos='48781943', logp=3.71067, fdr=2.26241, target='ENSG00000198218', maf=None),
#  SNPRes(rsid='chr3_50254761_G_T_b38', chrom='3', pos='50254761', logp=3.58012, fdr=2.14793, target='ENSG00000012171', maf=None),
#  SNPRes(rsid='chr3_48781943_G_T_b38', chrom='3', pos='48781943', logp=3.55069, fdr=2.12246, target='ENSG00000173421', maf=None),
#  SNPRes(rsid='chr3_48781943_G_T_b38', chrom='3', pos='48781943', logp=3.3756, fdr=1.96972, target='ENSG00000178149', maf=None),
#  SNPRes(rsid='chr3_48781943_G_T_b38', chrom='3', pos='48781943', logp=3.37061, fdr=1.96528, target='ENSG00000172053', maf=None),
#  SNPRes(rsid='chr3_50380247_C_T_b38', chrom='3', pos='50380247', logp=3.35375, fdr=1.95063, target='ENSG00000186792', maf=None),
#  SNPRes(rsid='chr3_50270519_G_A_b38', chrom='3', pos='50270519', logp=3.2206, fdr=1.83506, target='ENSG00000012171', maf=None),
#  SNPRes(rsid='chr3_48781943_G_T_b38', chrom='3', pos='48781943', logp=3.19153, fdr=1.8103, target='ENSG00000185909', maf=None),
#  SNPRes(rsid='chr3_50249828_T_G_b38', chrom='3', pos='50249828', logp=3.12835, fdr=1.75597, target='ENSG00000068028', maf=None),
#  SNPRes(rsid='chr3_50257119_A_G_b38', chrom='3', pos='50257119', logp=3.12835, fdr=1.75597, target='ENSG00000068028', maf=None),
#  SNPRes(rsid='chr3_48781943_G_T_b38', chrom='3', pos='48781943', logp=3.12441, fdr=1.75271, target='ENSG00000164068', maf=None),
#  SNPRes(rsid='chr3_48781943_G_T_b38', chrom='3', pos='48781943', logp=3.11419, fdr=1.74389, target='ENSG00000067560', maf=None),
#  SNPRes(rsid='chr3_48781943_G_T_b38', chrom='3', pos='48781943', logp=3.09704, fdr=1.72947, target='ENSG00000172113', maf=None),
#  SNPRes(rsid='chr4_139367077_A_G_b38', chrom='4', pos='139367077', logp=30.2116, fdr=27.4663, target='ENSG00000172007', maf=None),
#  SNPRes(rsid='chr4_139367077_A_G_b38', chrom='4', pos='139367077', logp=28.0579, fdr=25.3802, target='ENSG00000109390', maf=None),
#  SNPRes(rsid='chr4_139367077_A_G_b38', chrom='4', pos='139367077', logp=22.0387, fdr=19.5671, target='ENSG00000273247', maf=None),
#  SNPRes(rsid='chr4_139367077_A_G_b38', chrom='4', pos='139367077', logp=12.7849, fdr=10.6933, target='ENSG00000164134', maf=None),
#  SNPRes(rsid='chr4_139367077_A_G_b38', chrom='4', pos='139367077', logp=9.1735, fdr=7.25239, target='ENSG00000145391', maf=None),
#  SNPRes(rsid='chr4_139367077_A_G_b38', chrom='4', pos='139367077', logp=3.05289, fdr=1.60096, target='ENSG00000151014', maf=None),
#  SNPRes(rsid='chr5_132789134_T_C_b38', chrom='5', pos='132789134', logp=30.5731, fdr=27.9287, target='ENSG00000164402', maf=None),
#  SNPRes(rsid='chr5_132755136_T_C_b38', chrom='5', pos='132755136', logp=27.9156, fdr=25.3644, target='ENSG00000164402', maf=None),
#  SNPRes(rsid='chr5_132749264_G_A_b38', chrom='5', pos='132749264', logp=21.6288, fdr=19.3019, target='ENSG00000205089', maf=None),
#  SNPRes(rsid='chr5_132743502_A_G_b38', chrom='5', pos='132743502', logp=20.4214, fdr=18.1356, target='ENSG00000205089', maf=None),
#  SNPRes(rsid='chr5_132746205_A_G_b38', chrom='5', pos='132746205', logp=20.4214, fdr=18.1356, target='ENSG00000205089', maf=None),
#  SNPRes(rsid='chr5_132755136_T_C_b38', chrom='5', pos='132755136', logp=17.014, fdr=14.8457, target='ENSG00000205089', maf=None),
#  SNPRes(rsid='chr5_132789134_T_C_b38', chrom='5', pos='132789134', logp=16.4959, fdr=14.3461, target='ENSG00000205089', maf=None),
#  SNPRes(rsid='chr5_132749264_G_A_b38', chrom='5', pos='132749264', logp=16.1488, fdr=14.0156, target='ENSG00000164402', maf=None),
#  SNPRes(rsid='chr5_132743502_A_G_b38', chrom='5', pos='132743502', logp=15.6386, fdr=13.5246, target='ENSG00000164402', maf=None),
#  SNPRes(rsid='chr5_132746205_A_G_b38', chrom='5', pos='132746205', logp=15.6386, fdr=13.5246, target='ENSG00000164402', maf=None),
#  SNPRes(rsid='chr5_944183_A_G_b38', chrom='5', pos='944183', logp=13.148, fdr=11.1362, target='ENSG00000028310', maf=None),
#  SNPRes(rsid='chr5_944183_A_G_b38', chrom='5', pos='944183', logp=9.73004, fdr=7.86895, target='ENSG00000188818', maf=None),
#  SNPRes(rsid='chr5_61262583_G_A_b38', chrom='5', pos='61262583', logp=9.02421, fdr=7.19223, target='ENSG00000130449', maf=None),
#  SNPRes(rsid='chr5_61262644_C_T_b38', chrom='5', pos='61262644', logp=9.02421, fdr=7.19223, target='ENSG00000130449', maf=None),
#  SNPRes(rsid='chr5_132789134_T_C_b38', chrom='5', pos='132789134', logp=8.37834, fdr=6.58157, target='ENSG00000131437', maf=None),
#  SNPRes(rsid='chr5_132789134_T_C_b38', chrom='5', pos='132789134', logp=8.27335, fdr=6.48199, target='ENSG00000230612', maf=None),
#  SNPRes(rsid='chr5_61259437_A_G_b38', chrom='5', pos='61259437', logp=7.88198, fdr=6.11006, target='ENSG00000130449', maf=None),
#  SNPRes(rsid='chr5_132755136_T_C_b38', chrom='5', pos='132755136', logp=7.04003, fdr=5.31656, target='ENSG00000131437', maf=None),
#  SNPRes(rsid='chr5_132755136_T_C_b38', chrom='5', pos='132755136', logp=7.0031, fdr=5.28178, target='ENSG00000230612', maf=None),
#  SNPRes(rsid='chr5_61262583_G_A_b38', chrom='5', pos='61262583', logp=5.57981, fdr=3.94358, target='ENSG00000164181', maf=None),
#  SNPRes(rsid='chr5_61262644_C_T_b38', chrom='5', pos='61262644', logp=5.57981, fdr=3.94358, target='ENSG00000164181', maf=None),
#  SNPRes(rsid='chr6_144718923_G_A_b38', chrom='6', pos='144718923', logp=17.8969, fdr=15.6595, target='ENSG00000152818', maf=None),
#  SNPRes(rsid='chr6_144715196_T_C_b38', chrom='6', pos='144715196', logp=11.0711, fdr=9.14289, target='ENSG00000152818', maf=None),
#  SNPRes(rsid='chr6_169617611_G_A_b38', chrom='6', pos='169617611', logp=9.99005, fdr=8.12343, target='ENSG00000184465', maf=None),
#  SNPRes(rsid='chr6_169621385_C_T_b38', chrom='6', pos='169621385', logp=9.99005, fdr=8.12343, target='ENSG00000184465', maf=None),
#  SNPRes(rsid='chr6_169617611_G_A_b38', chrom='6', pos='169617611', logp=7.57417, fdr=5.85737, target='ENSG00000130024', maf=None),
#  SNPRes(rsid='chr6_169621385_C_T_b38', chrom='6', pos='169621385', logp=7.57417, fdr=5.85737, target='ENSG00000130024', maf=None),
#  SNPRes(rsid='chr6_54012383_G_A_b38', chrom='6', pos='54012383', logp=7.20763, fdr=5.51656, target='ENSG00000236996', maf=None),
#  SNPRes(rsid='chr6_54014520_G_T_b38', chrom='6', pos='54014520', logp=7.20763, fdr=5.51656, target='ENSG00000236996', maf=None),
#  SNPRes(rsid='chr6_54016213_G_A_b38', chrom='6', pos='54016213', logp=7.20763, fdr=5.51656, target='ENSG00000236996', maf=None),
#  SNPRes(rsid='chr6_159065354_C_A_b38', chrom='6', pos='159065354', logp=6.72662, fdr=5.07066, target='ENSG00000164691', maf=None),
#  SNPRes(rsid='chr6_144955490_G_A_b38', chrom='6', pos='144955490', logp=6.16701, fdr=4.55491, target='ENSG00000152818', maf=None),
#  SNPRes(rsid='chr6_144955508_C_T_b38', chrom='6', pos='144955508', logp=6.16701, fdr=4.55491, target='ENSG00000152818', maf=None),
#  SNPRes(rsid='chr6_159065354_C_A_b38', chrom='6', pos='159065354', logp=6.10954, fdr=4.50207, target='ENSG00000271913', maf=None),
#  SNPRes(rsid='chr6_144683275_C_T_b38', chrom='6', pos='144683275', logp=5.8918, fdr=4.30421, target='ENSG00000152818', maf=None),
#  SNPRes(rsid='chr6_110931131_G_A_b38', chrom='6', pos='110931131', logp=5.57925, fdr=4.01966, target='ENSG00000123505', maf=None),
#  SNPRes(rsid='chr6_110932599_A_G_b38', chrom='6', pos='110932599', logp=5.57925, fdr=4.01966, target='ENSG00000123505', maf=None),
#  SNPRes(rsid='chr6_110932797_T_G_b38', chrom='6', pos='110932797', logp=5.57925, fdr=4.01966, target='ENSG00000123505', maf=None),
#  SNPRes(rsid='chr6_159065354_C_A_b38', chrom='6', pos='159065354', logp=5.20535, fdr=3.68087, target='ENSG00000130363', maf=None),
#  SNPRes(rsid='chr6_143079531_A_G_b38', chrom='6', pos='143079531', logp=4.78003, fdr=3.29793, target='ENSG00000146416', maf=None),
#  SNPRes(rsid='chr6_111020491_G_A_b38', chrom='6', pos='111020491', logp=4.10469, fdr=2.69918, target='ENSG00000123505', maf=None),
#  SNPRes(rsid='chr6_3714832_T_C_b38', chrom='6', pos='3714832', logp=3.97384, fdr=2.5864, target='ENSG00000168994', maf=None),
#  SNPRes(rsid='chr6_110931131_G_A_b38', chrom='6', pos='110931131', logp=3.74572, fdr=2.38708, target='ENSG00000155115', maf=None),
#  SNPRes(rsid='chr6_110932599_A_G_b38', chrom='6', pos='110932599', logp=3.74572, fdr=2.38708, target='ENSG00000155115', maf=None),
#  SNPRes(rsid='chr6_110932797_T_G_b38', chrom='6', pos='110932797', logp=3.74572, fdr=2.38708, target='ENSG00000155115', maf=None),
#  SNPRes(rsid='chr6_111005884_T_G_b38', chrom='6', pos='111005884', logp=3.73704, fdr=2.37947, target='ENSG00000155115', maf=None),
#  SNPRes(rsid='chr6_111019248_G_A_b38', chrom='6', pos='111019248', logp=3.66403, fdr=2.3157, target='ENSG00000155115', maf=None),
#  SNPRes(rsid='chr6_110830956_A_G_b38', chrom='6', pos='110830956', logp=3.64711, fdr=2.30096, target='ENSG00000123505', maf=None),
#  SNPRes(rsid='chr6_111005884_T_G_b38', chrom='6', pos='111005884', logp=3.46165, fdr=2.14193, target='ENSG00000123505', maf=None),
#  SNPRes(rsid='chr6_111019248_G_A_b38', chrom='6', pos='111019248', logp=3.42956, fdr=2.11457, target='ENSG00000123505', maf=None),
#  SNPRes(rsid='chr6_54012383_G_A_b38', chrom='6', pos='54012383', logp=3.34344, fdr=2.0408, target='ENSG00000146147', maf=None),
#  SNPRes(rsid='chr6_54014520_G_T_b38', chrom='6', pos='54014520', logp=3.34344, fdr=2.0408, target='ENSG00000146147', maf=None),
#  SNPRes(rsid='chr6_54016213_G_A_b38', chrom='6', pos='54016213', logp=3.34344, fdr=2.0408, target='ENSG00000146147', maf=None),
#  SNPRes(rsid='chr6_111020491_G_A_b38', chrom='6', pos='111020491', logp=3.30778, fdr=2.01033, target='ENSG00000155115', maf=None),
#  SNPRes(rsid='chr9_85530029_T_C_b38', chrom='9', pos='85530029', logp=7.77265, fdr=5.92031, target='ENSG00000135049', maf=None),
#  SNPRes(rsid='chr9_85558031_A_G_b38', chrom='9', pos='85558031', logp=7.77265, fdr=5.92031, target='ENSG00000135049', maf=None),
#  SNPRes(rsid='chr9_126837427_A_G_b38', chrom='9', pos='126837427', logp=6.63019, fdr=4.84403, target='ENSG00000169155', maf=None),
#  SNPRes(rsid='chr9_126837427_A_G_b38', chrom='9', pos='126837427', logp=3.71324, fdr=2.16663, target='ENSG00000136854', maf=None),
#  SNPRes(rsid='chr10_89209002_C_T_b38', chrom='10', pos='89209002', logp=26.3537, fdr=23.9794, target='ENSG00000138135', maf=None),
#  SNPRes(rsid='chr10_89207336_T_C_b38', chrom='10', pos='89207336', logp=25.9164, fdr=23.5617, target='ENSG00000138135', maf=None),
#  SNPRes(rsid='chr10_89205934_T_C_b38', chrom='10', pos='89205934', logp=25.8733, fdr=23.5202, target='ENSG00000138135', maf=None),
#  SNPRes(rsid='chr10_89206789_C_T_b38', chrom='10', pos='89206789', logp=24.1034, fdr=21.8047, target='ENSG00000138135', maf=None),
#  SNPRes(rsid='chr10_89204269_A_G_b38', chrom='10', pos='89204269', logp=23.8258, fdr=21.533, target='ENSG00000138135', maf=None),
#  SNPRes(rsid='chr10_89204529_A_G_b38', chrom='10', pos='89204529', logp=23.8258, fdr=21.533, target='ENSG00000138135', maf=None),
#  SNPRes(rsid='chr10_89204638_G_T_b38', chrom='10', pos='89204638', logp=23.8258, fdr=21.533, target='ENSG00000138135', maf=None),
#  SNPRes(rsid='chr10_114281518_G_A_b38', chrom='10', pos='114281518', logp=23.1946, fdr=20.9195, target='ENSG00000169129', maf=None),
#  SNPRes(rsid='chr10_89198861_C_T_b38', chrom='10', pos='89198861', logp=22.724, fdr=20.4602, target='ENSG00000138135', maf=None),
#  SNPRes(rsid='chr10_89202042_G_A_b38', chrom='10', pos='89202042', logp=22.724, fdr=20.4602, target='ENSG00000138135', maf=None),
#  SNPRes(rsid='chr10_89204857_T_G_b38', chrom='10', pos='89204857', logp=22.724, fdr=20.4602, target='ENSG00000138135', maf=None),
#  SNPRes(rsid='chr10_114313937_C_T_b38', chrom='10', pos='114313937', logp=22.151, fdr=19.9058, target='ENSG00000169129', maf=None),
#  SNPRes(rsid='chr10_89163071_G_A_b38', chrom='10', pos='89163071', logp=20.1103, fdr=17.9331, target='ENSG00000138135', maf=None),
#  SNPRes(rsid='chr10_89163133_C_T_b38', chrom='10', pos='89163133', logp=20.1103, fdr=17.9331, target='ENSG00000138135', maf=None),
#  SNPRes(rsid='chr10_89164501_A_G_b38', chrom='10', pos='89164501', logp=20.1103, fdr=17.9331, target='ENSG00000138135', maf=None),
#  SNPRes(rsid='chr10_89167406_G_A_b38', chrom='10', pos='89167406', logp=20.1103, fdr=17.9331, target='ENSG00000138135', maf=None),
#  SNPRes(rsid='chr10_89195482_G_T_b38', chrom='10', pos='89195482', logp=19.3641, fdr=17.2071, target='ENSG00000138135', maf=None),
#  SNPRes(rsid='chr10_89195717_A_C_b38', chrom='10', pos='89195717', logp=19.3641, fdr=17.2071, target='ENSG00000138135', maf=None),
#  SNPRes(rsid='chr10_89163767_G_A_b38', chrom='10', pos='89163767', logp=19.3568, fdr=17.2001, target='ENSG00000138135', maf=None),
#  SNPRes(rsid='chr10_89165910_T_G_b38', chrom='10', pos='89165910', logp=19.3568, fdr=17.2001, target='ENSG00000138135', maf=None),
#  SNPRes(rsid='chr10_89169790_G_A_b38', chrom='10', pos='89169790', logp=19.3568, fdr=17.2001, target='ENSG00000138135', maf=None),
#  SNPRes(rsid='chr10_89171421_T_G_b38', chrom='10', pos='89171421', logp=19.3568, fdr=17.2001, target='ENSG00000138135', maf=None),
#  SNPRes(rsid='chr10_89179145_G_T_b38', chrom='10', pos='89179145', logp=19.3568, fdr=17.2001, target='ENSG00000138135', maf=None),
#  SNPRes(rsid='chr10_89499900_C_T_b38', chrom='10', pos='89499900', logp=9.31305, fdr=7.49675, target='ENSG00000152779', maf=None),
#  SNPRes(rsid='chr10_89494542_T_C_b38', chrom='10', pos='89494542', logp=9.19765, fdr=7.38575, target='ENSG00000152779', maf=None),
#  SNPRes(rsid='chr10_89221804_A_G_b38', chrom='10', pos='89221804', logp=8.8271, fdr=7.03266, target='ENSG00000138135', maf=None),
#  SNPRes(rsid='chr10_89222130_T_G_b38', chrom='10', pos='89222130', logp=7.11373, fdr=5.40371, target='ENSG00000138135', maf=None),
#  SNPRes(rsid='chr10_11114509_T_C_b38', chrom='10', pos='11114509', logp=3.45709, fdr=2.02329, target='ENSG00000237986', maf=None),
#  SNPRes(rsid='chr10_11107674_G_A_b38', chrom='10', pos='11107674', logp=3.22757, fdr=1.82226, target='ENSG00000237986', maf=None),
#  SNPRes(rsid='chr10_11108882_T_C_b38', chrom='10', pos='11108882', logp=3.02109, fdr=1.64177, target='ENSG00000237986', maf=None),
#  SNPRes(rsid='chr11_68393036_G_T_b38', chrom='11', pos='68393036', logp=28.1876, fdr=25.6427, target='ENSG00000162337', maf=None),
#  SNPRes(rsid='chr11_68381982_A_C_b38', chrom='11', pos='68381982', logp=28.0835, fdr=25.5416, target='ENSG00000162337', maf=None),
#  SNPRes(rsid='chr11_2309170_G_A_b38', chrom='11', pos='2309170', logp=16.9808, fdr=14.7776, target='ENSG00000064201', maf=None),
#  SNPRes(rsid='chr11_2309249_G_A_b38', chrom='11', pos='2309249', logp=16.9808, fdr=14.7776, target='ENSG00000064201', maf=None),
#  SNPRes(rsid='chr11_2309700_C_T_b38', chrom='11', pos='2309700', logp=16.9808, fdr=14.7776, target='ENSG00000064201', maf=None),
#  SNPRes(rsid='chr11_2309747_T_C_b38', chrom='11', pos='2309747', logp=16.9808, fdr=14.7776, target='ENSG00000064201', maf=None),
#  SNPRes(rsid='chr11_2309820_C_A_b38', chrom='11', pos='2309820', logp=16.9808, fdr=14.7776, target='ENSG00000064201', maf=None),
#  SNPRes(rsid='chr11_2309823_A_G_b38', chrom='11', pos='2309823', logp=16.9808, fdr=14.7776, target='ENSG00000064201', maf=None),
#  SNPRes(rsid='chr11_2309866_G_A_b38', chrom='11', pos='2309866', logp=16.9808, fdr=14.7776, target='ENSG00000064201', maf=None),
#  SNPRes(rsid='chr11_2309984_A_C_b38', chrom='11', pos='2309984', logp=16.9808, fdr=14.7776, target='ENSG00000064201', maf=None),
#  SNPRes(rsid='chr11_2307477_A_G_b38', chrom='11', pos='2307477', logp=16.6704, fdr=14.4769, target='ENSG00000064201', maf=None),
#  SNPRes(rsid='chr11_2307848_T_G_b38', chrom='11', pos='2307848', logp=16.5296, fdr=14.3419, target='ENSG00000064201', maf=None),
#  SNPRes(rsid='chr11_2307889_C_T_b38', chrom='11', pos='2307889', logp=16.5296, fdr=14.3419, target='ENSG00000064201', maf=None),
#  SNPRes(rsid='chr11_2307463_C_T_b38', chrom='11', pos='2307463', logp=15.9986, fdr=13.8283, target='ENSG00000064201', maf=None),
#  SNPRes(rsid='chr11_68381982_A_C_b38', chrom='11', pos='68381982', logp=15.3864, fdr=13.2355, target='ENSG00000110075', maf=None),
#  SNPRes(rsid='chr11_68393036_G_T_b38', chrom='11', pos='68393036', logp=15.2463, fdr=13.1004, target='ENSG00000110075', maf=None),
#  SNPRes(rsid='chr11_2301799_T_C_b38', chrom='11', pos='2301799', logp=12.1723, fdr=10.1399, target='ENSG00000064201', maf=None),
#  SNPRes(rsid='chr11_2302811_A_G_b38', chrom='11', pos='2302811', logp=11.7634, fdr=9.74714, target='ENSG00000064201', maf=None),
#  SNPRes(rsid='chr11_61954740_G_T_b38', chrom='11', pos='61954740', logp=11.6081, fdr=9.59914, target='ENSG00000167995', maf=None),
#  SNPRes(rsid='chr11_61955173_C_A_b38', chrom='11', pos='61955173', logp=11.5894, fdr=9.58101, target='ENSG00000167995', maf=None),
#  SNPRes(rsid='chr11_68381982_A_C_b38', chrom='11', pos='68381982', logp=8.41602, fdr=6.55772, target='ENSG00000260808', maf=None),
#  SNPRes(rsid='chr11_68393036_G_T_b38', chrom='11', pos='68393036', logp=8.19734, fdr=6.35073, target='ENSG00000260808', maf=None),
#  SNPRes(rsid='chr11_61954740_G_T_b38', chrom='11', pos='61954740', logp=7.94035, fdr=6.10702, target='ENSG00000167996', maf=None),
#  SNPRes(rsid='chr11_61955173_C_A_b38', chrom='11', pos='61955173', logp=7.79736, fdr=5.97302, target='ENSG00000167996', maf=None),
#  SNPRes(rsid='chr11_2307477_A_G_b38', chrom='11', pos='2307477', logp=5.62673, fdr=3.93587, target='ENSG00000238184', maf=None),
#  SNPRes(rsid='chr11_2309170_G_A_b38', chrom='11', pos='2309170', logp=5.58133, fdr=3.89412, target='ENSG00000238184', maf=None),
#  SNPRes(rsid='chr11_2309249_G_A_b38', chrom='11', pos='2309249', logp=5.58133, fdr=3.89412, target='ENSG00000238184', maf=None),
#  SNPRes(rsid='chr11_2309700_C_T_b38', chrom='11', pos='2309700', logp=5.58133, fdr=3.89412, target='ENSG00000238184', maf=None),
#  SNPRes(rsid='chr11_2309747_T_C_b38', chrom='11', pos='2309747', logp=5.58133, fdr=3.89412, target='ENSG00000238184', maf=None),
#  SNPRes(rsid='chr11_2309820_C_A_b38', chrom='11', pos='2309820', logp=5.58133, fdr=3.89412, target='ENSG00000238184', maf=None),
#  SNPRes(rsid='chr11_2309823_A_G_b38', chrom='11', pos='2309823', logp=5.58133, fdr=3.89412, target='ENSG00000238184', maf=None),
#  SNPRes(rsid='chr11_2309866_G_A_b38', chrom='11', pos='2309866', logp=5.58133, fdr=3.89412, target='ENSG00000238184', maf=None),
#  SNPRes(rsid='chr11_2309984_A_C_b38', chrom='11', pos='2309984', logp=5.58133, fdr=3.89412, target='ENSG00000238184', maf=None),
#  SNPRes(rsid='chr11_2307848_T_G_b38', chrom='11', pos='2307848', logp=5.33359, fdr=3.66532, target='ENSG00000238184', maf=None),
#  SNPRes(rsid='chr11_2307889_C_T_b38', chrom='11', pos='2307889', logp=5.33359, fdr=3.66532, target='ENSG00000238184', maf=None),
#  SNPRes(rsid='chr11_2307463_C_T_b38', chrom='11', pos='2307463', logp=5.30643, fdr=3.64013, target='ENSG00000238184', maf=None),
#  SNPRes(rsid='chr11_2917931_G_A_b38', chrom='11', pos='2917931', logp=3.85032, fdr=2.31845, target='ENSG00000110628', maf=None),
#  SNPRes(rsid='chr11_2918475_G_A_b38', chrom='11', pos='2918475', logp=3.85032, fdr=2.31845, target='ENSG00000110628', maf=None),
#  SNPRes(rsid='chr11_2301799_T_C_b38', chrom='11', pos='2301799', logp=3.49896, fdr=2.00799, target='ENSG00000238184', maf=None),
#  SNPRes(rsid='chr11_2302811_A_G_b38', chrom='11', pos='2302811', logp=3.31131, fdr=1.84452, target='ENSG00000238184', maf=None),
#  SNPRes(rsid='chr11_32539846_C_T_b38', chrom='11', pos='32539846', logp=3.06469, fdr=1.63329, target='ENSG00000135378', maf=None),
#  SNPRes(rsid='chr12_22543911_G_A_b38', chrom='12', pos='22543911', logp=20.397, fdr=18.1108, target='ENSG00000111731', maf=None),
#  SNPRes(rsid='chr12_22551497_G_A_b38', chrom='12', pos='22551497', logp=19.1937, fdr=16.9445, target='ENSG00000111731', maf=None),
#  SNPRes(rsid='chr12_22564999_G_T_b38', chrom='12', pos='22564999', logp=19.1937, fdr=16.9445, target='ENSG00000111731', maf=None),
#  SNPRes(rsid='chr12_22376906_G_A_b38', chrom='12', pos='22376906', logp=15.6332, fdr=13.5128, target='ENSG00000111731', maf=None),
#  SNPRes(rsid='chr12_22338706_G_A_b38', chrom='12', pos='22338706', logp=14.993, fdr=12.8944, target='ENSG00000111731', maf=None),
#  SNPRes(rsid='chr12_22366801_T_G_b38', chrom='12', pos='22366801', logp=14.993, fdr=12.8944, target='ENSG00000111731', maf=None),
#  SNPRes(rsid='chr12_22374260_C_T_b38', chrom='12', pos='22374260', logp=14.993, fdr=12.8944, target='ENSG00000111731', maf=None),
#  SNPRes(rsid='chr12_22356161_T_C_b38', chrom='12', pos='22356161', logp=13.7998, fdr=11.7418, target='ENSG00000111731', maf=None),
#  SNPRes(rsid='chr12_22372419_A_C_b38', chrom='12', pos='22372419', logp=12.9614, fdr=10.9341, target='ENSG00000111731', maf=None),
#  SNPRes(rsid='chr12_128653733_A_G_b38', chrom='12', pos='128653733', logp=3.94, fdr=2.41821, target='ENSG00000181234', maf=None),
#  SNPRes(rsid='chr12_80460849_C_T_b38', chrom='12', pos='80460849', logp=3.86436, fdr=2.35076, target='ENSG00000139304', maf=None),
#  SNPRes(rsid='chr12_19034411_T_C_b38', chrom='12', pos='19034411', logp=3.24572, fdr=1.80482, target='ENSG00000052126', maf=None),
#  SNPRes(rsid='chr13_49746825_T_C_b38', chrom='13', pos='49746825', logp=9.47449, fdr=7.5551, target='ENSG00000102753', maf=None),
#  SNPRes(rsid='chr13_49651403_C_T_b38', chrom='13', pos='49651403', logp=8.32883, fdr=6.46624, target='ENSG00000102753', maf=None),
#  SNPRes(rsid='chr13_49653360_T_G_b38', chrom='13', pos='49653360', logp=8.32883, fdr=6.46624, target='ENSG00000102753', maf=None),
#  SNPRes(rsid='chr13_113286646_A_G_b38', chrom='13', pos='113286646', logp=4.16436, fdr=2.56588, target='ENSG00000185896', maf=None),
#  SNPRes(rsid='chr13_113287986_G_A_b38', chrom='13', pos='113287986', logp=4.16436, fdr=2.56588, target='ENSG00000185896', maf=None),
#  SNPRes(rsid='chr13_113288632_G_A_b38', chrom='13', pos='113288632', logp=4.16436, fdr=2.56588, target='ENSG00000185896', maf=None),
#  SNPRes(rsid='chr13_113295721_C_T_b38', chrom='13', pos='113295721', logp=4.16436, fdr=2.56588, target='ENSG00000185896', maf=None),
#  SNPRes(rsid='chr13_113286646_A_G_b38', chrom='13', pos='113286646', logp=3.11206, fdr=1.6362, target='ENSG00000139835', maf=None),
#  SNPRes(rsid='chr13_113287986_G_A_b38', chrom='13', pos='113287986', logp=3.11206, fdr=1.6362, target='ENSG00000139835', maf=None),
#  SNPRes(rsid='chr13_113288632_G_A_b38', chrom='13', pos='113288632', logp=3.11206, fdr=1.6362, target='ENSG00000139835', maf=None),
#  SNPRes(rsid='chr13_113295721_C_T_b38', chrom='13', pos='113295721', logp=3.11206, fdr=1.6362, target='ENSG00000139835', maf=None),
#  SNPRes(rsid='chr14_94121934_G_A_b38', chrom='14', pos='94121934', logp=15.3966, fdr=13.2613, target='ENSG00000165949', maf=None),
#  SNPRes(rsid='chr14_94125298_C_A_b38', chrom='14', pos='94125298', logp=10.5843, fdr=8.65077, target='ENSG00000165949', maf=None),
#  SNPRes(rsid='chr15_52235969_A_G_b38', chrom='15', pos='52235969', logp=20.4877, fdr=18.2581, target='ENSG00000128833', maf=None),
#  SNPRes(rsid='chr15_52242147_G_A_b38', chrom='15', pos='52242147', logp=19.1838, fdr=17.0004, target='ENSG00000128833', maf=None),
#  SNPRes(rsid='chr15_52235969_A_G_b38', chrom='15', pos='52235969', logp=7.69183, fdr=5.97131, target='ENSG00000259577', maf=None),
#  SNPRes(rsid='chr15_52242147_G_A_b38', chrom='15', pos='52242147', logp=7.11492, fdr=5.42833, target='ENSG00000259577', maf=None),
#  SNPRes(rsid='chr15_52275027_C_T_b38', chrom='15', pos='52275027', logp=7.10982, fdr=5.42355, target='ENSG00000128833', maf=None),
#  SNPRes(rsid='chr15_52275326_T_C_b38', chrom='15', pos='52275326', logp=6.15373, fdr=4.52748, target='ENSG00000128833', maf=None),
#  SNPRes(rsid='chr15_52281323_A_C_b38', chrom='15', pos='52281323', logp=5.86628, fdr=4.25988, target='ENSG00000128833', maf=None),
#  SNPRes(rsid='chr15_52235969_A_G_b38', chrom='15', pos='52235969', logp=5.80143, fdr=4.19891, target='ENSG00000259709', maf=None),
#  SNPRes(rsid='chr15_52290413_G_A_b38', chrom='15', pos='52290413', logp=5.59195, fdr=4.00272, target='ENSG00000128833', maf=None),
# ...
#  SNPRes(rsid='chr16_29605798_A_C_b38', chrom='16', pos='29605798', logp=3.4729, fdr=2.03554, target='ENSG00000279583', maf=None),
#  SNPRes(rsid='chr17_19392137_G_T_b38', chrom='17', pos='19392137', logp=34.1878, fdr=31.6363, target='ENSG00000108641', maf=None),
#  SNPRes(rsid='chr17_19378515_T_G_b38', chrom='17', pos='19378515', logp=33.7489, fdr=31.2091, target='ENSG00000108641', maf=None),
#  SNPRes(rsid='chr17_19388755_A_G_b38', chrom='17', pos='19388755', logp=33.6121, fdr=31.1054, target='ENSG00000108641', maf=None),
#  SNPRes(rsid='chr17_19390414_G_A_b38', chrom='17', pos='19390414', logp=33.6121, fdr=31.1054, target='ENSG00000108641', maf=None),
#  SNPRes(rsid='chr17_19353811_A_G_b38', chrom='17', pos='19353811', logp=31.8722, fdr=29.3946, target='ENSG00000108641', maf=None),
#  SNPRes(rsid='chr17_19343762_G_A_b38', chrom='17', pos='19343762', logp=31.8475, fdr=29.3713, target='ENSG00000108641', maf=None),
#  SNPRes(rsid='chr17_19268883_T_G_b38', chrom='17', pos='19268883', logp=31.529, fdr=29.0575, target='ENSG00000108641', maf=None),
#  SNPRes(rsid='chr17_19269192_A_G_b38', chrom='17', pos='19269192', logp=31.529, fdr=29.0575, target='ENSG00000108641', maf=None),
#  SNPRes(rsid='chr17_19272004_A_G_b38', chrom='17', pos='19272004', logp=31.529, fdr=29.0575, target='ENSG00000108641', maf=None),
#  SNPRes(rsid='chr17_19301550_T_C_b38', chrom='17', pos='19301550', logp=31.529, fdr=29.0575, target='ENSG00000108641', maf=None),
#  SNPRes(rsid='chr17_19313948_C_T_b38', chrom='17', pos='19313948', logp=31.529, fdr=29.0575, target='ENSG00000108641', maf=None),
#  SNPRes(rsid='chr17_19338192_G_A_b38', chrom='17', pos='19338192', logp=31.529, fdr=29.0575, target='ENSG00000108641', maf=None),
#  SNPRes(rsid='chr17_19317353_G_A_b38', chrom='17', pos='19317353', logp=31.4795, fdr=29.0089, target='ENSG00000108641', maf=None),
#  SNPRes(rsid='chr17_19271561_T_C_b38', chrom='17', pos='19271561', logp=31.3788, fdr=28.9101, target='ENSG00000108641', maf=None),
#  SNPRes(rsid='chr17_19336119_C_T_b38', chrom='17', pos='19336119', logp=31.2429, fdr=28.7769, target='ENSG00000108641', maf=None),
#  SNPRes(rsid='chr17_19020505_G_A_b38', chrom='17', pos='19020505', logp=19.0899, fdr=16.9018, target='ENSG00000108641', maf=None),
#  SNPRes(rsid='chr17_19391511_G_T_b38', chrom='17', pos='19391511', logp=18.2782, fdr=16.1096, target='ENSG00000108641', maf=None),
#  SNPRes(rsid='chr17_19238913_C_T_b38', chrom='17', pos='19238913', logp=16.3459, fdr=14.2231, target='ENSG00000108641', maf=None),
#  SNPRes(rsid='chr17_19353811_A_G_b38', chrom='17', pos='19353811', logp=15.8684, fdr=13.7582, target='ENSG00000072134', maf=None),
#  SNPRes(rsid='chr17_19336119_C_T_b38', chrom='17', pos='19336119', logp=15.6417, fdr=13.5377, target='ENSG00000072134', maf=None),
#  SNPRes(rsid='chr17_19317353_G_A_b38', chrom='17', pos='19317353', logp=15.5829, fdr=13.4803, target='ENSG00000072134', maf=None),
#  SNPRes(rsid='chr17_19268883_T_G_b38', chrom='17', pos='19268883', logp=15.5538, fdr=13.4521, target='ENSG00000072134', maf=None),
#  SNPRes(rsid='chr17_19269192_A_G_b38', chrom='17', pos='19269192', logp=15.5538, fdr=13.4521, target='ENSG00000072134', maf=None),
#  SNPRes(rsid='chr17_19272004_A_G_b38', chrom='17', pos='19272004', logp=15.5538, fdr=13.4521, target='ENSG00000072134', maf=None),
#  SNPRes(rsid='chr17_19301550_T_C_b38', chrom='17', pos='19301550', logp=15.5538, fdr=13.4521, target='ENSG00000072134', maf=None),
#  SNPRes(rsid='chr17_19313948_C_T_b38', chrom='17', pos='19313948', logp=15.5538, fdr=13.4521, target='ENSG00000072134', maf=None),
#  SNPRes(rsid='chr17_19338192_G_A_b38', chrom='17', pos='19338192', logp=15.5538, fdr=13.4521, target='ENSG00000072134', maf=None),
#  SNPRes(rsid='chr17_19343762_G_A_b38', chrom='17', pos='19343762', logp=15.2473, fdr=13.1526, target='ENSG00000072134', maf=None),
#  SNPRes(rsid='chr17_19271561_T_C_b38', chrom='17', pos='19271561', logp=15.0739, fdr=12.9839, target='ENSG00000072134', maf=None),
#  SNPRes(rsid='chr17_60558968_A_G_b38', chrom='17', pos='60558968', logp=13.4867, fdr=11.4423, target='ENSG00000062725', maf=None),
#  SNPRes(rsid='chr17_19378515_T_G_b38', chrom='17', pos='19378515', logp=13.1046, fdr=11.0736, target='ENSG00000072134', maf=None),
#  SNPRes(rsid='chr17_19388755_A_G_b38', chrom='17', pos='19388755', logp=12.9898, fdr=10.9625, target='ENSG00000072134', maf=None),
#  SNPRes(rsid='chr17_19390414_G_A_b38', chrom='17', pos='19390414', logp=12.9898, fdr=10.9625, target='ENSG00000072134', maf=None),
#  SNPRes(rsid='chr17_19392137_G_T_b38', chrom='17', pos='19392137', logp=12.8021, fdr=10.7812, target='ENSG00000072134', maf=None),
#  SNPRes(rsid='chr17_19378515_T_G_b38', chrom='17', pos='19378515', logp=11.5148, fdr=9.53694, target='ENSG00000166484', maf=None),
#  SNPRes(rsid='chr17_19388755_A_G_b38', chrom='17', pos='19388755', logp=11.3132, fdr=9.34198, target='ENSG00000166484', maf=None),
#  SNPRes(rsid='chr17_19390414_G_A_b38', chrom='17', pos='19390414', logp=11.3132, fdr=9.34198, target='ENSG00000166484', maf=None),
#  SNPRes(rsid='chr17_19392137_G_T_b38', chrom='17', pos='19392137', logp=11.2068, fdr=9.24897, target='ENSG00000166484', maf=None),
#  SNPRes(rsid='chr17_19020505_G_A_b38', chrom='17', pos='19020505', logp=8.79137, fdr=6.93664, target='ENSG00000072134', maf=None),
#  SNPRes(rsid='chr17_19238913_C_T_b38', chrom='17', pos='19238913', logp=8.15928, fdr=6.33329, target='ENSG00000072134', maf=None),
#  SNPRes(rsid='chr17_19317353_G_A_b38', chrom='17', pos='19317353', logp=7.4179, fdr=5.62885, target='ENSG00000166484', maf=None),
#  SNPRes(rsid='chr17_19268883_T_G_b38', chrom='17', pos='19268883', logp=7.34951, fdr=5.56399, target='ENSG00000166484', maf=None),
#  SNPRes(rsid='chr17_19269192_A_G_b38', chrom='17', pos='19269192', logp=7.34951, fdr=5.56399, target='ENSG00000166484', maf=None),
#  SNPRes(rsid='chr17_19272004_A_G_b38', chrom='17', pos='19272004', logp=7.34951, fdr=5.56399, target='ENSG00000166484', maf=None),
#  SNPRes(rsid='chr17_19301550_T_C_b38', chrom='17', pos='19301550', logp=7.34951, fdr=5.56399, target='ENSG00000166484', maf=None),
#  SNPRes(rsid='chr17_19313948_C_T_b38', chrom='17', pos='19313948', logp=7.34951, fdr=5.56399, target='ENSG00000166484', maf=None),
#  SNPRes(rsid='chr17_19338192_G_A_b38', chrom='17', pos='19338192', logp=7.34951, fdr=5.56399, target='ENSG00000166484', maf=None),
#  SNPRes(rsid='chr17_19343762_G_A_b38', chrom='17', pos='19343762', logp=7.3372, fdr=5.55279, target='ENSG00000166484', maf=None),
#  SNPRes(rsid='chr17_19336119_C_T_b38', chrom='17', pos='19336119', logp=7.28033, fdr=5.49862, target='ENSG00000166484', maf=None),
#  SNPRes(rsid='chr17_19271561_T_C_b38', chrom='17', pos='19271561', logp=7.25673, fdr=5.47603, target='ENSG00000166484', maf=None),
#  SNPRes(rsid='chr17_19353811_A_G_b38', chrom='17', pos='19353811', logp=7.17801, fdr=5.40162, target='ENSG00000166484', maf=None),
#  SNPRes(rsid='chr17_19391511_G_T_b38', chrom='17', pos='19391511', logp=6.72563, fdr=4.97283, target='ENSG00000072134', maf=None),
#  SNPRes(rsid='chr17_60558968_A_G_b38', chrom='17', pos='60558968', logp=6.44782, fdr=4.71049, target='ENSG00000170832', maf=None),
#  SNPRes(rsid='chr17_60558968_A_G_b38', chrom='17', pos='60558968', logp=6.09845, fdr=4.38165, target='ENSG00000267248', maf=None),
#  SNPRes(rsid='chr17_19020505_G_A_b38', chrom='17', pos='19020505', logp=5.88629, fdr=4.18205, target='ENSG00000154025', maf=None),
#  SNPRes(rsid='chr17_55708143_C_T_b38', chrom='17', pos='55708143', logp=5.56281, fdr=3.88235, target='ENSG00000166292', maf=None),
#  SNPRes(rsid='chr17_78035144_C_T_b38', chrom='17', pos='78035144', logp=5.42232, fdr=3.75153, target='ENSG00000078687', maf=None),
#  SNPRes(rsid='chr17_19020505_G_A_b38', chrom='17', pos='19020505', logp=4.88093, fdr=3.25581, target='ENSG00000166484', maf=None),
#  SNPRes(rsid='chr17_19317353_G_A_b38', chrom='17', pos='19317353', logp=4.08443, fdr=2.52309, target='ENSG00000154025', maf=None),
#  SNPRes(rsid='chr17_19271561_T_C_b38', chrom='17', pos='19271561', logp=4.08349, fdr=2.52226, target='ENSG00000154025', maf=None),
#  SNPRes(rsid='chr17_19238913_C_T_b38', chrom='17', pos='19238913', logp=4.03834, fdr=2.48145, target='ENSG00000128482', maf=None),
#  SNPRes(rsid='chr17_19336119_C_T_b38', chrom='17', pos='19336119', logp=4.0324, fdr=2.47603, target='ENSG00000154025', maf=None),
#  SNPRes(rsid='chr17_19353811_A_G_b38', chrom='17', pos='19353811', logp=4.02484, fdr=2.46948, target='ENSG00000154025', maf=None),
#  SNPRes(rsid='chr17_19343762_G_A_b38', chrom='17', pos='19343762', logp=3.99132, fdr=2.43909, target='ENSG00000154025', maf=None),
#  SNPRes(rsid='chr17_19268883_T_G_b38', chrom='17', pos='19268883', logp=3.98227, fdr=2.43089, target='ENSG00000154025', maf=None),
#  SNPRes(rsid='chr17_19269192_A_G_b38', chrom='17', pos='19269192', logp=3.98227, fdr=2.43089, target='ENSG00000154025', maf=None),
#  SNPRes(rsid='chr17_19272004_A_G_b38', chrom='17', pos='19272004', logp=3.98227, fdr=2.43089, target='ENSG00000154025', maf=None),
#  SNPRes(rsid='chr17_19301550_T_C_b38', chrom='17', pos='19301550', logp=3.98227, fdr=2.43089, target='ENSG00000154025', maf=None),
#  SNPRes(rsid='chr17_19313948_C_T_b38', chrom='17', pos='19313948', logp=3.98227, fdr=2.43089, target='ENSG00000154025', maf=None),
#  SNPRes(rsid='chr17_19338192_G_A_b38', chrom='17', pos='19338192', logp=3.98227, fdr=2.43089, target='ENSG00000154025', maf=None),
#  SNPRes(rsid='chr17_78035144_C_T_b38', chrom='17', pos='78035144', logp=3.97931, fdr=2.42812, target='ENSG00000204282', maf=None),
#  SNPRes(rsid='chr17_19391511_G_T_b38', chrom='17', pos='19391511', logp=3.90318, fdr=2.3593, target='ENSG00000166484', maf=None),
#  SNPRes(rsid='chr17_19391511_G_T_b38', chrom='17', pos='19391511', logp=3.67175, fdr=2.15457, target='ENSG00000128482', maf=None),
#  SNPRes(rsid='chr17_60558968_A_G_b38', chrom='17', pos='60558968', logp=3.37574, fdr=1.89117, target='ENSG00000167434', maf=None),
#  SNPRes(rsid='chr17_19343762_G_A_b38', chrom='17', pos='19343762', logp=3.36018, fdr=1.87746, target='ENSG00000128482', maf=None),
#  SNPRes(rsid='chr17_19238913_C_T_b38', chrom='17', pos='19238913', logp=3.26403, fdr=1.79356, target='ENSG00000166484', maf=None),
#  SNPRes(rsid='chr17_19317353_G_A_b38', chrom='17', pos='19317353', logp=3.25816, fdr=1.7884, target='ENSG00000128482', maf=None),
#  SNPRes(rsid='chr17_19388755_A_G_b38', chrom='17', pos='19388755', logp=3.25112, fdr=1.78216, target='ENSG00000154025', maf=None),
#  SNPRes(rsid='chr17_19390414_G_A_b38', chrom='17', pos='19390414', logp=3.25112, fdr=1.78216, target='ENSG00000154025', maf=None),
#  SNPRes(rsid='chr17_19271561_T_C_b38', chrom='17', pos='19271561', logp=3.23762, fdr=1.77049, target='ENSG00000128482', maf=None),
#  SNPRes(rsid='chr17_19336119_C_T_b38', chrom='17', pos='19336119', logp=3.2207, fdr=1.75602, target='ENSG00000128482', maf=None),
#  SNPRes(rsid='chr17_19353811_A_G_b38', chrom='17', pos='19353811', logp=3.19551, fdr=1.73446, target='ENSG00000128482', maf=None),
#  SNPRes(rsid='chr17_19378515_T_G_b38', chrom='17', pos='19378515', logp=3.19077, fdr=1.73028, target='ENSG00000154025', maf=None),
#  SNPRes(rsid='chr17_19301550_T_C_b38', chrom='17', pos='19301550', logp=3.16454, fdr=1.70752, target='ENSG00000128482', maf=None),
#  SNPRes(rsid='chr17_19313948_C_T_b38', chrom='17', pos='19313948', logp=3.16454, fdr=1.70752, target='ENSG00000128482', maf=None),
#  SNPRes(rsid='chr17_19338192_G_A_b38', chrom='17', pos='19338192', logp=3.16454, fdr=1.70752, target='ENSG00000128482', maf=None),
#  SNPRes(rsid='chr17_19268883_T_G_b38', chrom='17', pos='19268883', logp=3.16454, fdr=1.70752, target='ENSG00000128482', maf=None),
#  SNPRes(rsid='chr17_19269192_A_G_b38', chrom='17', pos='19269192', logp=3.16454, fdr=1.70752, target='ENSG00000128482', maf=None),
#  SNPRes(rsid='chr17_19272004_A_G_b38', chrom='17', pos='19272004', logp=3.16454, fdr=1.70752, target='ENSG00000128482', maf=None),
#  SNPRes(rsid='chr17_19392137_G_T_b38', chrom='17', pos='19392137', logp=3.1471, fdr=1.69243, target='ENSG00000154025', maf=None),
#  SNPRes(rsid='chr19_39387366_G_A_b38', chrom='19', pos='39387366', logp=26.7844, fdr=24.1745, target='ENSG00000006712', maf=None),
#  SNPRes(rsid='chr19_39387366_G_A_b38', chrom='19', pos='39387366', logp=26.2618, fdr=23.6661, target='ENSG00000130755', maf=None),
#  SNPRes(rsid='chr19_39387366_G_A_b38', chrom='19', pos='39387366', logp=25.0268, fdr=22.4633, target='ENSG00000179134', maf=None),
#  SNPRes(rsid='chr19_7882640_C_T_b38', chrom='19', pos='7882640', logp=8.76106, fdr=6.78401, target='ENSG00000142459', maf=None),
#  SNPRes(rsid='chr19_7882640_C_T_b38', chrom='19', pos='7882640', logp=5.16576, fdr=3.40045, target='ENSG00000104976', maf=None),
#  SNPRes(rsid='chr20_20048801_A_C_b38', chrom='20', pos='20048801', logp=10.0198, fdr=8.08617, target='ENSG00000101343', maf=None),
#  SNPRes(rsid='chr20_20052966_A_C_b38', chrom='20', pos='20052966', logp=9.75732, fdr=7.83417, target='ENSG00000101343', maf=None),
#  SNPRes(rsid='chr20_20054592_T_C_b38', chrom='20', pos='20054592', logp=9.75732, fdr=7.83417, target='ENSG00000101343', maf=None),
#  SNPRes(rsid='chr20_20054645_A_C_b38', chrom='20', pos='20054645', logp=9.75732, fdr=7.83417, target='ENSG00000101343', maf=None),
#  SNPRes(rsid='chr20_20068264_A_C_b38', chrom='20', pos='20068264', logp=9.75732, fdr=7.83417, target='ENSG00000101343', maf=None),
#  SNPRes(rsid='chr20_20068901_C_T_b38', chrom='20', pos='20068901', logp=9.68473, fdr=7.76482, target='ENSG00000101343', maf=None),
#  SNPRes(rsid='chr20_20070420_T_C_b38', chrom='20', pos='20070420', logp=9.49446, fdr=7.58345, target='ENSG00000101343', maf=None),
#  SNPRes(rsid='chr20_20045611_C_A_b38', chrom='20', pos='20045611', logp=9.03088, fdr=7.14113, target='ENSG00000101343', maf=None),
#  SNPRes(rsid='chr20_20035701_C_T_b38', chrom='20', pos='20035701', logp=8.95112, fdr=7.06548, target='ENSG00000101343', maf=None),
#  SNPRes(rsid='chr20_20022010_G_T_b38', chrom='20', pos='20022010', logp=8.92628, fdr=7.04191, target='ENSG00000101343', maf=None),
#  SNPRes(rsid='chr20_20022103_G_A_b38', chrom='20', pos='20022103', logp=8.77844, fdr=6.90134, target='ENSG00000101343', maf=None),
#  SNPRes(rsid='chr20_19998228_C_T_b38', chrom='20', pos='19998228', logp=6.87359, fdr=5.10672, target='ENSG00000132669', maf=None),
#  SNPRes(rsid='chr20_19998735_G_A_b38', chrom='20', pos='19998735', logp=6.52632, fdr=4.78189, target='ENSG00000132669', maf=None),
#  SNPRes(rsid='chr20_32555011_G_T_b38', chrom='20', pos='32555011', logp=4.75771, fdr=3.12701, target='ENSG00000171456', maf=None),
#  SNPRes(rsid='chr20_32517220_A_G_b38', chrom='20', pos='32517220', logp=4.70265, fdr=3.0758, target='ENSG00000171456', maf=None),
#  SNPRes(rsid='chr20_32580637_C_T_b38', chrom='20', pos='32580637', logp=4.37962, fdr=2.77829, target='ENSG00000171456', maf=None),
#  SNPRes(rsid='chr20_32557005_A_G_b38', chrom='20', pos='32557005', logp=4.37244, fdr=2.77156, target='ENSG00000171456', maf=None),
#  SNPRes(rsid='chr20_32574766_G_A_b38', chrom='20', pos='32574766', logp=4.36029, fdr=2.76051, target='ENSG00000171456', maf=None),
#  SNPRes(rsid='chr20_32580637_C_T_b38', chrom='20', pos='32580637', logp=4.02877, fdr=2.45736, target='ENSG00000101336', maf=None),
#  SNPRes(rsid='chr20_32557005_A_G_b38', chrom='20', pos='32557005', logp=3.90767, fdr=2.34769, target='ENSG00000101336', maf=None),
#  SNPRes(rsid='chr20_32574766_G_A_b38', chrom='20', pos='32574766', logp=3.8653, fdr=2.30986, target='ENSG00000101336', maf=None),
#  SNPRes(rsid='chr20_32555011_G_T_b38', chrom='20', pos='32555011', logp=3.70124, fdr=2.16319, target='ENSG00000101336', maf=None),
#  SNPRes(rsid='chr20_32517220_A_G_b38', chrom='20', pos='32517220', logp=3.41073, fdr=1.90732, target='ENSG00000101336', maf=None),
#  SNPRes(rsid='chr20_20070420_T_C_b38', chrom='20', pos='20070420', logp=3.39212, fdr=1.89137, target='ENSG00000173418', maf=None),
#  SNPRes(rsid='chr20_20048801_A_C_b38', chrom='20', pos='20048801', logp=3.11886, fdr=1.65607, target='ENSG00000173418', maf=None),
#  SNPRes(rsid='chr22_42480785_G_A_b38', chrom='22', pos='42480785', logp=4.36232, fdr=2.78634, target='ENSG00000100243', maf=None)]

# %%
uniq_snps_targettype
# Out:
# 3

# %%
outcisfilename = os.path.join(outdir,"CisEQTL_enrichment_results_"+title+".txt")
if os.path.exists(outcisfilename):
    print("Warning! File exists")
    raise
with open(outcisfilename, 'w') as outstream:
    for tissue in tissues:
        if tissue in res_dict:
            line = f"{tissue}\t{res_dict[tissue].ncis}\t{res_dict[tissue].ntrans}\t{res_dict[tissue].ncistrans}\t{res_dict[tissue].randtrans}\t{res_dict[tissue].enrichment}\t{res_dict[tissue].pval}\n"
            outstream.write(line)

outcistypefilename = os.path.join(outdir,"CisEQTL_target_enrichment_results_"+title+".txt")
if os.path.exists(outcisfilename):
    print("Warning! File exists")
    raise
with open(outcistypefilename, 'w') as outstream:
    for tissue in tissues:
        if tissue in res_dict_cistype:
            for genetype in res_dict_cistype[tissue].keys():
                cis_hits = res_dict_cistype[tissue][genetype].hits
                cis_frac = res_dict_cistype[tissue][genetype].frac
                cis_e    = res_dict_cistype[tissue][genetype].enrichment
                cis_pval = res_dict_cistype[tissue][genetype].pval
                random_hits = res_dict_randomtype[tissue][genetype].hits
                random_frac = res_dict_randomtype[tissue][genetype].frac
                random_e    = res_dict_randomtype[tissue][genetype].enrichment
                random_pval = res_dict_randomtype[tissue][genetype].pval
                cisline    = f"{tissue}\t{genetype}\tCIS\t{cis_hits}\t{cis_frac}\t{cis_e}\t{cis_pval}\n"
                randomline = f"{tissue}\t{genetype}\tRANDOM\t{random_hits}\t{random_frac}\t{random_e}\t{random_pval}\n"
                outstream.write(cisline)
                outstream.write(randomline)

# %%
import json
import os 
from utils import utils

json_file = "../gtex_v8_metadata.json"
with open(json_file) as instream:
    gtex_meta = json.load(instream)
tissue_colors = dict()
tissue_names = dict()
tissue_samples = dict()
for tshort, tfull in zip(tissues, descriptions):
    tissue_names[tshort] = tfull
    tissue_colors[tshort] = "#" + gtex_meta[tfull.replace(" ", "_")]["colorHex"]
    tissue_samples[tshort] = gtex_meta[tfull.replace(" ", "_")]["rnaSeqAndGenotypeSampleCount"]

# %%
import operator
sorted_tissues = [x[0] for x in sorted(tissue_samples.items(), key=operator.itemgetter(1))]

# %%
# Load cis-eQTL enrichments (for our matrixeqtl cis-eqtls)
cisfilename = os.path.join(basepath, "cis_eqtls_analysis", title, "CisEQTL_enrichment_results_"+title+".txt")
# df_cis = pd.read_csv(cisfilename, sep="\t", header= None)
# df_cis.columns = ["tissue", "ncis", "ntrans", "ncistrans", "rand_frac", "cis_enrichment", "pval"]
# df_cis.index = df_cis.tissue

res_dict = dict()
with open(cisfilename) as instream:
    for line in instream:
        arr = line.strip().split("\t")
        tissue = arr[0]
        ncis   = int(arr[1])
        ntrans = int(arr[2])
        ncistrans = int(arr[3])
        rand_frac = float(arr[4])
        enrichment = float(arr[5])
        pval = float(arr[6])
        res_dict[tissue] = CisTrans(tissue=tissue, ncis=ncis, ntrans=ntrans, 
                                        ncistrans=ncistrans, randtrans=rand_frac,
                                        enrichment=enrichment, pval=pval)

# %%
from utils import mpl_stylesheet
mpl_stylesheet.banskt_presentation(fontfamily = 'latex-clearsans', fontsize = 22, colors = 'banskt', dpi = 300)

objects = list()
performance = list()
significance = list()
bar_colors = list()
bar_width = list()

for tshort in sorted_tissues:
    if tshort in res_dict:
        ntrans = res_dict[tshort].ntrans
        if ntrans > 0:
#             performance.append(res_dict[tshort].enrichment - 1.0))
            if np.log2(res_dict[tshort].enrichment) != -np.inf:
                objects.append(tissue_names[tshort] + f" ({tissue_samples[tshort]})")
                performance.append(np.log2(res_dict[tshort].enrichment))
                if res_dict[tshort].pval <= 0.0001:
                    significance.append('***')
                elif res_dict[tshort].pval <= 0.001:
                    significance.append('**')
                elif res_dict[tshort].pval <= 0.05:
                    significance.append('*')
                else:
                    significance.append('')
                bar_colors.append(tissue_colors[tshort])
                bar_width.append(tissue_samples[tshort])

bar_width = np.array(bar_width)

fig = plt.figure(figsize = (20, 15))
ax1 = fig.add_subplot(111)

y_pos = np.arange(len(objects))
bar1 = ax1.barh(y_pos, performance, align='center', color = bar_colors, linewidth = 0, height = 0.5) #01 * bar_width)

ax1.set_yticks(y_pos)
ax1.set_yticklabels(objects)
ax1.set_xlabel('Cis-EQTL $log_2(Enrichment)$')
xmax = np.around(np.max(performance) + 0.05, decimals = 1)
xmin = np.around(max(np.min(performance), -2) - 0.05, decimals = 1)
ax1.set_xlim([xmin, xmax])

ax1.tick_params(bottom = True, top = False, left = False, right = False, labelleft = True, labelbottom = True)
for side, border in ax1.spines.items():
    if not side == 'bottom':
        border.set_visible(False)
        
# Add p-values beside the bars
for i, rect in enumerate(bar1):
    width = rect.get_width()
    xpos = rect.get_width() + 0.02
    ypos = rect.get_y() + rect.get_height() / 2.0
    ax1.text(xpos, ypos, f'{significance[i]}', ha='left', va='center')

fig.canvas.draw()
# xticklabels = [f'{x.get_position()[0] + 1 :3.1f}' for x in ax1.get_xticklabels()]
# ax1.set_xticklabels(xticklabels)

outfile = "cis_eqtl_enrichment_barplot.png"
plt.tight_layout()
plt.savefig(outfile, bbox_inches='tight')
plt.show()

# %%
from utils import mpl_stylesheet
mpl_stylesheet.banskt_presentation(fontfamily = 'latex-clearsans', fontsize = 22, colors = 'banskt', dpi = 300)

genetypes = []
for tshort in tissues:
    genetypes += list(res_dict_randomtype[tshort].keys())
genetypes = list(set(genetypes))

for genetype in genetypes:
    objects = list()
    performance = list()
    significance = list()
    bar_colors = list()
    bar_width = list()
    for tshort in sorted_tissues:
        if tshort in res_dict:
            ntrans = res_dict[tshort].ntrans
            if ntrans > 0 and res_dict_randomtype[tshort].get(genetype, False):
                performance.append(res_dict_randomtype[tshort][genetype].enrichment - 1.0)
                objects.append(tissue_names[tshort])
                bar_colors.append(tissue_colors[tshort])
                bar_width.append(tissue_samples[tshort])
                if res_dict_randomtype[tshort][genetype].pval <= 0.0001:
                    significance.append('***')
                elif res_dict_randomtype[tshort][genetype].pval <= 0.001:
                    significance.append('**')
                elif res_dict_randomtype[tshort][genetype].pval <= 0.05:
                    significance.append('*')
                else:
                    significance.append('')
#                 objects.append(tissue_names[tshort])
#                 performance.append(res_dict[tshort].enrichment - 1.0)
#                 bar_colors.append(tissue_colors[tshort])
#                 bar_width.append(1)#tissue_samples[tshort])
#                 if res_dict[tshort].pval <= 0.0001:
#                     significance.append('***')
#                 elif res_dict[tshort].pval <= 0.001:
#                     significance.append('**')
#                 elif res_dict[tshort].pval <= 0.05:
#                     significance.append('*')
#                 else:
#                     significance.append('')


    bar_width = np.array(bar_width)

    fig = plt.figure(figsize = (15, 12))
    ax1 = fig.add_subplot(111)

    y_pos = np.arange(len(objects))
    bar1 = ax1.barh(y_pos, performance, align='center', color = bar_colors, linewidth = 0, height = 0.001 * bar_width)

    ax1.set_yticks(y_pos)
    ax1.set_yticklabels(objects)
    ax1.set_xlabel('Cis-EQTL Target-gene Enrichment in {:s}'.format(genetype))
    ax1.set_title(genetype)
    xmax = np.around(np.max(performance) + 0.05, decimals = 1)
    xmin = np.around(np.min(performance) - 0.05, decimals = 1)
    ax1.set_xlim([xmin, xmax])

    ax1.tick_params(bottom = True, top = False, left = False, right = False, labelleft = True, labelbottom = True)
    for side, border in ax1.spines.items():
        if not side == 'bottom':
            border.set_visible(False)

    # Add p-values beside the bars
    for i, rect in enumerate(bar1):
        width = rect.get_width()
        xpos = rect.get_width() + 0.02
        ypos = rect.get_y() + rect.get_height() / 2.0
        ax1.text(xpos, ypos, f'{significance[i]}', ha='left', va='center')

    fig.canvas.draw()
    xticklabels = [f'{x.get_position()[0] + 1 :3.1f}' for x in ax1.get_xticklabels()]
    ax1.set_xticklabels(xticklabels)

    outfile_type = os.path.join(outdir, "cis_eqtl_enrichment_{:s}.png".format(genetype))
    plt.tight_layout()
#     plt.savefig(outfile_type, bbox_inches='tight')
    plt.show()
