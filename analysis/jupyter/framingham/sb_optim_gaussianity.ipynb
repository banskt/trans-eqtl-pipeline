# %%
import numpy as np
import matplotlib.pyplot as plt

sb = []
k  = []
with open("/usr/users/fsimone/saikat/sb_optimization/framingham_uniq_sbpath_30_OFF_adj.txt") as ins:
# with open("/usr/users/fsimone/saikat/sb_optimization/framingham_uniq_sbpath_30.txt") as ins:
    for line in ins:
        arr = line.strip().split("\t")
        sb.append(float(arr[0]))
        k.append(np.abs(float(arr[1])))

# %%
plt.plot(sb, k)
plt.xlim(0, 0.007)
plt.show()

# %%
for i,j in zip(sb, k):
    print(i,j)
# Out:
# 0.001 0.1166134141851699
# 0.0010722672220103231 0.12286887251128953
# 0.0011497569953977356 0.12787560386908092
# 0.0012328467394420659 0.13174098494265263
# 0.0013219411484660286 0.13457882222708906
# 0.0014174741629268048 0.1365029425600799
# 0.0015199110829529332 0.1376216320419411
# 0.0016297508346206436 0.13803331346392433
# 0.001747528400007683 0.1378236982934431
# 0.001873817422860383 0.137064488150056
# 0.002009233002565048 0.13581355645583926
# 0.0021544346900318843 0.13411642787753308
# 0.0023101297000831605 0.13200879573341873
# 0.0024770763559917113 0.12951977334845333
# 0.0026560877829466868 0.12667555916264683
# 0.002848035868435802 0.12350320162659278
# 0.0030538555088334154 0.12003417326633592
# 0.0032745491628777285 0.11630749830349352
# 0.003511191734215131 0.11237221901588201
# 0.0037649358067924675 0.10828902711415145
# 0.004037017258596553 0.10413092424301063
# 0.004328761281083057 0.09998281053450064
# 0.004641588833612782 0.09593993672449852
# ...
